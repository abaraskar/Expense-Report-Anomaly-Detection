# %%
import numpy as np
import pandas as pd
import csv
import sys
import os
  
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
import warnings
import pickle

max_iters = 501
#n_estimators = 10

def logreg(x,y,filename):

   # Model output file name
   file = (os.path.splitext(filename))[0]
   fname = './models/lr_' + file +'/'

   # File for writing precision,recall, f-measure scores for fraud transactions
   f = open('./prf/lr_'+ file + '_prf' +'.txt' ,'w')
   f.write('precision,recall,f-score \n')

   # Stratified sampling based on Y
   X_train, X_test, y_train, y_test = train_test_split(x, y,stratify=y , test_size=0.30, random_state=42)

   # Create 15% validation set and 15% test set split
   X_val, X_test, y_val, y_test = train_test_split(X_test, y_test,stratify=y_test , test_size=0.50, random_state=42)
   
   #Iterations
   it = 1
   
   # Run training algorithm for multiple class weights
   while it < max_iters:
       cw = {}
       cw[0] = 1
       cw[1] = it
       # Train
       print('**************************************')
       print("Iteration number  " , it)
       lr = LogisticRegression(class_weight = cw)
       print('Class weights ', cw)
       lr.fit(X_train,y_train)

       # Save trained model to disk
       name = fname + str(cw[1]) + '.sav'
       pickle.dump(lr, open(name, 'wb'))

       # Predict on validation data
       y_val_pred = lr.predict(X_val)
       print('Performance on validation data - Confusion matrix')
       print(confusion_matrix(y_val,y_val_pred))
   
       precision,recall,fscore,support=score(y_val,y_val_pred,average=None)
       print('Precision, Recall, F-score, Support  on validation data' )
       print("Precision" , precision)
       print("Recall" , recall)
       print("F-score" , fscore)
       print("Support" , support)

       p1 = precision[1]
       r1 = recall[1]
       f1 = fscore[1]

       f.write(str(p1) +','+ str(r1) + ',' + str(f1) + '\n') 
       it += 1

   f.close()

def run():
   filename = 'm3.csv'
   df = pd.read_csv(filename, usecols = [9,10,11,12,13,14] , header = 0)
   
   results = list(map(int, df['Anomaly'])) 
   print('Number of fraudulent transactions ' , sum(results))

   features = ['Airfare', 'Lodging', 'Meals', 'Other_Transportation', 'Other_Expenses']
   targets = ['Anomaly']

   # Separating out the features and target variables
   x = df.loc[:, features].values
   y = df.loc[:, targets].values
    
   scaler = preprocessing.StandardScaler()
   x = scaler.fit_transform(x)    

   y  = [i for j in y for i in j]
   
   #Ignore warnings
   warnings.filterwarnings("ignore", category=FutureWarning)

   print("***********Logistic Regression**********")
   logreg(x,y,filename)
  
run()
# Out:
# Number of fraudulent transactions  4097
# ***********Logistic Regression**********
# **************************************
# Iteration number   1
# Class weights  {0: 1, 1: 1}
# Performance on validation data - Confusion matrix
# [[79313     9]
#  [  268   346]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99663236 0.97464789]
# Recall [0.99988654 0.56351792]
# F-score [0.9982568  0.71413829]
# Support [79322   614]
# **************************************
# Iteration number   2
# Class weights  {0: 1, 1: 2}
# Performance on validation data - Confusion matrix
# [[79307    15]
#  [  218   396]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99725872 0.96350365]
# Recall [0.9998109  0.64495114]
# F-score [0.99853318 0.77268293]
# Support [79322   614]
# **************************************
# Iteration number   3
# Class weights  {0: 1, 1: 3}
# Performance on validation data - Confusion matrix
# [[79302    20]
#  [  194   420]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99755963 0.95454545]
# Recall [0.99974786 0.68403909]
# F-score [0.99865255 0.79696395]
# Support [79322   614]
# **************************************
# Iteration number   4
# Class weights  {0: 1, 1: 4}
# Performance on validation data - Confusion matrix
# [[79296    26]
#  [  172   442]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99783561 0.94444444]
# Recall [0.99967222 0.71986971]
# F-score [0.99875307 0.81700555]
# Support [79322   614]
# **************************************
# Iteration number   5
# Class weights  {0: 1, 1: 5}
# Performance on validation data - Confusion matrix
# [[79291    31]
#  [  155   459]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99804899 0.93673469]
# Recall [0.99960919 0.747557  ]
# F-score [0.99882848 0.83152174]
# Support [79322   614]
# **************************************
# Iteration number   6
# Class weights  {0: 1, 1: 6}
# Performance on validation data - Confusion matrix
# [[79291    31]
#  [  139   475]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99825003 0.93873518]
# Recall [0.99960919 0.77361564]
# F-score [0.99892915 0.84821429]
# Support [79322   614]
# **************************************
# Iteration number   7
# Class weights  {0: 1, 1: 7}
# Performance on validation data - Confusion matrix
# [[79292    30]
#  [  125   489]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99842603 0.94219653]
# Recall [0.99962179 0.79641694]
# F-score [0.99902355 0.86319506]
# Support [79322   614]
# **************************************
# Iteration number   8
# Class weights  {0: 1, 1: 8}
# Performance on validation data - Confusion matrix
# [[79288    34]
#  [  110   504]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99861457 0.93680297]
# Recall [0.99957137 0.82084691]
# F-score [0.99909274 0.875     ]
# Support [79322   614]
# **************************************
# Iteration number   9
# Class weights  {0: 1, 1: 9}
# Performance on validation data - Confusion matrix
# [[79284    38]
#  [  105   509]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9986774  0.93053016]
# Recall [0.99952094 0.82899023]
# F-score [0.99909899 0.87683032]
# Support [79322   614]
# **************************************
# Iteration number   10
# Class weights  {0: 1, 1: 10}
# Performance on validation data - Confusion matrix
# [[79280    42]
#  [   90   524]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99886607 0.92579505]
# Recall [0.99947051 0.8534202 ]
# F-score [0.9991682  0.88813559]
# Support [79322   614]
# **************************************
# Iteration number   11
# Class weights  {0: 1, 1: 11}
# Performance on validation data - Confusion matrix
# [[79272    50]
#  [   79   535]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99900442 0.91452991]
# Recall [0.99936966 0.8713355 ]
# F-score [0.99918701 0.89241034]
# Support [79322   614]
# **************************************
# Iteration number   12
# Class weights  {0: 1, 1: 12}
# Performance on validation data - Confusion matrix
# [[79268    54]
#  [   70   544]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991177 0.909699 ]
# Recall [0.99931923 0.88599349]
# F-score [0.99921845 0.89768977]
# Support [79322   614]
# **************************************
# Iteration number   13
# Class weights  {0: 1, 1: 13}
# Performance on validation data - Confusion matrix
# [[79260    62]
#  [   62   552]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99921838 0.8990228 ]
# Recall [0.99921838 0.8990228 ]
# F-score [0.99921838 0.8990228 ]
# Support [79322   614]
# **************************************
# Iteration number   14
# Class weights  {0: 1, 1: 14}
# Performance on validation data - Confusion matrix
# [[79255    67]
#  [   57   557]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99928132 0.89262821]
# Recall [0.99915534 0.90716612]
# F-score [0.99921833 0.89983845]
# Support [79322   614]
# **************************************
# Iteration number   15
# Class weights  {0: 1, 1: 15}
# Performance on validation data - Confusion matrix
# [[79247    75]
#  [   49   565]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99938206 0.8828125 ]
# Recall [0.99905449 0.92019544]
# F-score [0.99921825 0.90111643]
# Support [79322   614]
# **************************************
# Iteration number   16
# Class weights  {0: 1, 1: 16}
# /home/sandisk/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Performance on validation data - Confusion matrix
# [[78762   560]
#  [  175   439]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99778304 0.43943944]
# Recall [0.99294017 0.71498371]
# F-score [0.99535571 0.54432734]
# Support [79322   614]
# **************************************
# Iteration number   17
# Class weights  {0: 1, 1: 17}
# /home/sandisk/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Performance on validation data - Confusion matrix
# [[78762   560]
#  [  189   425]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99760611 0.43147208]
# Recall [0.99294017 0.69218241]
# F-score [0.99526767 0.53158224]
# Support [79322   614]
# **************************************
# Iteration number   18
# Class weights  {0: 1, 1: 18}
# Performance on validation data - Confusion matrix
# [[79200   122]
#  [   32   582]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99959612 0.82670455]
# Recall [0.99846197 0.94788274]
# F-score [0.99902872 0.8831563 ]
# Support [79322   614]
# **************************************
# Iteration number   19
# Class weights  {0: 1, 1: 19}
# /home/sandisk/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Performance on validation data - Confusion matrix
# [[78648   674]
#  [  180   434]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99771655 0.39169675]
# Recall [0.99150299 0.70684039]
# F-score [0.99460006 0.50406504]
# Support [79322   614]
# **************************************
# Iteration number   20
# Class weights  {0: 1, 1: 20}
# /home/sandisk/anaconda3/envs/tf-gpu/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Performance on validation data - Confusion matrix
# [[78622   700]
#  [  171   443]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99782976 0.38757655]
# Recall [0.99117521 0.72149837]
# F-score [0.99449135 0.50426864]
# Support [79322   614]
# **************************************
# Iteration number   21
# Class weights  {0: 1, 1: 21}
# Performance on validation data - Confusion matrix
# [[79104   218]
#  [   14   600]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99982305 0.73349633]
# Recall [0.99725171 0.9771987 ]
# F-score [0.99853572 0.83798883]
# Support [79322   614]
# **************************************
# Iteration number   22
# Class weights  {0: 1, 1: 22}
# Performance on validation data - Confusion matrix
# [[79029   293]
#  [    7   607]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99991143 0.67444444]
# Recall [0.9963062  0.98859935]
# F-score [0.99810556 0.80184941]
# Support [79322   614]
# **************************************
# Iteration number   23
# Class weights  {0: 1, 1: 23}
# Performance on validation data - Confusion matrix
# [[78911   411]
#  [    3   611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99996198 0.59784736]
# Recall [0.99481859 0.99511401]
# F-score [0.99738365 0.74694377]
# Support [79322   614]
# **************************************
# Iteration number   24
# Class weights  {0: 1, 1: 24}
# Performance on validation data - Confusion matrix
# [[78609   713]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.46269781]
# Recall [0.99101132 1.        ]
# F-score [0.99548537 0.63266358]
# Support [79322   614]
# **************************************
# Iteration number   25
# Class weights  {0: 1, 1: 25}
# Performance on validation data - Confusion matrix
# [[78533   789]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.43763364]
# Recall [0.9900532 1.       ]
# F-score [0.99500174 0.60882499]
# Support [79322   614]
# **************************************
# Iteration number   26
# Class weights  {0: 1, 1: 26}
# Performance on validation data - Confusion matrix
# [[78476   846]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.42054795]
# Recall [0.98933461 1.        ]
# F-score [0.99463872 0.59209257]
# Support [79322   614]
# **************************************
# Iteration number   27
# Class weights  {0: 1, 1: 27}
# Performance on validation data - Confusion matrix
# [[78430   892]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.40770252]
# Recall [0.9887547 1.       ]
# F-score [0.99434556 0.57924528]
# Support [79322   614]
# **************************************
# Iteration number   28
# Class weights  {0: 1, 1: 28}
# Performance on validation data - Confusion matrix
# [[78390   932]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.39715395]
# Recall [0.98825042 1.        ]
# F-score [0.99409049 0.56851852]
# Support [79322   614]
# **************************************
# Iteration number   29
# Class weights  {0: 1, 1: 29}
# Performance on validation data - Confusion matrix
# [[78349   973]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.38689351]
# Recall [0.98773354 1.        ]
# F-score [0.99382892 0.55792821]
# Support [79322   614]
# **************************************
# Iteration number   30
# Class weights  {0: 1, 1: 30}
# Performance on validation data - Confusion matrix
# [[78308  1014]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.37714988]
# Recall [0.98721666 1.        ]
# F-score [0.99356721 0.54772525]
# Support [79322   614]
# **************************************
# Iteration number   31
# Class weights  {0: 1, 1: 31}
# Performance on validation data - Confusion matrix
# [[78271  1051]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.36876877]
# Recall [0.98675021 1.        ]
# F-score [0.99333092 0.53883282]
# Support [79322   614]
# **************************************
# Iteration number   32
# Class weights  {0: 1, 1: 32}
# Performance on validation data - Confusion matrix
# [[78222  1100]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.35822637]
# Recall [0.98613247 1.        ]
# F-score [0.99301782 0.52749141]
# Support [79322   614]
# **************************************
# Iteration number   33
# Class weights  {0: 1, 1: 33}
# Performance on validation data - Confusion matrix
# [[78179  1143]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.34945931]
# Recall [0.98559038 1.        ]
# F-score [0.9927429  0.51792493]
# Support [79322   614]
# **************************************
# Iteration number   34
# Class weights  {0: 1, 1: 34}
# Performance on validation data - Confusion matrix
# [[78152  1170]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.3441704]
# Recall [0.98524999 1.        ]
# F-score [0.9925702  0.51209341]
# Support [79322   614]
# **************************************
# Iteration number   35
# Class weights  {0: 1, 1: 35}
# Performance on validation data - Confusion matrix
# [[78120  1202]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.33810573]
# Recall [0.98484657 1.        ]
# F-score [0.99236544 0.50534979]
# Support [79322   614]
# **************************************
# Iteration number   36
# Class weights  {0: 1, 1: 36}
# Performance on validation data - Confusion matrix
# [[78083  1239]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.33135456]
# Recall [0.98438012 1.        ]
# F-score [0.99212859 0.49777057]
# Support [79322   614]
# **************************************
# Iteration number   37
# Class weights  {0: 1, 1: 37}
# Performance on validation data - Confusion matrix
# [[78043  1279]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.32435288]
# Recall [0.98387585 1.        ]
# F-score [0.9918724  0.48982848]
# Support [79322   614]
# **************************************
# Iteration number   38
# Class weights  {0: 1, 1: 38}
# Performance on validation data - Confusion matrix
# [[78013  1309]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.31929277]
# Recall [0.98349764 1.        ]
# F-score [0.99168017 0.48403626]
# Support [79322   614]
# **************************************
# Iteration number   39
# Class weights  {0: 1, 1: 39}
# Performance on validation data - Confusion matrix
# [[77978  1344]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.31358529]
# Recall [0.9830564 1.       ]
# F-score [0.99145582 0.47744946]
# Support [79322   614]
# **************************************
# Iteration number   40
# Class weights  {0: 1, 1: 40}
# Performance on validation data - Confusion matrix
# [[77953  1369]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.30963187]
# Recall [0.98274123 1.        ]
# F-score [0.9912955  0.47285329]
# Support [79322   614]
# **************************************
# Iteration number   41
# Class weights  {0: 1, 1: 41}
# Performance on validation data - Confusion matrix
# [[77923  1399]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.30501739]
# Recall [0.98236303 1.        ]
# F-score [0.99110306 0.46745337]
# Support [79322   614]
# **************************************
# Iteration number   42
# Class weights  {0: 1, 1: 42}
# Performance on validation data - Confusion matrix
# [[77893  1429]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.30053842]
# Recall [0.98198482 1.        ]
# F-score [0.99091054 0.46217539]
# Support [79322   614]
# **************************************
# Iteration number   43
# Class weights  {0: 1, 1: 43}
# Performance on validation data - Confusion matrix
# [[77871  1451]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.29733656]
# Recall [0.98170747 1.        ]
# F-score [0.99076931 0.45837999]
# Support [79322   614]
# **************************************
# Iteration number   44
# Class weights  {0: 1, 1: 44}
# Performance on validation data - Confusion matrix
# [[77851  1471]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.29448441]
# Recall [0.98145533 1.        ]
# F-score [0.99064089 0.45498333]
# Support [79322   614]
# **************************************
# Iteration number   45
# Class weights  {0: 1, 1: 45}
# Performance on validation data - Confusion matrix
# [[77832  1490]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.2918251]
# Recall [0.9812158 1.       ]
# F-score [0.99051885 0.4518028 ]
# Support [79322   614]
# **************************************
# Iteration number   46
# Class weights  {0: 1, 1: 46}
# Performance on validation data - Confusion matrix
# [[77808  1514]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.28853383]
# Recall [0.98091324 1.        ]
# F-score [0.99036467 0.44784829]
# Support [79322   614]
# **************************************
# Iteration number   47
# Class weights  {0: 1, 1: 47}
# Performance on validation data - Confusion matrix
# [[77795  1527]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.28678188]
# Recall [0.98074935 1.        ]
# F-score [0.99028113 0.44573503]
# Support [79322   614]
# **************************************
# Iteration number   48
# Class weights  {0: 1, 1: 48}
# Performance on validation data - Confusion matrix
# [[77773  1549]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.       0.283865]
# Recall [0.980472 1.      ]
# F-score [0.99013972 0.44220382]
# Support [79322   614]
# **************************************
# Iteration number   49
# Class weights  {0: 1, 1: 49}
# Performance on validation data - Confusion matrix
# [[77747  1575]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.28049338]
# Recall [0.98014422 1.        ]
# F-score [0.98997256 0.43810203]
# Support [79322   614]
# **************************************
# Iteration number   50
# Class weights  {0: 1, 1: 50}
# Performance on validation data - Confusion matrix
# [[77729  1593]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.27820571]
# Recall [0.9799173 1.       ]
# F-score [0.9898568  0.43530663]
# Support [79322   614]
# **************************************
# Iteration number   51
# Class weights  {0: 1, 1: 51}
# Performance on validation data - Confusion matrix
# [[77716  1606]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.27657658]
# Recall [0.97975341 1.        ]
# F-score [0.98977318 0.43330981]
# Support [79322   614]
# **************************************
# Iteration number   52
# Class weights  {0: 1, 1: 52}
# Performance on validation data - Confusion matrix
# [[77692  1630]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.27361854]
# Recall [0.97945085 1.        ]
# F-score [0.98961876 0.4296711 ]
# Support [79322   614]
# **************************************
# Iteration number   53
# Class weights  {0: 1, 1: 53}
# Performance on validation data - Confusion matrix
# [[77673  1649]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.27132125]
# Recall [0.97921132 1.        ]
# F-score [0.98949648 0.42683351]
# Support [79322   614]
# **************************************
# Iteration number   54
# Class weights  {0: 1, 1: 54}
# Performance on validation data - Confusion matrix
# [[77659  1663]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.26965305]
# Recall [0.97903482 1.        ]
# F-score [0.98940636 0.42476652]
# Support [79322   614]
# **************************************
# Iteration number   55
# Class weights  {0: 1, 1: 55}
# Performance on validation data - Confusion matrix
# [[77639  1683]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.26730518]
# Recall [0.97878268 1.        ]
# F-score [0.98927759 0.42184816]
# Support [79322   614]
# **************************************
# Iteration number   56
# Class weights  {0: 1, 1: 56}
# Performance on validation data - Confusion matrix
# [[77624  1698]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.26557093]
# Recall [0.97859358 1.        ]
# F-score [0.98918099 0.41968558]
# Support [79322   614]
# **************************************
# Iteration number   57
# Class weights  {0: 1, 1: 57}
# Performance on validation data - Confusion matrix
# [[77596  1726]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.26239316]
# Recall [0.97824059 1.        ]
# F-score [0.98900062 0.41570752]
# Support [79322   614]
# **************************************
# Iteration number   58
# Class weights  {0: 1, 1: 58}
# Performance on validation data - Confusion matrix
# [[77581  1741]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.26072187]
# Recall [0.97805149 1.        ]
# F-score [0.98890397 0.41360728]
# Support [79322   614]
# **************************************
# Iteration number   59
# Class weights  {0: 1, 1: 59}
# Performance on validation data - Confusion matrix
# [[77554  1768]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.25776658]
# Recall [0.9777111 1.       ]
# F-score [0.98872995 0.40987984]
# Support [79322   614]
# **************************************
# Iteration number   60
# Class weights  {0: 1, 1: 60}
# Performance on validation data - Confusion matrix
# [[77529  1793]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.25508932]
# Recall [0.97739593 1.        ]
# F-score [0.98856877 0.40648792]
# Support [79322   614]
# **************************************
# Iteration number   61
# Class weights  {0: 1, 1: 61}
# Performance on validation data - Confusion matrix
# [[77511  1811]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.25319588]
# Recall [0.97716901 1.        ]
# F-score [0.98845269 0.40408029]
# Support [79322   614]
# **************************************
# Iteration number   62
# Class weights  {0: 1, 1: 62}
# Performance on validation data - Confusion matrix
# [[77498  1824]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.25184578]
# Recall [0.97700512 1.        ]
# F-score [0.98836883 0.40235911]
# Support [79322   614]
# **************************************
# Iteration number   63
# Class weights  {0: 1, 1: 63}
# Performance on validation data - Confusion matrix
# [[77467  1855]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.24868368]
# Recall [0.97661431 1.        ]
# F-score [0.98816881 0.39831333]
# Support [79322   614]
# **************************************
# Iteration number   64
# Class weights  {0: 1, 1: 64}
# Performance on validation data - Confusion matrix
# [[77439  1883]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.24589507]
# Recall [0.97626131 1.        ]
# F-score [0.98798808 0.39472838]
# Support [79322   614]
# **************************************
# Iteration number   65
# Class weights  {0: 1, 1: 65}
# Performance on validation data - Confusion matrix
# [[77426  1896]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.24462151]
# Recall [0.97609743 1.        ]
# F-score [0.98790415 0.39308579]
# Support [79322   614]
# **************************************
# Iteration number   66
# Class weights  {0: 1, 1: 66}
# Performance on validation data - Confusion matrix
# [[77402  1920]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.24230466]
# Recall [0.97579486 1.        ]
# F-score [0.98774916 0.39008895]
# Support [79322   614]
# **************************************
# Iteration number   67
# Class weights  {0: 1, 1: 67}
# Performance on validation data - Confusion matrix
# [[77380  1942]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.24021909]
# Recall [0.97551751 1.        ]
# F-score [0.98760705 0.3873817 ]
# Support [79322   614]
# **************************************
# Iteration number   68
# Class weights  {0: 1, 1: 68}
# Performance on validation data - Confusion matrix
# [[77366  1956]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.23891051]
# Recall [0.97534102 1.        ]
# F-score [0.98751659 0.38567839]
# Support [79322   614]
# **************************************
# Iteration number   69
# Class weights  {0: 1, 1: 69}
# Performance on validation data - Confusion matrix
# [[77345  1977]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.23697414]
# Recall [0.97507627 1.        ]
# F-score [0.98738088 0.38315133]
# Support [79322   614]
# **************************************
# Iteration number   70
# Class weights  {0: 1, 1: 70}
# Performance on validation data - Confusion matrix
# [[77330  1992]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.23561013]
# Recall [0.97488717 1.        ]
# F-score [0.98728392 0.38136646]
# Support [79322   614]
# **************************************
# Iteration number   71
# Class weights  {0: 1, 1: 71}
# Performance on validation data - Confusion matrix
# [[77313  2009]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.23408311]
# Recall [0.97467285 1.        ]
# F-score [0.987174   0.37936361]
# Support [79322   614]
# **************************************
# Iteration number   72
# Class weights  {0: 1, 1: 72}
# Performance on validation data - Confusion matrix
# [[77297  2025]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.23266389]
# Recall [0.97447114 1.        ]
# F-score [0.98707053 0.37749769]
# Support [79322   614]
# **************************************
# Iteration number   73
# Class weights  {0: 1, 1: 73}
# Performance on validation data - Confusion matrix
# [[77281  2041]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.23126177]
# Recall [0.97426943 1.        ]
# F-score [0.98696704 0.37565005]
# Support [79322   614]
# **************************************
# Iteration number   74
# Class weights  {0: 1, 1: 74}
# Performance on validation data - Confusion matrix
# [[77264  2058]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.22979042]
# Recall [0.97405512 1.        ]
# F-score [0.98685706 0.37370663]
# Support [79322   614]
# **************************************
# Iteration number   75
# Class weights  {0: 1, 1: 75}
# Performance on validation data - Confusion matrix
# [[77245  2077]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.22816797]
# Recall [0.97381559 1.        ]
# F-score [0.98673411 0.37155825]
# Support [79322   614]
# **************************************
# Iteration number   76
# Class weights  {0: 1, 1: 76}
# Performance on validation data - Confusion matrix
# [[77228  2094]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.2267356]
# Recall [0.97360127 1.        ]
# F-score [0.98662408 0.36965683]
# Support [79322   614]
# **************************************
# Iteration number   77
# Class weights  {0: 1, 1: 77}
# Performance on validation data - Confusion matrix
# [[77211  2111]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.2253211]
# Recall [0.97338695 1.        ]
# F-score [0.98651403 0.36777478]
# Support [79322   614]
# **************************************
# Iteration number   78
# Class weights  {0: 1, 1: 78}
# Performance on validation data - Confusion matrix
# [[77198  2124]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.22425128]
# Recall [0.97322307 1.        ]
# F-score [0.98642985 0.36634845]
# Support [79322   614]
# **************************************
# Iteration number   79
# Class weights  {0: 1, 1: 79}
# Performance on validation data - Confusion matrix
# [[77188  2134]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.22343523]
# Recall [0.973097 1.      ]
# F-score [0.98636509 0.36525877]
# Support [79322   614]
# **************************************
# Iteration number   80
# Class weights  {0: 1, 1: 80}
# Performance on validation data - Confusion matrix
# [[77172  2150]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.22214182]
# Recall [0.97289529 1.        ]
# F-score [0.98626145 0.36352872]
# Support [79322   614]
# **************************************
# Iteration number   81
# Class weights  {0: 1, 1: 81}
# Performance on validation data - Confusion matrix
# [[77160  2162]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.22118156]
# Recall [0.97274401 1.        ]
# F-score [0.98618371 0.36224189]
# Support [79322   614]
# **************************************
# Iteration number   82
# Class weights  {0: 1, 1: 82}
# Performance on validation data - Confusion matrix
# [[77145  2177]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21999283]
# Recall [0.9725549 1.       ]
# F-score [0.98608652 0.36064611]
# Support [79322   614]
# **************************************
# Iteration number   83
# Class weights  {0: 1, 1: 83}
# Performance on validation data - Confusion matrix
# [[77131  2191]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21889483]
# Recall [0.97237841 1.        ]
# F-score [0.98599579 0.35916935]
# Support [79322   614]
# **************************************
# Iteration number   84
# Class weights  {0: 1, 1: 84}
# Performance on validation data - Confusion matrix
# [[77122  2200]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21819474]
# Recall [0.97226495 1.        ]
# F-score [0.98593746 0.35822637]
# Support [79322   614]
# **************************************
# Iteration number   85
# Class weights  {0: 1, 1: 85}
# Performance on validation data - Confusion matrix
# [[77106  2216]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21696113]
# Recall [0.97206324 1.        ]
# F-score [0.98583374 0.35656214]
# Support [79322   614]
# **************************************
# Iteration number   86
# Class weights  {0: 1, 1: 86}
# Performance on validation data - Confusion matrix
# [[77087  2235]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21551422]
# Recall [0.97182371 1.        ]
# F-score [0.98571054 0.35460583]
# Support [79322   614]
# **************************************
# Iteration number   87
# Class weights  {0: 1, 1: 87}
# Performance on validation data - Confusion matrix
# [[77076  2246]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21468531]
# Recall [0.97168503 1.        ]
# F-score [0.9856392  0.35348302]
# Support [79322   614]
# **************************************
# Iteration number   88
# Class weights  {0: 1, 1: 88}
# Performance on validation data - Confusion matrix
# [[77061  2261]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21356522]
# Recall [0.97149593 1.        ]
# F-score [0.98554191 0.35196331]
# Support [79322   614]
# **************************************
# Iteration number   89
# Class weights  {0: 1, 1: 89}
# Performance on validation data - Confusion matrix
# [[77041  2281]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21208981]
# Recall [0.97124379 1.        ]
# F-score [0.98541215 0.34995725]
# Support [79322   614]
# **************************************
# Iteration number   90
# Class weights  {0: 1, 1: 90}
# Performance on validation data - Confusion matrix
# [[77024  2298]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21085165]
# Recall [0.97102947 1.        ]
# F-score [0.98530183 0.34826999]
# Support [79322   614]
# **************************************
# Iteration number   91
# Class weights  {0: 1, 1: 91}
# Performance on validation data - Confusion matrix
# [[77014  2308]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.21013005]
# Recall [0.97090341 1.        ]
# F-score [0.98523693 0.34728507]
# Support [79322   614]
# **************************************
# Iteration number   92
# Class weights  {0: 1, 1: 92}
# Performance on validation data - Confusion matrix
# [[76999  2323]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20905686]
# Recall [0.9707143 1.       ]
# F-score [0.98513955 0.34581808]
# Support [79322   614]
# **************************************
# Iteration number   93
# Class weights  {0: 1, 1: 93}
# Performance on validation data - Confusion matrix
# [[76984  2338]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20799458]
# Recall [0.9705252 1.       ]
# F-score [0.98504216 0.34436343]
# Support [79322   614]
# **************************************
# Iteration number   94
# Class weights  {0: 1, 1: 94}
# Performance on validation data - Confusion matrix
# [[76971  2351]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20708263]
# Recall [0.97036131 1.        ]
# F-score [0.98495774 0.3431126 ]
# Support [79322   614]
# **************************************
# Iteration number   95
# Class weights  {0: 1, 1: 95}
# Performance on validation data - Confusion matrix
# [[76960  2362]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.2063172]
# Recall [0.97022264 1.        ]
# F-score [0.9848863  0.34206128]
# Support [79322   614]
# **************************************
# Iteration number   96
# Class weights  {0: 1, 1: 96}
# Performance on validation data - Confusion matrix
# [[76952  2370]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20576408]
# Recall [0.97012178 1.        ]
# F-score [0.98483433 0.34130072]
# Support [79322   614]
# **************************************
# Iteration number   97
# Class weights  {0: 1, 1: 97}
# Performance on validation data - Confusion matrix
# [[76936  2386]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20466667]
# Recall [0.96992007 1.        ]
# F-score [0.98473038 0.33978971]
# Support [79322   614]
# **************************************
# Iteration number   98
# Class weights  {0: 1, 1: 98}
# Performance on validation data - Confusion matrix
# [[76925  2397]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20391896]
# Recall [0.9697814 1.       ]
# F-score [0.98465891 0.33875862]
# Support [79322   614]
# **************************************
# Iteration number   99
# Class weights  {0: 1, 1: 99}
# Performance on validation data - Confusion matrix
# [[76916  2406]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20331126]
# Recall [0.96966794 1.        ]
# F-score [0.98460042 0.33791965]
# Support [79322   614]
# **************************************
# Iteration number   100
# Class weights  {0: 1, 1: 100}
# Performance on validation data - Confusion matrix
# [[76903  2419]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20243983]
# Recall [0.96950405 1.        ]
# F-score [0.98451592 0.33671511]
# Support [79322   614]
# **************************************
# Iteration number   101
# Class weights  {0: 1, 1: 101}
# Performance on validation data - Confusion matrix
# [[76888  2434]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20144357]
# Recall [0.96931494 1.        ]
# F-score [0.98441841 0.33533588]
# Support [79322   614]
# **************************************
# Iteration number   102
# Class weights  {0: 1, 1: 102}
# Performance on validation data - Confusion matrix
# [[76875  2447]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.20058804]
# Recall [0.96915106 1.        ]
# F-score [0.98433389 0.33414966]
# Support [79322   614]
# **************************************
# Iteration number   103
# Class weights  {0: 1, 1: 103}
# Performance on validation data - Confusion matrix
# [[76865  2457]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19993487]
# Recall [0.96902499 1.        ]
# F-score [0.98426886 0.33324288]
# Support [79322   614]
# **************************************
# Iteration number   104
# Class weights  {0: 1, 1: 104}
# Performance on validation data - Confusion matrix
# [[76854  2468]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19922128]
# Recall [0.96888631 1.        ]
# F-score [0.98419732 0.33225108]
# Support [79322   614]
# **************************************
# Iteration number   105
# Class weights  {0: 1, 1: 105}
# Performance on validation data - Confusion matrix
# [[76841  2481]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19838449]
# Recall [0.96872242 1.        ]
# F-score [0.98411275 0.33108655]
# Support [79322   614]
# **************************************
# Iteration number   106
# Class weights  {0: 1, 1: 106}
# Performance on validation data - Confusion matrix
# [[76832  2490]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19780928]
# Recall [0.96860896 1.        ]
# F-score [0.9840542 0.3302851]
# Support [79322   614]
# **************************************
# Iteration number   107
# Class weights  {0: 1, 1: 107}
# Performance on validation data - Confusion matrix
# [[76818  2504]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.1969211]
# Recall [0.96843247 1.        ]
# F-score [0.98396311 0.32904609]
# Support [79322   614]
# **************************************
# Iteration number   108
# Class weights  {0: 1, 1: 108}
# Performance on validation data - Confusion matrix
# [[76803  2519]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.1959783]
# Recall [0.96824336 1.        ]
# F-score [0.98386549 0.32772885]
# Support [79322   614]
# **************************************
# Iteration number   109
# Class weights  {0: 1, 1: 109}
# Performance on validation data - Confusion matrix
# [[76787  2535]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19498253]
# Recall [0.96804165 1.        ]
# F-score [0.98376135 0.32633537]
# Support [79322   614]
# **************************************
# Iteration number   110
# Class weights  {0: 1, 1: 110}
# Performance on validation data - Confusion matrix
# [[76773  2549]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19411951]
# Recall [0.96786516 1.        ]
# F-score [0.9836702  0.32512576]
# Support [79322   614]
# **************************************
# Iteration number   111
# Class weights  {0: 1, 1: 111}
# Performance on validation data - Confusion matrix
# [[76761  2561]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19338583]
# Recall [0.96771388 1.        ]
# F-score [0.98359206 0.32409607]
# Support [79322   614]
# **************************************
# Iteration number   112
# Class weights  {0: 1, 1: 112}
# Performance on validation data - Confusion matrix
# [[76752  2570]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.1928392]
# Recall [0.96760041 1.        ]
# F-score [0.98353345 0.32332807]
# Support [79322   614]
# **************************************
# Iteration number   113
# Class weights  {0: 1, 1: 113}
# Performance on validation data - Confusion matrix
# [[76740  2582]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19211514]
# Recall [0.96744913 1.        ]
# F-score [0.98345529 0.32230971]
# Support [79322   614]
# **************************************
# Iteration number   114
# Class weights  {0: 1, 1: 114}
# Performance on validation data - Confusion matrix
# [[76724  2598]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19115816]
# Recall [0.96724742 1.        ]
# F-score [0.98335106 0.32096184]
# Support [79322   614]
# **************************************
# Iteration number   115
# Class weights  {0: 1, 1: 115}
# Performance on validation data - Confusion matrix
# [[76710  2612]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.19032858]
# Recall [0.96707093 1.        ]
# F-score [0.98325984 0.31979167]
# Support [79322   614]
# **************************************
# Iteration number   116
# Class weights  {0: 1, 1: 116}
# Performance on validation data - Confusion matrix
# [[76698  2624]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18962322]
# Recall [0.96691964 1.        ]
# F-score [0.98318164 0.31879543]
# Support [79322   614]
# **************************************
# Iteration number   117
# Class weights  {0: 1, 1: 117}
# Performance on validation data - Confusion matrix
# [[76680  2642]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18857494]
# Recall [0.96669272 1.        ]
# F-score [0.98306432 0.31731266]
# Support [79322   614]
# **************************************
# Iteration number   118
# Class weights  {0: 1, 1: 118}
# Performance on validation data - Confusion matrix
# [[76671  2651]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18805513]
# Recall [0.96657926 1.        ]
# F-score [0.98300565 0.31657644]
# Support [79322   614]
# **************************************
# Iteration number   119
# Class weights  {0: 1, 1: 119}
# Performance on validation data - Confusion matrix
# [[76664  2658]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18765281]
# Recall [0.96649101 1.        ]
# F-score [0.98296001 0.31600618]
# Support [79322   614]
# **************************************
# Iteration number   120
# Class weights  {0: 1, 1: 120}
# Performance on validation data - Confusion matrix
# [[76647  2675]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18668288]
# Recall [0.96627669 1.        ]
# F-score [0.98284916 0.31462977]
# Support [79322   614]
# **************************************
# Iteration number   121
# Class weights  {0: 1, 1: 121}
# Performance on validation data - Confusion matrix
# [[76632  2690]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18583535]
# Recall [0.96608759 1.        ]
# F-score [0.98275132 0.31342522]
# Support [79322   614]
# **************************************
# Iteration number   122
# Class weights  {0: 1, 1: 122}
# Performance on validation data - Confusion matrix
# [[76622  2700]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18527459]
# Recall [0.96596152 1.        ]
# F-score [0.98268609 0.31262729]
# Support [79322   614]
# **************************************
# Iteration number   123
# Class weights  {0: 1, 1: 123}
# Performance on validation data - Confusion matrix
# [[76609  2713]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18455065]
# Recall [0.96579763 1.        ]
# F-score [0.98260128 0.31159604]
# Support [79322   614]
# **************************************
# Iteration number   124
# Class weights  {0: 1, 1: 124}
# Performance on validation data - Confusion matrix
# [[76595  2727]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18377731]
# Recall [0.96562114 1.        ]
# F-score [0.98250993 0.31049305]
# Support [79322   614]
# **************************************
# Iteration number   125
# Class weights  {0: 1, 1: 125}
# Performance on validation data - Confusion matrix
# [[76586  2736]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18328358]
# Recall [0.96550768 1.        ]
# F-score [0.98245119 0.30978809]
# Support [79322   614]
# **************************************
# Iteration number   126
# Class weights  {0: 1, 1: 126}
# Performance on validation data - Confusion matrix
# [[76572  2750]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18252081]
# Recall [0.96533118 1.        ]
# F-score [0.98235981 0.30869784]
# Support [79322   614]
# **************************************
# Iteration number   127
# Class weights  {0: 1, 1: 127}
# Performance on validation data - Confusion matrix
# [[76561  2761]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18192593]
# Recall [0.96519251 1.        ]
# F-score [0.982288   0.30784658]
# Support [79322   614]
# **************************************
# Iteration number   128
# Class weights  {0: 1, 1: 128}
# Performance on validation data - Confusion matrix
# [[76552  2770]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18144208]
# Recall [0.96507904 1.        ]
# F-score [0.98222924 0.30715358]
# Support [79322   614]
# **************************************
# Iteration number   129
# Class weights  {0: 1, 1: 129}
# Performance on validation data - Confusion matrix
# [[76537  2785]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18064137]
# Recall [0.96488994 1.        ]
# F-score [0.98213129 0.30600548]
# Support [79322   614]
# **************************************
# Iteration number   130
# Class weights  {0: 1, 1: 130}
# Performance on validation data - Confusion matrix
# [[76527  2795]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.18011147]
# Recall [0.96476387 1.        ]
# F-score [0.98206597 0.30524484]
# Support [79322   614]
# **************************************
# Iteration number   131
# Class weights  {0: 1, 1: 131}
# Performance on validation data - Confusion matrix
# [[76513  2809]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.17937482]
# Recall [0.96458738 1.        ]
# F-score [0.98197452 0.30418628]
# Support [79322   614]
# **************************************
# Iteration number   132
# Class weights  {0: 1, 1: 132}
# Performance on validation data - Confusion matrix
# [[76501  2821]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.17874818]
# Recall [0.9644361 1.       ]
# F-score [0.98189613 0.30328476]
# Support [79322   614]
# **************************************
# Iteration number   133
# Class weights  {0: 1, 1: 133}
# Performance on validation data - Confusion matrix
# [[76493  2829]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.17833285]
# Recall [0.96433524 1.        ]
# F-score [0.98184385 0.30268671]
# Support [79322   614]
# **************************************
# Iteration number   134
# Class weights  {0: 1, 1: 134}
# Performance on validation data - Confusion matrix
# [[76481  2841]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.17771346]
# Recall [0.96418396 1.        ]
# F-score [0.98176543 0.30179405]
# Support [79322   614]
# **************************************
# Iteration number   135
# Class weights  {0: 1, 1: 135}
# Performance on validation data - Confusion matrix
# [[76474  2848]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.17735413]
# Recall [0.96409571 1.        ]
# F-score [0.98171968 0.30127576]
# Support [79322   614]
# **************************************
# Iteration number   136
# Class weights  {0: 1, 1: 136}
# Performance on validation data - Confusion matrix
# [[76459  2863]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.17658901]
# Recall [0.96390661 1.        ]
# ...
# **************************************
# Iteration number   455
# Class weights  {0: 1, 1: 455}
# Performance on validation data - Confusion matrix
# [[73769  5553]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09956219]
# Recall [0.9299942 1.       ]
# F-score [0.96372746 0.18109423]
# Support [79322   614]
# **************************************
# Iteration number   456
# Class weights  {0: 1, 1: 456}
# Performance on validation data - Confusion matrix
# [[73764  5558]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09948153]
# Recall [0.92993117 1.        ]
# F-score [0.96369361 0.1809608 ]
# Support [79322   614]
# **************************************
# Iteration number   457
# Class weights  {0: 1, 1: 457}
# Performance on validation data - Confusion matrix
# [[73759  5563]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.       0.099401]
# Recall [0.92986813 1.        ]
# F-score [0.96365976 0.18082757]
# Support [79322   614]
# **************************************
# Iteration number   458
# Class weights  {0: 1, 1: 458}
# Performance on validation data - Confusion matrix
# [[73752  5570]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09928849]
# Recall [0.92977988 1.        ]
# F-score [0.96361237 0.18064137]
# Support [79322   614]
# **************************************
# Iteration number   459
# Class weights  {0: 1, 1: 459}
# Performance on validation data - Confusion matrix
# [[73748  5574]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09922431]
# Recall [0.92972946 1.        ]
# F-score [0.96358529 0.18053514]
# Support [79322   614]
# **************************************
# Iteration number   460
# Class weights  {0: 1, 1: 460}
# Performance on validation data - Confusion matrix
# [[73741  5581]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09911219]
# Recall [0.92964121 1.        ]
# F-score [0.96353789 0.18034954]
# Support [79322   614]
# **************************************
# Iteration number   461
# Class weights  {0: 1, 1: 461}
# Performance on validation data - Confusion matrix
# [[73737  5585]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09904823]
# Recall [0.92959078 1.        ]
# F-score [0.9635108  0.18024365]
# Support [79322   614]
# **************************************
# Iteration number   462
# Class weights  {0: 1, 1: 462}
# Performance on validation data - Confusion matrix
# [[73729  5593]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09892057]
# Recall [0.92948993 1.        ]
# F-score [0.96345663 0.18003225]
# Support [79322   614]
# **************************************
# Iteration number   463
# Class weights  {0: 1, 1: 463}
# Performance on validation data - Confusion matrix
# [[73721  5601]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09879324]
# Recall [0.92938907 1.        ]
# F-score [0.96340244 0.17982135]
# Support [79322   614]
# **************************************
# Iteration number   464
# Class weights  {0: 1, 1: 464}
# Performance on validation data - Confusion matrix
# [[73716  5606]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09871383]
# Recall [0.92932604 1.        ]
# F-score [0.96336858 0.17968979]
# Support [79322   614]
# **************************************
# Iteration number   465
# Class weights  {0: 1, 1: 465}
# Performance on validation data - Confusion matrix
# [[73707  5615]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.0985712]
# Recall [0.92921258 1.        ]
# F-score [0.96330761 0.17945346]
# Support [79322   614]
# **************************************
# Iteration number   466
# Class weights  {0: 1, 1: 466}
# Performance on validation data - Confusion matrix
# [[73703  5619]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09850794]
# Recall [0.92916215 1.        ]
# F-score [0.96328051 0.17934862]
# Support [79322   614]
# **************************************
# Iteration number   467
# Class weights  {0: 1, 1: 467}
# Performance on validation data - Confusion matrix
# [[73698  5624]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09842898]
# Recall [0.92909911 1.        ]
# F-score [0.96324663 0.17921775]
# Support [79322   614]
# **************************************
# Iteration number   468
# Class weights  {0: 1, 1: 468}
# Performance on validation data - Confusion matrix
# [[73694  5628]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09836591]
# Recall [0.92904869 1.        ]
# F-score [0.96321953 0.17911319]
# Support [79322   614]
# **************************************
# Iteration number   469
# Class weights  {0: 1, 1: 469}
# Performance on validation data - Confusion matrix
# [[73688  5634]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09827145]
# Recall [0.92897305 1.        ]
# F-score [0.96317888 0.17895657]
# Support [79322   614]
# **************************************
# Iteration number   470
# Class weights  {0: 1, 1: 470}
# Performance on validation data - Confusion matrix
# [[73682  5640]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09817717]
# Recall [0.92889741 1.        ]
# F-score [0.96313822 0.17880023]
# Support [79322   614]
# **************************************
# Iteration number   471
# Class weights  {0: 1, 1: 471}
# Performance on validation data - Confusion matrix
# [[73673  5649]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09803608]
# Recall [0.92878394 1.        ]
# F-score [0.96307722 0.17856624]
# Support [79322   614]
# **************************************
# Iteration number   472
# Class weights  {0: 1, 1: 472}
# Performance on validation data - Confusion matrix
# [[73669  5653]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09797351]
# Recall [0.92873352 1.        ]
# F-score [0.96305011 0.17846243]
# Support [79322   614]
# **************************************
# Iteration number   473
# Class weights  {0: 1, 1: 473}
# Performance on validation data - Confusion matrix
# [[73666  5656]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09792663]
# Recall [0.9286957 1.       ]
# F-score [0.96302978 0.17838466]
# Support [79322   614]
# **************************************
# Iteration number   474
# Class weights  {0: 1, 1: 474}
# Performance on validation data - Confusion matrix
# [[73662  5660]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.0978642]
# Recall [0.92864527 1.        ]
# F-score [0.96300267 0.17828107]
# Support [79322   614]
# **************************************
# Iteration number   475
# Class weights  {0: 1, 1: 475}
# Performance on validation data - Confusion matrix
# [[73651  5671]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09769292]
# Recall [0.92850659 1.        ]
# F-score [0.9629281  0.17799681]
# Support [79322   614]
# **************************************
# Iteration number   476
# Class weights  {0: 1, 1: 476}
# Performance on validation data - Confusion matrix
# [[73647  5675]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09763078]
# Recall [0.92845617 1.        ]
# F-score [0.96290098 0.17789367]
# Support [79322   614]
# **************************************
# Iteration number   477
# Class weights  {0: 1, 1: 477}
# Performance on validation data - Confusion matrix
# [[73635  5687]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09744485]
# Recall [0.92830488 1.        ]
# F-score [0.96281962 0.17758496]
# Support [79322   614]
# **************************************
# Iteration number   478
# Class weights  {0: 1, 1: 478}
# Performance on validation data - Confusion matrix
# [[73629  5693]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09735215]
# Recall [0.92822924 1.        ]
# F-score [0.96277893 0.17743101]
# Support [79322   614]
# **************************************
# Iteration number   479
# Class weights  {0: 1, 1: 479}
# Performance on validation data - Confusion matrix
# [[73622  5700]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09724422]
# Recall [0.92814099 1.        ]
# F-score [0.96273146 0.17725173]
# Support [79322   614]
# **************************************
# Iteration number   480
# Class weights  {0: 1, 1: 480}
# Performance on validation data - Confusion matrix
# [[73617  5705]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09716727]
# Recall [0.92807796 1.        ]
# F-score [0.96269755 0.1771239 ]
# Support [79322   614]
# **************************************
# Iteration number   481
# Class weights  {0: 1, 1: 481}
# Performance on validation data - Confusion matrix
# [[73612  5710]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09709045]
# Recall [0.92801493 1.        ]
# F-score [0.96266363 0.17699625]
# Support [79322   614]
# **************************************
# Iteration number   482
# Class weights  {0: 1, 1: 482}
# Performance on validation data - Confusion matrix
# [[73604  5718]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09696778]
# Recall [0.92791407 1.        ]
# F-score [0.96260937 0.1767924 ]
# Support [79322   614]
# **************************************
# Iteration number   483
# Class weights  {0: 1, 1: 483}
# Performance on validation data - Confusion matrix
# [[73596  5726]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09684543]
# Recall [0.92781322 1.        ]
# F-score [0.96255509 0.17658901]
# Support [79322   614]
# **************************************
# Iteration number   484
# Class weights  {0: 1, 1: 484}
# Performance on validation data - Confusion matrix
# [[73584  5738]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09666247]
# Recall [0.92766193 1.        ]
# F-score [0.96247368 0.17628481]
# Support [79322   614]
# **************************************
# Iteration number   485
# Class weights  {0: 1, 1: 485}
# Performance on validation data - Confusion matrix
# [[73586  5736]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09669291]
# Recall [0.92768715 1.        ]
# F-score [0.96248725 0.17633544]
# Support [79322   614]
# **************************************
# Iteration number   486
# Class weights  {0: 1, 1: 486}
# Performance on validation data - Confusion matrix
# [[73575  5747]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.0965257]
# Recall [0.92754847 1.        ]
# F-score [0.9624126  0.17605735]
# Support [79322   614]
# **************************************
# Iteration number   487
# Class weights  {0: 1, 1: 487}
# Performance on validation data - Confusion matrix
# [[73561  5761]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09631373]
# Recall [0.92737198 1.        ]
# F-score [0.96231759 0.17570468]
# Support [79322   614]
# **************************************
# Iteration number   488
# Class weights  {0: 1, 1: 488}
# Performance on validation data - Confusion matrix
# [[73558  5764]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09626842]
# Recall [0.92733416 1.        ]
# F-score [0.96229723 0.17562929]
# Support [79322   614]
# **************************************
# Iteration number   489
# Class weights  {0: 1, 1: 489}
# Performance on validation data - Confusion matrix
# [[73549  5773]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09613277]
# Recall [0.9272207 1.       ]
# F-score [0.96223613 0.17540351]
# Support [79322   614]
# **************************************
# Iteration number   490
# Class weights  {0: 1, 1: 490}
# Performance on validation data - Confusion matrix
# [[73539  5783]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09598249]
# Recall [0.92709463 1.        ]
# F-score [0.96216824 0.17515333]
# Support [79322   614]
# **************************************
# Iteration number   491
# Class weights  {0: 1, 1: 491}
# Performance on validation data - Confusion matrix
# [[73530  5792]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09584764]
# Recall [0.92698117 1.        ]
# F-score [0.96210714 0.17492877]
# Support [79322   614]
# **************************************
# Iteration number   492
# Class weights  {0: 1, 1: 492}
# Performance on validation data - Confusion matrix
# [[73523  5799]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09574302]
# Recall [0.92689292 1.        ]
# F-score [0.9620596  0.17475452]
# Support [79322   614]
# **************************************
# Iteration number   493
# Class weights  {0: 1, 1: 493}
# Performance on validation data - Confusion matrix
# [[73519  5803]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09568334]
# Recall [0.92684249 1.        ]
# F-score [0.96203244 0.1746551 ]
# Support [79322   614]
# **************************************
# Iteration number   494
# Class weights  {0: 1, 1: 494}
# Performance on validation data - Confusion matrix
# [[73508  5814]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.0955196]
# Recall [0.92670381 1.        ]
# F-score [0.96195773 0.17438228]
# Support [79322   614]
# **************************************
# Iteration number   495
# Class weights  {0: 1, 1: 495}
# Performance on validation data - Confusion matrix
# [[73501  5821]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.0954157]
# Recall [0.92661557 1.        ]
# F-score [0.96191018 0.17420911]
# Support [79322   614]
# **************************************
# Iteration number   496
# Class weights  {0: 1, 1: 496}
# Performance on validation data - Confusion matrix
# [[73498  5824]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09537123]
# Recall [0.92657775 1.        ]
# F-score [0.9618898 0.174135 ]
# Support [79322   614]
# **************************************
# Iteration number   497
# Class weights  {0: 1, 1: 497}
# Performance on validation data - Confusion matrix
# [[73495  5827]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09532681]
# Recall [0.92653993 1.        ]
# F-score [0.96186943 0.17406095]
# Support [79322   614]
# **************************************
# Iteration number   498
# Class weights  {0: 1, 1: 498}
# Performance on validation data - Confusion matrix
# [[73489  5833]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.        0.0952381]
# Recall [0.92646428 1.        ]
# F-score [0.96182866 0.17391304]
# Support [79322   614]
# **************************************
# Iteration number   499
# Class weights  {0: 1, 1: 499}
# Performance on validation data - Confusion matrix
# [[73480  5842]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09510533]
# Recall [0.92635082 1.        ]
# F-score [0.96176752 0.17369165]
# Support [79322   614]
# **************************************
# Iteration number   500
# Class weights  {0: 1, 1: 500}
# Performance on validation data - Confusion matrix
# [[73475  5847]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.09503173]
# Recall [0.92628779 1.        ]
# F-score [0.96173354 0.1735689 ]
# Support [79322   614]
