# %%
import numpy as np
import pandas as pd
import csv
import sys
import os

import matplotlib.pyplot as plt    
    
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
import warnings
import pickle

max_iters = 101


def svm(x,y,filename):

   # Model output file name
   file = (os.path.splitext(filename))[0]
   fname = './models/svm_' + file +'/'

   # File for writing precision,recall, f-measure scores for fraud transactions
   f = open('./prf/svm_'+ file + '_prf' +'.txt' ,'w')
   f.write('precision,recall,f-score \n')

   # Stratified sampling based on Y
   X_train, X_test, y_train, y_test = train_test_split(x, y,stratify=y , test_size=0.30, random_state=42)

   # Create 15% validation set and 15% test set split
   X_val, X_test, y_val, y_test = train_test_split(X_test, y_test,stratify=y_test , test_size=0.50, random_state=42)

   #Iterations
   it = 1
   
   # Run training algorithm for multiple class weights
   while it < max_iters:
       cw = {}
       cw[0] = 1
       cw[1] = it
       # Train
       print('**************************************')
       print("Iteration number  " , it)
       svm = LinearSVC(class_weight = cw, dual = False ,tol=1e-05,max_iter = 1000)
       print('Class weights ', cw)
       svm.fit(X_train,y_train)

       # Save trained model to disk
       name = fname + str(cw[1]) + '.sav'
       pickle.dump(svm, open(name, 'wb'))

       #Predict on validation data
       y_val_pred = svm.predict(X_val)
       print('Performance on validation data - Confusion matrix')
       print(confusion_matrix(y_val,y_val_pred))
   
       precision,recall,fscore,support=score(y_val,y_val_pred,average=None)
       print('Precision, Recall, F-score, Support on validation data' )
       print("Precision" , precision)
       print("Recall" , recall)
       print("F-score" , fscore)
       print("Support" , support)

       p1 = precision[1]
       r1 = recall[1]
       f1 = fscore[1]

       f.write(str(p1) +','+ str(r1) + ',' + str(f1) + '\n')    
       it += 1

   f.close()

def run():
   filename = 'm2.csv'
   df = pd.read_csv(filename, usecols = [9,10,11,12,13,14] , header = 0)
   
   results = list(map(int, df['Anomaly'])) 
   print('Number of fraudulent transactions ' , sum(results))

   features = ['Airfare', 'Lodging', 'Meals', 'Other_Transportation', 'Other_Expenses']
   targets = ['Anomaly']

   # Separating out the features and target variables
   x = df.loc[:, features].values
   y = df.loc[:, targets].values

   y  = [i for j in y for i in j]
   
   #Ignore warnings
   warnings.filterwarnings("ignore", category=FutureWarning)

   print("**************** SVM *******************")
   svm(x,y,filename)
  
run()
# Out:
# Number of fraudulent transactions  4116
# **************** SVM *******************
# **************************************
# Iteration number   1
# Class weights  {0: 1, 1: 1}
# Performance on validation data - Confusion matrix
# [[334937     70]
#  [   132    486]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99960605 0.87410072]
# Recall [0.99979105 0.78640777]
# F-score [0.99969854 0.82793867]
# Support [335007    618]
# **************************************
# Iteration number   2
# Class weights  {0: 1, 1: 2}
# Performance on validation data - Confusion matrix
# [[334853    154]
#  [   101    517]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99969847 0.7704918 ]
# Recall [0.99954031 0.83656958]
# F-score [0.99961938 0.80217223]
# Support [335007    618]
# **************************************
# Iteration number   3
# Class weights  {0: 1, 1: 3}
# Performance on validation data - Confusion matrix
# [[334768    239]
#  [    82    536]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99975511 0.6916129 ]
# Recall [0.99928658 0.86731392]
# F-score [0.99952079 0.7695621 ]
# Support [335007    618]
# **************************************
# Iteration number   4
# Class weights  {0: 1, 1: 4}
# Performance on validation data - Confusion matrix
# [[334720    287]
#  [    75    543]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99977598 0.65421687]
# Recall [0.9991433  0.87864078]
# F-score [0.99945954 0.75      ]
# Support [335007    618]
# **************************************
# Iteration number   5
# Class weights  {0: 1, 1: 5}
# Performance on validation data - Confusion matrix
# [[334642    365]
#  [    66    552]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99980281 0.60196292]
# Recall [0.99891047 0.89320388]
# F-score [0.99935644 0.71921824]
# Support [335007    618]
# **************************************
# Iteration number   6
# Class weights  {0: 1, 1: 6}
# Performance on validation data - Confusion matrix
# [[334579    428]
#  [    65    553]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99980576 0.5637105 ]
# Recall [0.99872241 0.89482201]
# F-score [0.9992638 0.6916823]
# Support [335007    618]
# **************************************
# Iteration number   7
# Class weights  {0: 1, 1: 7}
# Performance on validation data - Confusion matrix
# [[334488    519]
#  [    59    559]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99982364 0.51855288]
# Recall [0.99845078 0.90453074]
# F-score [0.99913674 0.65919811]
# Support [335007    618]
# **************************************
# Iteration number   8
# Class weights  {0: 1, 1: 8}
# Performance on validation data - Confusion matrix
# [[334844    163]
#  [   260    358]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99922412 0.68714012]
# Recall [0.99951344 0.57928803]
# F-score [0.99936876 0.6286216 ]
# Support [335007    618]
# **************************************
# Iteration number   9
# Class weights  {0: 1, 1: 9}
# Performance on validation data - Confusion matrix
# [[334359    648]
#  [    52    566]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9998445  0.46622735]
# Recall [0.99806571 0.91585761]
# F-score [0.99895432 0.61790393]
# Support [335007    618]
# **************************************
# Iteration number   10
# Class weights  {0: 1, 1: 10}
# Performance on validation data - Confusion matrix
# [[334461    546]
#  [    75    543]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99977581 0.49862259]
# Recall [0.99837018 0.87864078]
# F-score [0.9990725  0.63620387]
# Support [335007    618]
# **************************************
# Iteration number   11
# Class weights  {0: 1, 1: 11}
# Performance on validation data - Confusion matrix
# [[334558    449]
#  [   122    496]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99963547 0.52486772]
# Recall [0.99865973 0.802589  ]
# F-score [0.99914736 0.6346769 ]
# Support [335007    618]
# **************************************
# Iteration number   12
# Class weights  {0: 1, 1: 12}
# Performance on validation data - Confusion matrix
# [[334143    864]
#  [    45    573]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99986535 0.39874739]
# Recall [0.99742095 0.92718447]
# F-score [0.99864165 0.55766423]
# Support [335007    618]
# **************************************
# Iteration number   13
# Class weights  {0: 1, 1: 13}
# Performance on validation data - Confusion matrix
# [[334152    855]
#  [    50    568]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99985039 0.39915671]
# Recall [0.99744781 0.91909385]
# F-score [0.99864766 0.55658991]
# Support [335007    618]
# **************************************
# Iteration number   14
# Class weights  {0: 1, 1: 14}
# Performance on validation data - Confusion matrix
# [[334672    335]
#  [   223    395]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99933412 0.54109589]
# Recall [0.99900002 0.63915858]
# F-score [0.99916704 0.58605341]
# Support [335007    618]
# **************************************
# Iteration number   15
# Class weights  {0: 1, 1: 15}
# Performance on validation data - Confusion matrix
# [[334282    725]
#  [    76    542]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9997727  0.42778216]
# Recall [0.99783587 0.87702265]
# F-score [0.99880334 0.57506631]
# Support [335007    618]
# **************************************
# Iteration number   16
# Class weights  {0: 1, 1: 16}
# Performance on validation data - Confusion matrix
# [[334396    611]
#  [   115    503]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99965621 0.45152603]
# Recall [0.99817616 0.81391586]
# F-score [0.99891564 0.58083141]
# Support [335007    618]
# **************************************
# Iteration number   17
# Class weights  {0: 1, 1: 17}
# Performance on validation data - Confusion matrix
# [[334220    787]
#  [    78    540]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99976668 0.40693293]
# Recall [0.9976508  0.87378641]
# F-score [0.99870761 0.55526992]
# Support [335007    618]
# **************************************
# Iteration number   18
# Class weights  {0: 1, 1: 18}
# Performance on validation data - Confusion matrix
# [[334550    457]
#  [   227    391]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99932194 0.46108491]
# Recall [0.99863585 0.63268608]
# F-score [0.99897878 0.53342428]
# Support [335007    618]
# **************************************
# Iteration number   19
# Class weights  {0: 1, 1: 19}
# Performance on validation data - Confusion matrix
# [[334273    734]
#  [   113    505]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99966207 0.40758676]
# Recall [0.997809  0.8171521]
# F-score [0.99873467 0.54388799]
# Support [335007    618]
# **************************************
# Iteration number   20
# Class weights  {0: 1, 1: 20}
# Performance on validation data - Confusion matrix
# [[334147    860]
#  [    90    528]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99973073 0.38040346]
# Recall [0.99743289 0.85436893]
# F-score [0.99858049 0.52642074]
# Support [335007    618]
# **************************************
# Iteration number   21
# Class weights  {0: 1, 1: 21}
# Performance on validation data - Confusion matrix
# [[334455    552]
#  [   207    411]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99938147 0.42679128]
# Recall [0.99835227 0.66504854]
# F-score [0.9988666 0.5199241]
# Support [335007    618]
# **************************************
# Iteration number   22
# Class weights  {0: 1, 1: 22}
# Performance on validation data - Confusion matrix
# [[334089    918]
#  [    86    532]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99974265 0.36689655]
# Recall [0.99725976 0.86084142]
# F-score [0.99849966 0.51450677]
# Support [335007    618]
# **************************************
# Iteration number   23
# Class weights  {0: 1, 1: 23}
# Performance on validation data - Confusion matrix
# [[333942   1065]
#  [    69    549]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99979342 0.3401487 ]
# Recall [0.99682096 0.88834951]
# F-score [0.99830498 0.49193548]
# Support [335007    618]
# **************************************
# Iteration number   24
# Class weights  {0: 1, 1: 24}
# Performance on validation data - Confusion matrix
# [[333849   1158]
#  [    60    558]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99982031 0.32517483]
# Recall [0.99654336 0.90291262]
# F-score [0.99817914 0.4781491 ]
# Support [335007    618]
# **************************************
# Iteration number   25
# Class weights  {0: 1, 1: 25}
# Performance on validation data - Confusion matrix
# [[334340    667]
#  [   205    413]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99938723 0.38240741]
# Recall [0.998009   0.66828479]
# F-score [0.99869764 0.48645465]
# Support [335007    618]
# **************************************
# Iteration number   26
# Class weights  {0: 1, 1: 26}
# Performance on validation data - Confusion matrix
# [[333592   1415]
#  [    43    575]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99987112 0.28894472]
# Recall [0.99577621 0.93042071]
# F-score [0.99781946 0.44095092]
# Support [335007    618]
# **************************************
# Iteration number   27
# Class weights  {0: 1, 1: 27}
# Performance on validation data - Confusion matrix
# [[334032    975]
#  [   110    508]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9996708  0.34254889]
# Recall [0.99708961 0.82200647]
# F-score [0.99837854 0.48357925]
# Support [335007    618]
# **************************************
# Iteration number   28
# Class weights  {0: 1, 1: 28}
# Performance on validation data - Confusion matrix
# [[333836   1171]
#  [    80    538]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99976042 0.31480398]
# Recall [0.99650455 0.87055016]
# F-score [0.99812983 0.46239794]
# Support [335007    618]
# **************************************
# Iteration number   29
# Class weights  {0: 1, 1: 29}
# Performance on validation data - Confusion matrix
# [[333655   1352]
#  [    53    565]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99984118 0.29473135]
# Recall [0.99596426 0.91423948]
# F-score [0.99789896 0.44575937]
# Support [335007    618]
# **************************************
# Iteration number   30
# Class weights  {0: 1, 1: 30}
# Performance on validation data - Confusion matrix
# [[333654   1353]
#  [    60    558]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99982021 0.29199372]
# Recall [0.99596128 0.90291262]
# F-score [0.99788701 0.44128114]
# Support [335007    618]
# **************************************
# Iteration number   31
# Class weights  {0: 1, 1: 31}
# Performance on validation data - Confusion matrix
# [[334175    832]
#  [   191    427]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99942877 0.33915806]
# Recall [0.99751647 0.69093851]
# F-score [0.9984717  0.45498135]
# Support [335007    618]
# **************************************
# Iteration number   32
# Class weights  {0: 1, 1: 32}
# Performance on validation data - Confusion matrix
# [[333769   1238]
#  [    83    535]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99975139 0.30174845]
# Recall [0.99630455 0.86569579]
# F-score [0.99802499 0.4475115 ]
# Support [335007    618]
# **************************************
# Iteration number   33
# Class weights  {0: 1, 1: 33}
# Performance on validation data - Confusion matrix
# [[334123    884]
#  [   168    450]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99949744 0.33733133]
# Recall [0.99736125 0.72815534]
# F-score [0.9984282  0.46106557]
# Support [335007    618]
# **************************************
# Iteration number   34
# Class weights  {0: 1, 1: 34}
# Performance on validation data - Confusion matrix
# [[333572   1435]
#  [    62    556]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99981417 0.27925665]
# Recall [0.99571651 0.89967638]
# F-score [0.99776113 0.42621694]
# Support [335007    618]
# **************************************
# Iteration number   35
# Class weights  {0: 1, 1: 35}
# Performance on validation data - Confusion matrix
# [[333669   1338]
#  [    82    536]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99975431 0.28601921]
# Recall [0.99600605 0.86731392]
# F-score [0.99787666 0.43017657]
# Support [335007    618]
# **************************************
# Iteration number   36
# Class weights  {0: 1, 1: 36}
# Performance on validation data - Confusion matrix
# [[333582   1425]
#  [    70    548]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9997902  0.27774962]
# Recall [0.99574636 0.88673139]
# F-score [0.99776418 0.4230027 ]
# Support [335007    618]
# **************************************
# Iteration number   37
# Class weights  {0: 1, 1: 37}
# Performance on validation data - Confusion matrix
# [[334004   1003]
#  [   182    436]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99945539 0.30298819]
# Recall [0.99700603 0.70550162]
# F-score [0.99822921 0.42391833]
# Support [335007    618]
# **************************************
# Iteration number   38
# Class weights  {0: 1, 1: 38}
# Performance on validation data - Confusion matrix
# [[333508   1499]
#  [    70    548]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99979015 0.26770884]
# Recall [0.99552547 0.88673139]
# F-score [0.99765325 0.41125704]
# Support [335007    618]
# **************************************
# Iteration number   39
# Class weights  {0: 1, 1: 39}
# Performance on validation data - Confusion matrix
# [[333447   1560]
#  [    66    552]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99980211 0.26136364]
# Recall [0.99534338 0.89320388]
# F-score [0.99756776 0.4043956 ]
# Support [335007    618]
# **************************************
# Iteration number   40
# Class weights  {0: 1, 1: 40}
# Performance on validation data - Confusion matrix
# [[333951   1056]
#  [   159    459]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99952411 0.3029703 ]
# Recall [0.99684783 0.74271845]
# F-score [0.99818417 0.43037975]
# Support [335007    618]
# **************************************
# Iteration number   41
# Class weights  {0: 1, 1: 41}
# Performance on validation data - Confusion matrix
# [[333930   1077]
#  [   161    457]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9995181  0.29791395]
# Recall [0.99678514 0.7394822 ]
# F-score [0.99814975 0.42472119]
# Support [335007    618]
# **************************************
# Iteration number   42
# Class weights  {0: 1, 1: 42}
# Performance on validation data - Confusion matrix
# [[333886   1121]
#  [   147    471]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99955992 0.29585427]
# Recall [0.9966538  0.76213592]
# F-score [0.99810475 0.42624434]
# Support [335007    618]
# **************************************
# Iteration number   43
# Class weights  {0: 1, 1: 43}
# Performance on validation data - Confusion matrix
# [[333857   1150]
#  [   176    442]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99947311 0.27763819]
# Recall [0.99656724 0.71521036]
# F-score [0.99801806 0.4       ]
# Support [335007    618]
# **************************************
# Iteration number   44
# Class weights  {0: 1, 1: 44}
# Performance on validation data - Confusion matrix
# [[333275   1732]
#  [    59    559]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.999823   0.24399825]
# Recall [0.99482996 0.90453074]
# F-score [0.99732023 0.38432451]
# Support [335007    618]
# **************************************
# Iteration number   45
# Class weights  {0: 1, 1: 45}
# Performance on validation data - Confusion matrix
# [[333813   1194]
#  [   172    446]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99948501 0.27195122]
# Recall [0.9964359  0.72168285]
# F-score [0.99795812 0.39503986]
# Support [335007    618]
# **************************************
# Iteration number   46
# Class weights  {0: 1, 1: 46}
# Performance on validation data - Confusion matrix
# [[333237   1770]
#  [    61    557]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99981698 0.23936399]
# Recall [0.99471653 0.9012945 ]
# F-score [0.99726023 0.37826825]
# Support [335007    618]
# **************************************
# Iteration number   47
# Class weights  {0: 1, 1: 47}
# Performance on validation data - Confusion matrix
# [[333683   1324]
#  [   134    484]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99959858 0.26769912]
# Recall [0.99604784 0.78317152]
# F-score [0.99782005 0.39901072]
# Support [335007    618]
# **************************************
# Iteration number   48
# Class weights  {0: 1, 1: 48}
# Performance on validation data - Confusion matrix
# [[333706   1301]
#  [   139    479]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99958364 0.26910112]
# Recall [0.9961165  0.77508091]
# F-score [0.99784706 0.39949958]
# Support [335007    618]
# **************************************
# Iteration number   49
# Class weights  {0: 1, 1: 49}
# Performance on validation data - Confusion matrix
# [[333125   1882]
#  [    55    563]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99983492 0.23026585]
# Recall [0.99438221 0.91100324]
# F-score [0.99710111 0.36761345]
# Support [335007    618]
# **************************************
# Iteration number   50
# Class weights  {0: 1, 1: 50}
# Performance on validation data - Confusion matrix
# [[333680   1327]
#  [   143    475]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99957163 0.263596  ]
# Recall [0.99603889 0.76860841]
# F-score [0.99780213 0.39256198]
# Support [335007    618]
# **************************************
# Iteration number   51
# Class weights  {0: 1, 1: 51}
# Performance on validation data - Confusion matrix
# [[333032   1975]
#  [    49    569]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99985289 0.22366352]
# Recall [0.9941046  0.92071197]
# F-score [0.99697046 0.3598988 ]
# Support [335007    618]
# **************************************
# Iteration number   52
# Class weights  {0: 1, 1: 52}
# Performance on validation data - Confusion matrix
# [[333663   1344]
#  [   155    463]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99953568 0.25622579]
# Recall [0.99598814 0.74919094]
# F-score [0.99775876 0.38185567]
# Support [335007    618]
# **************************************
# Iteration number   53
# Class weights  {0: 1, 1: 53}
# Performance on validation data - Confusion matrix
# [[333427   1580]
#  [   107    511]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99967919 0.24438068]
# Recall [0.99528368 0.82686084]
# F-score [0.99747659 0.37726098]
# Support [335007    618]
# **************************************
# Iteration number   54
# Class weights  {0: 1, 1: 54}
# Performance on validation data - Confusion matrix
# [[333616   1391]
#  [   160    458]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99952064 0.24770146]
# Recall [0.99584785 0.74110032]
# F-score [0.99768086 0.37130118]
# Support [335007    618]
# **************************************
# Iteration number   55
# Class weights  {0: 1, 1: 55}
# Performance on validation data - Confusion matrix
# [[333586   1421]
#  [   160    458]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99952059 0.24374667]
# Recall [0.9957583  0.74110032]
# F-score [0.9976359  0.36684021]
# Support [335007    618]
# **************************************
# Iteration number   56
# Class weights  {0: 1, 1: 56}
# Performance on validation data - Confusion matrix
# [[333562   1445]
#  [   160    458]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99952056 0.24067262]
# Recall [0.99568666 0.74110032]
# F-score [0.99759992 0.36334788]
# Support [335007    618]
# **************************************
# Iteration number   57
# Class weights  {0: 1, 1: 57}
# Performance on validation data - Confusion matrix
# [[333477   1530]
#  [   135    483]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99959534 0.23994039]
# Recall [0.99543293 0.7815534 ]
# F-score [0.99750979 0.36716078]
# Support [335007    618]
# **************************************
# Iteration number   58
# Class weights  {0: 1, 1: 58}
# Performance on validation data - Confusion matrix
# [[333511   1496]
#  [   146    472]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99956242 0.2398374 ]
# Recall [0.99553442 0.76375405]
# F-score [0.99754436 0.36504254]
# Support [335007    618]
# **************************************
# Iteration number   59
# Class weights  {0: 1, 1: 59}
# Performance on validation data - Confusion matrix
# [[333490   1517]
#  [   156    462]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99953244 0.23345124]
# Recall [0.99547174 0.74757282]
# F-score [0.99749795 0.35579515]
# Support [335007    618]
# **************************************
# Iteration number   60
# Class weights  {0: 1, 1: 60}
# Performance on validation data - Confusion matrix
# [[333213   1794]
#  [    98    520]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99970598 0.2247191 ]
# Recall [0.99464489 0.84142395]
# F-score [0.99716901 0.35470668]
# Support [335007    618]
# **************************************
# Iteration number   61
# Class weights  {0: 1, 1: 61}
# Performance on validation data - Confusion matrix
# [[333220   1787]
#  [   103    515]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99969099 0.22371851]
# Recall [0.99466578 0.83333333]
# F-score [0.99717206 0.35273973]
# Support [335007    618]
# **************************************
# Iteration number   62
# Class weights  {0: 1, 1: 62}
# Performance on validation data - Confusion matrix
# [[333419   1588]
#  [   148    470]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99955631 0.22837707]
# Recall [0.9952598 0.7605178]
# F-score [0.99740343 0.35127055]
# Support [335007    618]
# **************************************
# Iteration number   63
# Class weights  {0: 1, 1: 63}
# Performance on validation data - Confusion matrix
# [[333411   1596]
#  [   152    466]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99954431 0.22599418]
# Recall [0.99523592 0.75404531]
# F-score [0.99738546 0.34776119]
# Support [335007    618]
# **************************************
# Iteration number   64
# Class weights  {0: 1, 1: 64}
# Performance on validation data - Confusion matrix
# [[333120   1887]
#  [    96    522]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9997119  0.21668742]
# Recall [0.99436728 0.84466019]
# F-score [0.99703243 0.34489594]
# Support [335007    618]
# **************************************
# Iteration number   65
# Class weights  {0: 1, 1: 65}
# Performance on validation data - Confusion matrix
# [[333018   1989]
#  [    86    532]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99974182 0.21102737]
# Recall [0.99406281 0.86084142]
# F-score [0.99689423 0.33896145]
# Support [335007    618]
# **************************************
# Iteration number   66
# Class weights  {0: 1, 1: 66}
# Performance on validation data - Confusion matrix
# [[333003   2004]
#  [    86    532]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99974181 0.20977918]
# Recall [0.99401804 0.86084142]
# F-score [0.99687171 0.3373494 ]
# Support [335007    618]
# **************************************
# Iteration number   67
# Class weights  {0: 1, 1: 67}
# Performance on validation data - Confusion matrix
# [[333304   1703]
#  [   148    470]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99955616 0.21629084]
# Recall [0.99491652 0.7605178 ]
# F-score [0.99723094 0.33679685]
# Support [335007    618]
# **************************************
# Iteration number   68
# Class weights  {0: 1, 1: 68}
# Performance on validation data - Confusion matrix
# [[333249   1758]
#  [   139    479]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99958307 0.21412606]
# Recall [0.99475235 0.77508091]
# F-score [0.99716186 0.33555166]
# Support [335007    618]
# **************************************
# Iteration number   69
# Class weights  {0: 1, 1: 69}
# Performance on validation data - Confusion matrix
# [[333257   1750]
#  [   146    472]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99956209 0.21242124]
# Recall [0.99477623 0.76375405]
# F-score [0.99716342 0.33239437]
# Support [335007    618]
# **************************************
# Iteration number   70
# Class weights  {0: 1, 1: 70}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-431572d56fe0> in <module>
#     101    svm(x,y,filename)
#     102
# --> 103 run()
#
# <ipython-input-2-431572d56fe0> in run()
#      99
#     100    print("**************** SVM *******************")
# --> 101    svm(x,y,filename)
#     102
#     103 run()
#
# <ipython-input-2-431572d56fe0> in svm(x, y, filename)
#      52        svm = LinearSVC(class_weight = cw, dual = False ,tol=1e-05,max_iter = 1000)
#      53        print('Class weights ', cw)
# ---> 54        svm.fit(X_train,y_train)
#      55
#      56        # Save trained model to disk
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\classes.py in fit(self, X, y, sample_weight)
#     235             self.class_weight, self.penalty, self.dual, self.verbose,
#     236             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 237             self.loss, sample_weight=sample_weight)
#     238
#     239         if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     912         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     913         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 914         epsilon, sample_weight)
#     915     # Regarding rnd.randint(..) in the above signature:
#     916     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:
