# %%
import numpy as np
import pandas as pd
import csv
import sys
import os

import matplotlib.pyplot as plt    
    
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
import warnings
import pickle

max_iters = 501


def svm(x,y,filename):

   # Model output file name
   file = (os.path.splitext(filename))[0]
   fname = './models/svm_' + file +'/'

   # File for writing precision,recall, f-measure scores for fraud transactions
   f = open('./prf/svm_'+ file + '_prf' +'.txt' ,'w')
   f.write('precision,recall,f-score \n')

   # Stratified sampling based on Y
   X_train, X_test, y_train, y_test = train_test_split(x, y,stratify=y , test_size=0.30, random_state=42)

   # Create 15% validation set and 15% test set split
   X_val, X_test, y_val, y_test = train_test_split(X_test, y_test,stratify=y_test , test_size=0.50, random_state=42)

   #Iterations
   it = 1
   
   # Run training algorithm for multiple class weights
   while it < max_iters:
       cw = {}
       cw[0] = 1
       cw[1] = it
       # Train
       print('**************************************')
       print("Iteration number  " , it)
       svm = LinearSVC(class_weight = cw, dual = False ,tol=1e-05,max_iter = 1000)
       print('Class weights ', cw)
       svm.fit(X_train,y_train)

       # Save trained model to disk
       name = fname + str(cw[1]) + '.sav'
       pickle.dump(svm, open(name, 'wb'))

       #Predict on validation data
       y_val_pred = svm.predict(X_val)
       print('Performance on validation data - Confusion matrix')
       print(confusion_matrix(y_val,y_val_pred))
   
       precision,recall,fscore,support=score(y_val,y_val_pred,average=None)
       print('Precision, Recall, F-score, Support on validation data' )
       print("Precision" , precision)
       print("Recall" , recall)
       print("F-score" , fscore)
       print("Support" , support)

       p1 = precision[1]
       r1 = recall[1]
       f1 = fscore[1]

       f.write(str(p1) +','+ str(r1) + ',' + str(f1) + '\n')    
       it += 1

   f.close()

def run():
   filename = 'm3.csv'
   df = pd.read_csv(filename, usecols = [9,10,11,12,13,14] , header = 0)
   
   results = list(map(int, df['Anomaly'])) 
   print('Number of fraudulent transactions ' , sum(results))

   features = ['Airfare', 'Lodging', 'Meals', 'Other_Transportation', 'Other_Expenses']
   targets = ['Anomaly']

   # Separating out the features and target variables
   x = df.loc[:, features].values
   y = df.loc[:, targets].values
    
   scaler = preprocessing.StandardScaler()
   x = scaler.fit_transform(x) 

   y  = [i for j in y for i in j]
   
   #Ignore warnings
   warnings.filterwarnings("ignore", category=FutureWarning)

   print("**************** SVM *******************")
   svm(x,y,filename)
  
run()
# Out:
# Number of fraudulent transactions  4097
# **************** SVM *******************
# **************************************
# Iteration number   1
# Class weights  {0: 1, 1: 1}
# Performance on validation data - Confusion matrix
# [[79310    12]
#  [  207   407]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99739678 0.97136038]
# Recall [0.99984872 0.66286645]
# F-score [0.99862125 0.78799613]
# Support [79322   614]
# **************************************
# Iteration number   2
# Class weights  {0: 1, 1: 2}
# Performance on validation data - Confusion matrix
# [[79302    20]
#  [  185   429]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99767258 0.95545657]
# Recall [0.99974786 0.69869707]
# F-score [0.99870914 0.80714958]
# Support [79322   614]
# **************************************
# Iteration number   3
# Class weights  {0: 1, 1: 3}
# Performance on validation data - Confusion matrix
# [[79293    29]
#  [  162   452]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99796111 0.93970894]
# Recall [0.9996344  0.73615635]
# F-score [0.99879705 0.82557078]
# Support [79322   614]
# **************************************
# Iteration number   4
# Class weights  {0: 1, 1: 4}
# Performance on validation data - Confusion matrix
# [[79282    40]
#  [  145   469]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99817442 0.92141454]
# Recall [0.99949573 0.76384365]
# F-score [0.99883464 0.83526269]
# Support [79322   614]
# **************************************
# Iteration number   5
# Class weights  {0: 1, 1: 5}
# Performance on validation data - Confusion matrix
# [[79274    48]
#  [  132   482]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99833766 0.90943396]
# Recall [0.99939487 0.78501629]
# F-score [0.99886598 0.84265734]
# Support [79322   614]
# **************************************
# Iteration number   6
# Class weights  {0: 1, 1: 6}
# Performance on validation data - Confusion matrix
# [[79262    60]
#  [  117   497]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99852606 0.89228007]
# Recall [0.99924359 0.80944625]
# F-score [0.9988847  0.84884714]
# Support [79322   614]
# **************************************
# Iteration number   7
# Class weights  {0: 1, 1: 7}
# Performance on validation data - Confusion matrix
# [[79256    66]
#  [  111   503]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99860143 0.88400703]
# Recall [0.99916795 0.81921824]
# F-score [0.99888461 0.85038039]
# Support [79322   614]
# **************************************
# Iteration number   8
# Class weights  {0: 1, 1: 8}
# Performance on validation data - Confusion matrix
# [[79248    74]
#  [  106   508]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99866421 0.87285223]
# Recall [0.99906709 0.82736156]
# F-score [0.99886561 0.84949833]
# Support [79322   614]
# **************************************
# Iteration number   9
# Class weights  {0: 1, 1: 9}
# Performance on validation data - Confusion matrix
# [[79240    82]
#  [   97   517]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99877737 0.86310518]
# Recall [0.99896624 0.84201954]
# F-score [0.99887179 0.85243199]
# Support [79322   614]
# **************************************
# Iteration number   10
# Class weights  {0: 1, 1: 10}
# Performance on validation data - Confusion matrix
# [[79234    88]
#  [   90   524]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99886541 0.85620915]
# Recall [0.9988906 0.8534202]
# F-score [0.99887801 0.8548124 ]
# Support [79322   614]
# **************************************
# Iteration number   11
# Class weights  {0: 1, 1: 11}
# Performance on validation data - Confusion matrix
# [[79221   101]
#  [   79   535]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99900378 0.84119497]
# Recall [0.99872671 0.8713355 ]
# F-score [0.99886523 0.856     ]
# Support [79322   614]
# **************************************
# Iteration number   12
# Class weights  {0: 1, 1: 12}
# Performance on validation data - Confusion matrix
# [[79206   116]
#  [   71   543]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99910441 0.82397572]
# Recall [0.99853761 0.88436482]
# F-score [0.99882093 0.85310291]
# Support [79322   614]
# **************************************
# Iteration number   13
# Class weights  {0: 1, 1: 13}
# Performance on validation data - Confusion matrix
# [[79198   124]
#  [   66   548]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99916734 0.81547619]
# Recall [0.99843675 0.89250814]
# F-score [0.99880191 0.85225505]
# Support [79322   614]
# **************************************
# Iteration number   14
# Class weights  {0: 1, 1: 14}
# Performance on validation data - Confusion matrix
# [[79193   129]
#  [   59   555]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99925554 0.81140351]
# Recall [0.99837372 0.90390879]
# F-score [0.99881443 0.85516179]
# Support [79322   614]
# **************************************
# Iteration number   15
# Class weights  {0: 1, 1: 15}
# Performance on validation data - Confusion matrix
# [[79182   140]
#  [   55   559]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99930588 0.79971388]
# Recall [0.99823504 0.91042345]
# F-score [0.99877017 0.85148515]
# Support [79322   614]
# **************************************
# Iteration number   16
# Class weights  {0: 1, 1: 16}
# Performance on validation data - Confusion matrix
# [[79164   158]
#  [   50   564]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9993688  0.78116343]
# Recall [0.99800812 0.91856678]
# F-score [0.998688   0.84431138]
# Support [79322   614]
# **************************************
# Iteration number   17
# Class weights  {0: 1, 1: 17}
# Performance on validation data - Confusion matrix
# [[79150   172]
#  [   45   569]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99943178 0.76788124]
# Recall [0.99783162 0.9267101 ]
# F-score [0.99863106 0.8398524 ]
# Support [79322   614]
# **************************************
# Iteration number   18
# Class weights  {0: 1, 1: 18}
# Performance on validation data - Confusion matrix
# [[79137   185]
#  [   43   571]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99945693 0.75529101]
# Recall [0.99766773 0.92996743]
# F-score [0.99856153 0.83357664]
# Support [79322   614]
# **************************************
# Iteration number   19
# Class weights  {0: 1, 1: 19}
# Performance on validation data - Confusion matrix
# [[79126   196]
#  [   41   573]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99948211 0.74512354]
# Recall [0.99752906 0.93322476]
# F-score [0.99850463 0.82863341]
# Support [79322   614]
# **************************************
# Iteration number   20
# Class weights  {0: 1, 1: 20}
# Performance on validation data - Confusion matrix
# [[79113   209]
#  [   31   583]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99960831 0.73611111]
# Recall [0.99736517 0.9495114 ]
# F-score [0.99848548 0.82930299]
# Support [79322   614]
# **************************************
# Iteration number   21
# Class weights  {0: 1, 1: 21}
# Performance on validation data - Confusion matrix
# [[79102   220]
#  [   26   588]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99967142 0.72772277]
# Recall [0.99722649 0.95765472]
# F-score [0.99844746 0.82700422]
# Support [79322   614]
# **************************************
# Iteration number   22
# Class weights  {0: 1, 1: 22}
# Performance on validation data - Confusion matrix
# [[79090   232]
#  [   22   592]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99972191 0.7184466 ]
# Recall [0.99707521 0.96416938]
# F-score [0.99839681 0.82336579]
# Support [79322   614]
# **************************************
# Iteration number   23
# Class weights  {0: 1, 1: 23}
# Performance on validation data - Confusion matrix
# [[79076   246]
#  [   18   596]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99977242 0.70783848]
# Recall [0.99689872 0.97068404]
# F-score [0.9983335  0.81868132]
# Support [79322   614]
# **************************************
# Iteration number   24
# Class weights  {0: 1, 1: 24}
# Performance on validation data - Confusion matrix
# [[79068   254]
#  [   11   603]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9998609  0.70361727]
# Recall [0.99679786 0.98208469]
# F-score [0.99832703 0.81985044]
# Support [79322   614]
# **************************************
# Iteration number   25
# Class weights  {0: 1, 1: 25}
# Performance on validation data - Confusion matrix
# [[79061   261]
#  [    7   607]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99991147 0.69930876]
# Recall [0.99670961 0.98859935]
# F-score [0.99830797 0.81916329]
# Support [79322   614]
# **************************************
# Iteration number   26
# Class weights  {0: 1, 1: 26}
# Performance on validation data - Confusion matrix
# [[79051   271]
#  [    3   611]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99996205 0.69274376]
# Recall [0.99658355 0.99511401]
# F-score [0.99826994 0.81684492]
# Support [79322   614]
# **************************************
# Iteration number   27
# Class weights  {0: 1, 1: 27}
# Performance on validation data - Confusion matrix
# [[78884   438]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998732 0.58325404]
# Recall [0.9944782  0.99837134]
# F-score [0.99722515 0.73633634]
# Support [79322   614]
# **************************************
# Iteration number   28
# Class weights  {0: 1, 1: 28}
# Performance on validation data - Confusion matrix
# [[78685   637]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998729 0.4904    ]
# Recall [0.99196944 0.99837134]
# F-score [0.99596223 0.65772532]
# Support [79322   614]
# **************************************
# Iteration number   29
# Class weights  {0: 1, 1: 29}
# Performance on validation data - Confusion matrix
# [[78559   763]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998727 0.44549419]
# Recall [0.99038098 0.99837134]
# F-score [0.99516094 0.6160804 ]
# Support [79322   614]
# **************************************
# Iteration number   30
# Class weights  {0: 1, 1: 30}
# Performance on validation data - Confusion matrix
# [[78462   860]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998726 0.4161575 ]
# Recall [0.98915812 0.99837134]
# F-score [0.99454321 0.58744609]
# Support [79322   614]
# **************************************
# Iteration number   31
# Class weights  {0: 1, 1: 31}
# Performance on validation data - Confusion matrix
# [[78379   943]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998724 0.39395887]
# Recall [0.98811175 0.99837134]
# F-score [0.99401403 0.56497696]
# Support [79322   614]
# **************************************
# Iteration number   32
# Class weights  {0: 1, 1: 32}
# Performance on validation data - Confusion matrix
# [[78321  1001]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998723 0.37980173]
# Recall [0.98738055 0.99837134]
# F-score [0.99364391 0.5502693 ]
# Support [79322   614]
# **************************************
# Iteration number   33
# Class weights  {0: 1, 1: 33}
# Performance on validation data - Confusion matrix
# [[78258  1064]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998722 0.36553369]
# Recall [0.98658632 0.99837134]
# F-score [0.99324157 0.53513749]
# Support [79322   614]
# **************************************
# Iteration number   34
# Class weights  {0: 1, 1: 34}
# Performance on validation data - Confusion matrix
# [[78196  1126]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998721 0.35250144]
# Recall [0.98580469 0.99837134]
# F-score [0.99284531 0.52103697]
# Support [79322   614]
# **************************************
# Iteration number   35
# Class weights  {0: 1, 1: 35}
# Performance on validation data - Confusion matrix
# [[78129  1193]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999872  0.33942414]
# Recall [0.98496004 0.99837134]
# F-score [0.99241674 0.50661157]
# Support [79322   614]
# **************************************
# Iteration number   36
# Class weights  {0: 1, 1: 36}
# Performance on validation data - Confusion matrix
# [[78075  1247]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998719 0.32956989]
# Recall [0.98427927 0.99837134]
# F-score [0.99207106 0.49555376]
# Support [79322   614]
# **************************************
# Iteration number   37
# Class weights  {0: 1, 1: 37}
# Performance on validation data - Confusion matrix
# [[78022  1300]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998718 0.3204391 ]
# Recall [0.9836111  0.99837134]
# F-score [0.99173155 0.48516027]
# Support [79322   614]
# **************************************
# Iteration number   38
# Class weights  {0: 1, 1: 38}
# Performance on validation data - Confusion matrix
# [[77968  1354]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998717 0.31164209]
# Recall [0.98293033 0.99837134]
# F-score [0.99138539 0.47500969]
# Support [79322   614]
# **************************************
# Iteration number   39
# Class weights  {0: 1, 1: 39}
# Performance on validation data - Confusion matrix
# [[77918  1404]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998717 0.30391671]
# Recall [0.98229999 0.99837134]
# F-score [0.99106467 0.46598252]
# Support [79322   614]
# **************************************
# Iteration number   40
# Class weights  {0: 1, 1: 40}
# Performance on validation data - Confusion matrix
# [[77879  1443]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998716 0.29815175]
# Recall [0.98180833 0.99837134]
# F-score [0.99081437 0.45917603]
# Support [79322   614]
# **************************************
# Iteration number   41
# Class weights  {0: 1, 1: 41}
# Performance on validation data - Confusion matrix
# [[77822  1500]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998715 0.29010885]
# Recall [0.98108974 0.99837134]
# F-score [0.99044831 0.44957829]
# Support [79322   614]
# **************************************
# Iteration number   42
# Class weights  {0: 1, 1: 42}
# Performance on validation data - Confusion matrix
# [[77777  1545]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998714 0.28405931]
# Recall [0.98052243 0.99837134]
# F-score [0.99015913 0.44227994]
# Support [79322   614]
# **************************************
# Iteration number   43
# Class weights  {0: 1, 1: 43}
# Performance on validation data - Confusion matrix
# [[77744  1578]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998714 0.27978092]
# Recall [0.9801064  0.99837134]
# F-score [0.98994697 0.43707665]
# Support [79322   614]
# **************************************
# Iteration number   44
# Class weights  {0: 1, 1: 44}
# Performance on validation data - Confusion matrix
# [[77707  1615]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998713 0.27513465]
# Recall [0.97963995 0.99837134]
# F-score [0.98970897 0.43138635]
# Support [79322   614]
# **************************************
# Iteration number   45
# Class weights  {0: 1, 1: 45}
# Performance on validation data - Confusion matrix
# [[77676  1646]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998713 0.27135901]
# Recall [0.97924914 0.99837134]
# F-score [0.98950949 0.42673164]
# Support [79322   614]
# **************************************
# Iteration number   46
# Class weights  {0: 1, 1: 46}
# Performance on validation data - Confusion matrix
# [[77648  1674]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998712 0.26803673]
# Recall [0.97889614 0.99837134]
# F-score [0.98932924 0.42261289]
# Support [79322   614]
# **************************************
# Iteration number   47
# Class weights  {0: 1, 1: 47}
# Performance on validation data - Confusion matrix
# [[77621  1701]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998712 0.26490925]
# Recall [0.97855576 0.99837134]
# F-score [0.98915537 0.41871585]
# Support [79322   614]
# **************************************
# Iteration number   48
# Class weights  {0: 1, 1: 48}
# Performance on validation data - Confusion matrix
# [[77576  1746]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998711 0.25985587]
# Recall [0.97798845 0.99837134]
# F-score [0.98886545 0.41237807]
# Support [79322   614]
# **************************************
# Iteration number   49
# Class weights  {0: 1, 1: 49}
# Performance on validation data - Confusion matrix
# [[77542  1780]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999871  0.25616381]
# Recall [0.97755982 0.99837134]
# F-score [0.98864629 0.40771533]
# Support [79322   614]
# **************************************
# Iteration number   50
# Class weights  {0: 1, 1: 50}
# Performance on validation data - Confusion matrix
# [[77505  1817]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999871  0.25226337]
# Recall [0.97709337 0.99837134]
# F-score [0.98840768 0.40275953]
# Support [79322   614]
# **************************************
# Iteration number   51
# Class weights  {0: 1, 1: 51}
# Performance on validation data - Confusion matrix
# [[77467  1855]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998709 0.24837925]
# Recall [0.97661431 0.99837134]
# F-score [0.98816251 0.39779364]
# Support [79322   614]
# **************************************
# Iteration number   52
# Class weights  {0: 1, 1: 52}
# Performance on validation data - Confusion matrix
# [[77430  1892]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998709 0.24471058]
# Recall [0.97614785 0.99837134]
# F-score [0.98792368 0.3930747 ]
# Support [79322   614]
# **************************************
# Iteration number   53
# Class weights  {0: 1, 1: 53}
# Performance on validation data - Confusion matrix
# [[77389  1933]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998708 0.24076984]
# Recall [0.97563097 0.99837134]
# F-score [0.98765889 0.38797468]
# Support [79322   614]
# **************************************
# Iteration number   54
# Class weights  {0: 1, 1: 54}
# Performance on validation data - Confusion matrix
# [[77337  1985]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998707 0.23595073]
# Recall [0.97497542 0.99837134]
# F-score [0.98732286 0.38169365]
# Support [79322   614]
# **************************************
# Iteration number   55
# Class weights  {0: 1, 1: 55}
# Performance on validation data - Confusion matrix
# [[77302  2020]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998706 0.23281428]
# Recall [0.97453418 0.99837134]
# F-score [0.98709657 0.3775793 ]
# Support [79322   614]
# **************************************
# Iteration number   56
# Class weights  {0: 1, 1: 56}
# Performance on validation data - Confusion matrix
# [[77272  2050]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998706 0.23019151]
# Recall [0.97415597 0.99837134]
# F-score [0.98690252 0.37412267]
# Support [79322   614]
# **************************************
# Iteration number   57
# Class weights  {0: 1, 1: 57}
# Performance on validation data - Confusion matrix
# [[77235  2087]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998705 0.22703704]
# Recall [0.97368952 0.99837134]
# F-score [0.98666309 0.36994568]
# Support [79322   614]
# **************************************
# Iteration number   58
# Class weights  {0: 1, 1: 58}
# Performance on validation data - Confusion matrix
# [[77209  2113]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998705 0.22487161]
# Recall [0.97336174 0.99837134]
# F-score [0.98649477 0.36706587]
# Support [79322   614]
# **************************************
# Iteration number   59
# Class weights  {0: 1, 1: 59}
# Performance on validation data - Confusion matrix
# [[77185  2137]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998704 0.22290909]
# Recall [0.97305918 0.99837134]
# F-score [0.98633936 0.36444709]
# Support [79322   614]
# **************************************
# Iteration number   60
# Class weights  {0: 1, 1: 60}
# Performance on validation data - Confusion matrix
# [[77146  2176]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998704 0.21979204]
# Recall [0.97256751 0.99837134]
# F-score [0.9860867  0.36027035]
# Support [79322   614]
# **************************************
# Iteration number   61
# Class weights  {0: 1, 1: 61}
# Performance on validation data - Confusion matrix
# [[77103  2219]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998703 0.2164548 ]
# Recall [0.97202542 0.99837134]
# F-score [0.98580799 0.35577481]
# Support [79322   614]
# **************************************
# Iteration number   62
# Class weights  {0: 1, 1: 62}
# Performance on validation data - Confusion matrix
# [[77064  2258]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998702 0.21351445]
# Recall [0.97153375 0.99837134]
# F-score [0.98555507 0.3517934 ]
# Support [79322   614]
# **************************************
# Iteration number   63
# Class weights  {0: 1, 1: 63}
# Performance on validation data - Confusion matrix
# [[77034  2288]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998702 0.21130645]
# Recall [0.97115554 0.99837134]
# F-score [0.98536043 0.3487909 ]
# Support [79322   614]
# **************************************
# Iteration number   64
# Class weights  {0: 1, 1: 64}
# Performance on validation data - Confusion matrix
# [[77011  2311]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998702 0.20964432]
# Recall [0.97086559 0.99837134]
# F-score [0.98521115 0.34652346]
# Support [79322   614]
# **************************************
# Iteration number   65
# Class weights  {0: 1, 1: 65}
# Performance on validation data - Confusion matrix
# [[76981  2341]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998701 0.20751523]
# Recall [0.97048738 0.99837134]
# F-score [0.98501638 0.34360987]
# Support [79322   614]
# **************************************
# Iteration number   66
# Class weights  {0: 1, 1: 66}
# Performance on validation data - Confusion matrix
# [[76952  2370]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998701 0.20549782]
# Recall [0.97012178 0.99837134]
# F-score [0.98482803 0.34083959]
# Support [79322   614]
# **************************************
# Iteration number   67
# Class weights  {0: 1, 1: 67}
# Performance on validation data - Confusion matrix
# [[76919  2403]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.999987   0.20324934]
# Recall [0.96970576 0.99837134]
# F-score [0.98461361 0.33774105]
# Support [79322   614]
# **************************************
# Iteration number   68
# Class weights  {0: 1, 1: 68}
# Performance on validation data - Confusion matrix
# [[76887  2435]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998699 0.20111549]
# Recall [0.96930234 0.99837134]
# F-score [0.98440561 0.33478973]
# Support [79322   614]
# **************************************
# Iteration number   69
# Class weights  {0: 1, 1: 69}
# Performance on validation data - Confusion matrix
# [[76860  2462]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998699 0.19934959]
# Recall [0.96896195 0.99837134]
# F-score [0.98423004 0.33233939]
# Support [79322   614]
# **************************************
# Iteration number   70
# Class weights  {0: 1, 1: 70}
# Performance on validation data - Confusion matrix
# [[76825  2497]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998698 0.19710611]
# Recall [0.96852071 0.99837134]
# F-score [0.98400236 0.3292159 ]
# Support [79322   614]
# **************************************
# Iteration number   71
# Class weights  {0: 1, 1: 71}
# Performance on validation data - Confusion matrix
# [[76791  2531]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998698 0.19497455]
# Recall [0.96809208 0.99837134]
# F-score [0.98378108 0.32623736]
# Support [79322   614]
# **************************************
# Iteration number   72
# Class weights  {0: 1, 1: 72}
# Performance on validation data - Confusion matrix
# [[76764  2558]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998697 0.19331441]
# Recall [0.9677517  0.99837134]
# F-score [0.9836053  0.32391017]
# Support [79322   614]
# **************************************
# Iteration number   73
# Class weights  {0: 1, 1: 73}
# Performance on validation data - Confusion matrix
# [[76732  2590]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998697 0.19138308]
# Recall [0.96734828 0.99837134]
# F-score [0.98339688 0.32119466]
# Support [79322   614]
# **************************************
# Iteration number   74
# Class weights  {0: 1, 1: 74}
# Performance on validation data - Confusion matrix
# [[76700  2622]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998696 0.18948995]
# Recall [0.96694486 0.99837134]
# F-score [0.98318838 0.31852429]
# Support [79322   614]
# **************************************
# Iteration number   75
# Class weights  {0: 1, 1: 75}
# Performance on validation data - Confusion matrix
# [[76666  2656]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998696 0.18751912]
# Recall [0.96651623 0.99837134]
# F-score [0.98296675 0.31573526]
# Support [79322   614]
# **************************************
# Iteration number   76
# Class weights  {0: 1, 1: 76}
# Performance on validation data - Confusion matrix
# [[76645  2677]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998695 0.18632219]
# Recall [0.96625148 0.99837134]
# F-score [0.98282981 0.31403689]
# Support [79322   614]
# **************************************
# Iteration number   77
# Class weights  {0: 1, 1: 77}
# Performance on validation data - Confusion matrix
# [[76622  2700]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998695 0.18502867]
# Recall [0.96596152 0.99837134]
# F-score [0.98267979 0.31219761]
# Support [79322   614]
# **************************************
# Iteration number   78
# Class weights  {0: 1, 1: 78}
# Performance on validation data - Confusion matrix
# [[76594  2728]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998694 0.183478  ]
# Recall [0.96560853 0.99837134]
# F-score [0.9824971  0.30998736]
# Support [79322   614]
# **************************************
# Iteration number   79
# Class weights  {0: 1, 1: 79}
# Performance on validation data - Confusion matrix
# [[76566  2756]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998694 0.1819531 ]
# Recall [0.96525554 0.99837134]
# F-score [0.98231434 0.30780818]
# Support [79322   614]
# **************************************
# Iteration number   80
# Class weights  {0: 1, 1: 80}
# Performance on validation data - Confusion matrix
# [[76531  2791]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998693 0.18008226]
# Recall [0.9648143  0.99837134]
# F-score [0.9820858  0.30512693]
# Support [79322   614]
# **************************************
# Iteration number   81
# Class weights  {0: 1, 1: 81}
# Performance on validation data - Confusion matrix
# [[76507  2815]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998693 0.17882147]
# Recall [0.96451174 0.99837134]
# F-score [0.98192903 0.30331519]
# Support [79322   614]
# **************************************
# Iteration number   82
# Class weights  {0: 1, 1: 82}
# Performance on validation data - Confusion matrix
# [[76469  2853]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998692 0.17686093]
# Recall [0.96403268 0.99837134]
# F-score [0.9816807 0.3004902]
# Support [79322   614]
# **************************************
# Iteration number   83
# Class weights  {0: 1, 1: 83}
# Performance on validation data - Confusion matrix
# [[76445  2877]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998692 0.1756447 ]
# Recall [0.96373011 0.99837134]
# F-score [0.9815238  0.29873294]
# Support [79322   614]
# **************************************
# Iteration number   84
# Class weights  {0: 1, 1: 84}
# Performance on validation data - Confusion matrix
# [[76423  2899]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998692 0.17454442]
# Recall [0.96345276 0.99837134]
# F-score [0.98137994 0.29714009]
# Support [79322   614]
# **************************************
# Iteration number   85
# Class weights  {0: 1, 1: 85}
# Performance on validation data - Confusion matrix
# [[76394  2928]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998691 0.17311494]
# Recall [0.96308716 0.99837134]
# F-score [0.98119024 0.29506619]
# Support [79322   614]
# **************************************
# Iteration number   86
# Class weights  {0: 1, 1: 86}
# Performance on validation data - Confusion matrix
# [[76365  2957]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998691 0.17170868]
# Recall [0.96272157 0.99837134]
# F-score [0.98100046 0.29302103]
# Support [79322   614]
# **************************************
# Iteration number   87
# Class weights  {0: 1, 1: 87}
# Performance on validation data - Confusion matrix
# [[76336  2986]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999869  0.17032509]
# Recall [0.96235597 0.99837134]
# F-score [0.98081062 0.29100404]
# Support [79322   614]
# **************************************
# Iteration number   88
# Class weights  {0: 1, 1: 88}
# Performance on validation data - Confusion matrix
# [[76306  3016]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999869  0.16891706]
# Recall [0.96197776 0.99837134]
# F-score [0.98061415 0.2889465 ]
# Support [79322   614]
# **************************************
# Iteration number   89
# Class weights  {0: 1, 1: 89}
# Performance on validation data - Confusion matrix
# [[76282  3040]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998689 0.16780728]
# Recall [0.9616752  0.99837134]
# F-score [0.98045693 0.2873213 ]
# Support [79322   614]
# **************************************
# Iteration number   90
# Class weights  {0: 1, 1: 90}
# Performance on validation data - Confusion matrix
# [[76251  3071]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998689 0.16639522]
# Recall [0.96128439 0.99837134]
# F-score [0.98025377 0.28524895]
# Support [79322   614]
# **************************************
# Iteration number   91
# Class weights  {0: 1, 1: 91}
# Performance on validation data - Confusion matrix
# [[76229  3093]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998688 0.16540745]
# Recall [0.96100703 0.99837134]
# F-score [0.98010955 0.2837963 ]
# Support [79322   614]
# **************************************
# Iteration number   92
# Class weights  {0: 1, 1: 92}
# Performance on validation data - Confusion matrix
# [[76191  3131]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998688 0.16372863]
# Recall [0.96052797 0.99837134]
# F-score [0.97986033 0.28132171]
# Support [79322   614]
# **************************************
# Iteration number   93
# Class weights  {0: 1, 1: 93}
# Performance on validation data - Confusion matrix
# [[76165  3157]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998687 0.16259947]
# Recall [0.9602002  0.99837134]
# F-score [0.97968975 0.27965328]
# Support [79322   614]
# **************************************
# Iteration number   94
# Class weights  {0: 1, 1: 94}
# Performance on validation data - Confusion matrix
# [[76138  3184]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998687 0.16144324]
# Recall [0.95985981 0.99837134]
# F-score [0.97951255 0.27794151]
# Support [79322   614]
# **************************************
# Iteration number   95
# Class weights  {0: 1, 1: 95}
# Performance on validation data - Confusion matrix
# [[76113  3209]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998686 0.16038723]
# Recall [0.95954464 0.99837134]
# F-score [0.97934841 0.27637511]
# Support [79322   614]
# **************************************
# Iteration number   96
# Class weights  {0: 1, 1: 96}
# Performance on validation data - Confusion matrix
# [[76089  3233]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998686 0.15938638]
# Recall [0.95924208 0.99837134]
# F-score [0.9791908  0.27488789]
# Support [79322   614]
# **************************************
# Iteration number   97
# Class weights  {0: 1, 1: 97}
# Performance on validation data - Confusion matrix
# [[76059  3263]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998685 0.15815273]
# Recall [0.95886387 0.99837134]
# F-score [0.97899371 0.27305122]
# Support [79322   614]
# **************************************
# Iteration number   98
# Class weights  {0: 1, 1: 98}
# Performance on validation data - Confusion matrix
# [[76039  3283]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998685 0.15734086]
# Recall [0.95861173 0.99837134]
# F-score [0.97886227 0.27184035]
# Support [79322   614]
# **************************************
# Iteration number   99
# Class weights  {0: 1, 1: 99}
# Performance on validation data - Confusion matrix
# [[76012  3310]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998684 0.15625797]
# Recall [0.95827135 0.99837134]
# F-score [0.97868478 0.27022261]
# Support [79322   614]
# **************************************
# Iteration number   100
# Class weights  {0: 1, 1: 100}
# Performance on validation data - Confusion matrix
# [[75984  3338]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998684 0.15515059]
# Recall [0.95791836 0.99837134]
# F-score [0.97850065 0.26856517]
# Support [79322   614]
# **************************************
# Iteration number   101
# Class weights  {0: 1, 1: 101}
# Performance on validation data - Confusion matrix
# [[75962  3360]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998684 0.15429147]
# Recall [0.95764101 0.99837134]
# F-score [0.97835593 0.26727709]
# Support [79322   614]
# **************************************
# Iteration number   102
# Class weights  {0: 1, 1: 102}
# Performance on validation data - Confusion matrix
# [[75938  3384]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998683 0.15336502]
# Recall [0.95733844 0.99837134]
# F-score [0.978198   0.26588592]
# Support [79322   614]
# **************************************
# Iteration number   103
# Class weights  {0: 1, 1: 103}
# Performance on validation data - Confusion matrix
# [[75915  3407]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998683 0.15248756]
# Recall [0.95704849 0.99837134]
# F-score [0.97804661 0.26456625]
# Support [79322   614]
# **************************************
# Iteration number   104
# Class weights  {0: 1, 1: 104}
# Performance on validation data - Confusion matrix
# [[75890  3432]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998682 0.15154512]
# Recall [0.95673331 0.99837134]
# F-score [0.97788201 0.2631466 ]
# Support [79322   614]
# **************************************
# Iteration number   105
# Class weights  {0: 1, 1: 105}
# Performance on validation data - Confusion matrix
# [[75856  3466]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998682 0.15028193]
# Recall [0.95630468 0.99837134]
# F-score [0.97765806 0.26124014]
# Support [79322   614]
# **************************************
# Iteration number   106
# Class weights  {0: 1, 1: 106}
# Performance on validation data - Confusion matrix
# [[75827  3495]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998681 0.14922103]
# Recall [0.95593908 0.99837134]
# F-score [0.97746697 0.25963575]
# Support [79322   614]
# **************************************
# Iteration number   107
# Class weights  {0: 1, 1: 107}
# Performance on validation data - Confusion matrix
# [[75805  3517]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998681 0.14842615]
# Recall [0.95566173 0.99837134]
# F-score [0.97732195 0.2584317 ]
# Support [79322   614]
# **************************************
# Iteration number   108
# Class weights  {0: 1, 1: 108}
# Performance on validation data - Confusion matrix
# [[75788  3534]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998681 0.1478177 ]
# Recall [0.95544742 0.99837134]
# F-score [0.97720987 0.25750893]
# Support [79322   614]
# **************************************
# Iteration number   109
# Class weights  {0: 1, 1: 109}
# Performance on validation data - Confusion matrix
# [[75758  3564]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999868  0.14675605]
# Recall [0.95506921 0.99837134]
# F-score [0.97701201 0.25589647]
# Support [79322   614]
# **************************************
# Iteration number   110
# Class weights  {0: 1, 1: 110}
# Performance on validation data - Confusion matrix
# [[75729  3593]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999868  0.14574417]
# Recall [0.95470361 0.99837134]
# F-score [0.97682068 0.25435685]
# Support [79322   614]
# **************************************
# Iteration number   111
# Class weights  {0: 1, 1: 111}
# Performance on validation data - Confusion matrix
# [[75704  3618]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998679 0.14488301]
# Recall [0.95438844 0.99837134]
# F-score [0.97665568 0.25304438]
# Support [79322   614]
# **************************************
# Iteration number   112
# Class weights  {0: 1, 1: 112}
# Performance on validation data - Confusion matrix
# [[75687  3635]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998679 0.1443032 ]
# Recall [0.95417413 0.99837134]
# F-score [0.97654345 0.25215961]
# Support [79322   614]
# **************************************
# Iteration number   113
# Class weights  {0: 1, 1: 113}
# Performance on validation data - Confusion matrix
# [[75668  3654]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998678 0.14366065]
# Recall [0.9539346  0.99837134]
# F-score [0.97641799 0.25117804]
# Support [79322   614]
# **************************************
# Iteration number   114
# Class weights  {0: 1, 1: 114}
# Performance on validation data - Confusion matrix
# [[75640  3682]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998678 0.1427241 ]
# Recall [0.9535816  0.99837134]
# F-score [0.97623304 0.24974537]
# Support [79322   614]
# **************************************
# Iteration number   115
# Class weights  {0: 1, 1: 115}
# Performance on validation data - Confusion matrix
# [[75622  3700]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998678 0.14212845]
# Recall [0.95335468 0.99837134]
# F-score [0.97611411 0.24883296]
# Support [79322   614]
# **************************************
# Iteration number   116
# Class weights  {0: 1, 1: 116}
# Performance on validation data - Confusion matrix
# [[75603  3719]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998677 0.14150508]
# Recall [0.95311515 0.99837134]
# F-score [0.97598854 0.24787707]
# Support [79322   614]
# **************************************
# Iteration number   117
# Class weights  {0: 1, 1: 117}
# Performance on validation data - Confusion matrix
# [[75584  3738]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998677 0.14088715]
# Recall [0.95287562 0.99837134]
# F-score [0.97586294 0.2469285 ]
# Support [79322   614]
# **************************************
# Iteration number   118
# Class weights  {0: 1, 1: 118}
# Performance on validation data - Confusion matrix
# [[75560  3762]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998677 0.14011429]
# Recall [0.95257306 0.99837134]
# F-score [0.97570424 0.24574063]
# Support [79322   614]
# **************************************
# Iteration number   119
# Class weights  {0: 1, 1: 119}
# Performance on validation data - Confusion matrix
# [[75539  3783]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998676 0.13944495]
# Recall [0.95230831 0.99837134]
# F-score [0.97556534 0.24471058]
# Support [79322   614]
# **************************************
# Iteration number   120
# Class weights  {0: 1, 1: 120}
# Performance on validation data - Confusion matrix
# [[75516  3806]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998676 0.13871917]
# Recall [0.95201836 0.99837134]
# F-score [0.97541317 0.24359229]
# Support [79322   614]
# **************************************
# Iteration number   121
# Class weights  {0: 1, 1: 121}
# Performance on validation data - Confusion matrix
# [[75488  3834]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998675 0.13784574]
# Recall [0.95166536 0.99837134]
# F-score [0.97522786 0.24224462]
# Support [79322   614]
# **************************************
# Iteration number   122
# Class weights  {0: 1, 1: 122}
# Performance on validation data - Confusion matrix
# [[75460  3862]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998675 0.13698324]
# Recall [0.95131237 0.99837134]
# F-score [0.97504248 0.24091177]
# Support [79322   614]
# **************************************
# Iteration number   123
# Class weights  {0: 1, 1: 123}
# Performance on validation data - Confusion matrix
# [[75434  3888]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998674 0.13619196]
# Recall [0.95098459 0.99837134]
# F-score [0.97487028 0.23968719]
# Support [79322   614]
# **************************************
# Iteration number   124
# Class weights  {0: 1, 1: 124}
# Performance on validation data - Confusion matrix
# [[75412  3910]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998674 0.13552952]
# Recall [0.95070724 0.99837134]
# F-score [0.97472453 0.2386607 ]
# Support [79322   614]
# **************************************
# Iteration number   125
# Class weights  {0: 1, 1: 125}
# Performance on validation data - Confusion matrix
# [[75391  3931]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998674 0.13490317]
# Recall [0.9504425  0.99837134]
# F-score [0.97458536 0.23768903]
# Support [79322   614]
# **************************************
# Iteration number   126
# Class weights  {0: 1, 1: 126}
# Performance on validation data - Confusion matrix
# [[75371  3951]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998673 0.13431201]
# Recall [0.95019036 0.99837134]
# F-score [0.97445279 0.23677095]
# Support [79322   614]
# **************************************
# Iteration number   127
# Class weights  {0: 1, 1: 127}
# Performance on validation data - Confusion matrix
# [[75356  3966]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998673 0.13387202]
# Recall [0.95000126 0.99837134]
# F-score [0.97435334 0.23608704]
# Support [79322   614]
# **************************************
# Iteration number   128
# Class weights  {0: 1, 1: 128}
# Performance on validation data - Confusion matrix
# [[75333  3989]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998673 0.13320296]
# Recall [0.9497113  0.99837134]
# F-score [0.97420081 0.23504601]
# Support [79322   614]
# **************************************
# Iteration number   129
# Class weights  {0: 1, 1: 129}
# Performance on validation data - Confusion matrix
# [[75304  4018]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998672 0.13236882]
# Recall [0.9493457  0.99837134]
# F-score [0.97400842 0.23374643]
# Support [79322   614]
# **************************************
# Iteration number   130
# Class weights  {0: 1, 1: 130}
# Performance on validation data - Confusion matrix
# [[75280  4042]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998672 0.13168636]
# Recall [0.94904314 0.99837134]
# F-score [0.97384915 0.23268172]
# Support [79322   614]
# **************************************
# Iteration number   131
# Class weights  {0: 1, 1: 131}
# Performance on validation data - Confusion matrix
# [[75256  4066]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998671 0.1310109 ]
# Recall [0.94874058 0.99837134]
# F-score [0.97368983 0.23162668]
# Support [79322   614]
# **************************************
# Iteration number   132
# Class weights  {0: 1, 1: 132}
# Performance on validation data - Confusion matrix
# [[75233  4089]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998671 0.13037006]
# Recall [0.94845062 0.99837134]
# F-score [0.9735371  0.23062453]
# Support [79322   614]
# **************************************
# Iteration number   133
# Class weights  {0: 1, 1: 133}
# Performance on validation data - Confusion matrix
# [[75213  4109]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999867  0.12981787]
# Recall [0.94819848 0.99837134]
# F-score [0.97340426 0.22976012]
# Support [79322   614]
# **************************************
# Iteration number   134
# Class weights  {0: 1, 1: 134}
# Performance on validation data - Confusion matrix
# [[75196  4126]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999867  0.12935218]
# Recall [0.94798417 0.99837134]
# F-score [0.97329131 0.22903045]
# Support [79322   614]
# **************************************
# Iteration number   135
# Class weights  {0: 1, 1: 135}
# Performance on validation data - Confusion matrix
# [[75167  4155]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.9999867  0.12856544]
# Recall [0.94761857 0.99837134]
# F-score [0.97309858 0.22779636]
# Support [79322   614]
# **************************************
# Iteration number   136
# Class weights  {0: 1, 1: 136}
# Performance on validation data - Confusion matrix
# [[75142  4180]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998669 0.12789485]
# Recall [0.9473034  0.99837134]
# F-score [0.97293238 0.22674311]
# Support [79322   614]
# **************************************
# Iteration number   137
# Class weights  {0: 1, 1: 137}
# Performance on validation data - Confusion matrix
# [[75120  4202]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998669 0.12731049]
# Recall [0.94702605 0.99837134]
# F-score [0.97278608 0.22582428]
# Support [79322   614]
# **************************************
# Iteration number   138
# Class weights  {0: 1, 1: 138}
# Performance on validation data - Confusion matrix
# [[75098  4224]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# Precision [0.99998668 0.12673145]
# Recall [0.9467487  0.99837134]
# F-score [0.97263973 0.22491286]
# Support [79322   614]
# **************************************
# Iteration number   139
# Class weights  {0: 1, 1: 139}
# Performance on validation data - Confusion matrix
# [[75081  4241]
#  [    1   613]]
# Precision, Recall, F-score, Support on validation data
# ...
# F-score [0.94409797 0.12755791]
# Support [79322   614]
# **************************************
# Iteration number   455
# Class weights  {0: 1, 1: 455}
# Performance on validation data - Confusion matrix
# [[70915  8407]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06806341]
# Recall [0.89401427 1.        ]
# F-score [0.94404175 0.127452  ]
# Support [79322   614]
# **************************************
# Iteration number   456
# Class weights  {0: 1, 1: 456}
# Performance on validation data - Confusion matrix
# [[70907  8415]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.        0.0680031]
# Recall [0.89391342 1.        ]
# F-score [0.94398552 0.12734626]
# Support [79322   614]
# **************************************
# Iteration number   457
# Class weights  {0: 1, 1: 457}
# Performance on validation data - Confusion matrix
# [[70897  8425]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06792787]
# Recall [0.89378735 1.        ]
# F-score [0.94391522 0.12721434]
# Support [79322   614]
# **************************************
# Iteration number   458
# Class weights  {0: 1, 1: 458}
# Performance on validation data - Confusion matrix
# [[70887  8435]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.        0.0678528]
# Recall [0.89366128 1.        ]
# F-score [0.94384491 0.12708269]
# Support [79322   614]
# **************************************
# Iteration number   459
# Class weights  {0: 1, 1: 459}
# Performance on validation data - Confusion matrix
# [[70878  8444]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06778538]
# Recall [0.89354782 1.        ]
# F-score [0.94378162 0.12696443]
# Support [79322   614]
# **************************************
# Iteration number   460
# Class weights  {0: 1, 1: 460}
# Performance on validation data - Confusion matrix
# [[70869  8453]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.        0.0677181]
# Recall [0.89343436 1.        ]
# F-score [0.94371833 0.1268464 ]
# Support [79322   614]
# **************************************
# Iteration number   461
# Class weights  {0: 1, 1: 461}
# Performance on validation data - Confusion matrix
# [[70864  8458]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06768078]
# Recall [0.89337132 1.        ]
# F-score [0.94368317 0.12678092]
# Support [79322   614]
# **************************************
# Iteration number   462
# Class weights  {0: 1, 1: 462}
# Performance on validation data - Confusion matrix
# [[70851  8471]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06758393]
# Recall [0.89320743 1.        ]
# F-score [0.94359172 0.12661099]
# Support [79322   614]
# **************************************
# Iteration number   463
# Class weights  {0: 1, 1: 463}
# Performance on validation data - Confusion matrix
# [[70846  8476]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06754675]
# Recall [0.8931444 1.       ]
# F-score [0.94355655 0.12654575]
# Support [79322   614]
# **************************************
# Iteration number   464
# Class weights  {0: 1, 1: 464}
# Performance on validation data - Confusion matrix
# [[70840  8482]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.        0.0675022]
# Recall [0.89306876 1.        ]
# F-score [0.94351434 0.12646756]
# Support [79322   614]
# **************************************
# Iteration number   465
# Class weights  {0: 1, 1: 465}
# Performance on validation data - Confusion matrix
# [[70829  8493]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06742067]
# Recall [0.89293008 1.        ]
# F-score [0.94343694 0.12632445]
# Support [79322   614]
# **************************************
# Iteration number   466
# Class weights  {0: 1, 1: 466}
# Performance on validation data - Confusion matrix
# [[70820  8502]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.        0.0673541]
# Recall [0.89281662 1.        ]
# F-score [0.94337361 0.12620761]
# Support [79322   614]
# **************************************
# Iteration number   467
# Class weights  {0: 1, 1: 467}
# Performance on validation data - Confusion matrix
# [[70805  8517]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06724346]
# Recall [0.89262752 1.        ]
# F-score [0.94326803 0.12601334]
# Support [79322   614]
# **************************************
# Iteration number   468
# Class weights  {0: 1, 1: 468}
# Performance on validation data - Confusion matrix
# [[70798  8524]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06719195]
# Recall [0.89253927 1.        ]
# F-score [0.94321876 0.12592289]
# Support [79322   614]
# **************************************
# Iteration number   469
# Class weights  {0: 1, 1: 469}
# Performance on validation data - Confusion matrix
# [[70790  8532]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06713317]
# Recall [0.89243842 1.        ]
# F-score [0.94316244 0.12581967]
# Support [79322   614]
# **************************************
# Iteration number   470
# Class weights  {0: 1, 1: 470}
# Performance on validation data - Confusion matrix
# [[70784  8538]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06708916]
# Recall [0.89236277 1.        ]
# F-score [0.9431202  0.12574237]
# Support [79322   614]
# **************************************
# Iteration number   471
# Class weights  {0: 1, 1: 471}
# Performance on validation data - Confusion matrix
# [[70776  8546]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06703057]
# Recall [0.89226192 1.        ]
# F-score [0.94306386 0.12563945]
# Support [79322   614]
# **************************************
# Iteration number   472
# Class weights  {0: 1, 1: 472}
# Performance on validation data - Confusion matrix
# [[70770  8552]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06698669]
# Recall [0.89218628 1.        ]
# F-score [0.94302161 0.12556237]
# Support [79322   614]
# **************************************
# Iteration number   473
# Class weights  {0: 1, 1: 473}
# Performance on validation data - Confusion matrix
# [[70754  8568]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06686996]
# Recall [0.89198457 1.        ]
# F-score [0.94290893 0.12535729]
# Support [79322   614]
# **************************************
# Iteration number   474
# Class weights  {0: 1, 1: 474}
# Performance on validation data - Confusion matrix
# [[70745  8577]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06680448]
# Recall [0.89187111 1.        ]
# F-score [0.94284553 0.12524222]
# Support [79322   614]
# **************************************
# Iteration number   475
# Class weights  {0: 1, 1: 475}
# Performance on validation data - Confusion matrix
# [[70738  8584]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06675364]
# Recall [0.89178286 1.        ]
# F-score [0.94279621 0.12515287]
# Support [79322   614]
# **************************************
# Iteration number   476
# Class weights  {0: 1, 1: 476}
# Performance on validation data - Confusion matrix
# [[70729  8593]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06668839]
# Recall [0.8916694 1.       ]
# F-score [0.9427328  0.12503818]
# Support [79322   614]
# **************************************
# Iteration number   477
# Class weights  {0: 1, 1: 477}
# Performance on validation data - Confusion matrix
# [[70723  8599]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06664496]
# Recall [0.89159376 1.        ]
# F-score [0.94269053 0.12496184]
# Support [79322   614]
# **************************************
# Iteration number   478
# Class weights  {0: 1, 1: 478}
# Performance on validation data - Confusion matrix
# [[70714  8608]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06657992]
# Recall [0.8914803 1.       ]
# F-score [0.9426271 0.1248475]
# Support [79322   614]
# **************************************
# Iteration number   479
# Class weights  {0: 1, 1: 479}
# Performance on validation data - Confusion matrix
# [[70705  8617]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.       0.066515]
# Recall [0.89136683 1.        ]
# F-score [0.94256367 0.12473337]
# Support [79322   614]
# **************************************
# Iteration number   480
# Class weights  {0: 1, 1: 480}
# Performance on validation data - Confusion matrix
# [[70694  8628]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06643584]
# Recall [0.89122816 1.        ]
# F-score [0.94248613 0.12459416]
# Support [79322   614]
# **************************************
# Iteration number   481
# Class weights  {0: 1, 1: 481}
# Performance on validation data - Confusion matrix
# [[70684  8638]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06636403]
# Recall [0.89110209 1.        ]
# F-score [0.94241564 0.12446787]
# Support [79322   614]
# **************************************
# Iteration number   482
# Class weights  {0: 1, 1: 482}
# Performance on validation data - Confusion matrix
# [[70669  8653]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06625661]
# Recall [0.89091299 1.        ]
# F-score [0.94230987 0.12427892]
# Support [79322   614]
# **************************************
# Iteration number   483
# Class weights  {0: 1, 1: 483}
# Performance on validation data - Confusion matrix
# [[70663  8659]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06621374]
# Recall [0.89083735 1.        ]
# F-score [0.94226756 0.1242035 ]
# Support [79322   614]
# **************************************
# Iteration number   484
# Class weights  {0: 1, 1: 484}
# Performance on validation data - Confusion matrix
# [[70656  8666]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06616379]
# Recall [0.8907491 1.       ]
# F-score [0.94221819 0.12411563]
# Support [79322   614]
# **************************************
# Iteration number   485
# Class weights  {0: 1, 1: 485}
# Performance on validation data - Confusion matrix
# [[70651  8671]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06612816]
# Recall [0.89068606 1.        ]
# F-score [0.94218293 0.12405293]
# Support [79322   614]
# **************************************
# Iteration number   486
# Class weights  {0: 1, 1: 486}
# Performance on validation data - Confusion matrix
# [[70645  8677]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06608546]
# Recall [0.89061042 1.        ]
# F-score [0.9421406  0.12397779]
# Support [79322   614]
# **************************************
# Iteration number   487
# Class weights  {0: 1, 1: 487}
# Performance on validation data - Confusion matrix
# [[70635  8687]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06601441]
# Recall [0.89048435 1.        ]
# F-score [0.94207006 0.12385275]
# Support [79322   614]
# **************************************
# Iteration number   488
# Class weights  {0: 1, 1: 488}
# Performance on validation data - Confusion matrix
# [[70626  8696]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06595059]
# Recall [0.89037089 1.        ]
# F-score [0.94200656 0.12374043]
# Support [79322   614]
# **************************************
# Iteration number   489
# Class weights  {0: 1, 1: 489}
# Performance on validation data - Confusion matrix
# [[70615  8707]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06587276]
# Recall [0.89023222 1.        ]
# F-score [0.94192894 0.12360342]
# Support [79322   614]
# **************************************
# Iteration number   490
# Class weights  {0: 1, 1: 490}
# Performance on validation data - Confusion matrix
# [[70601  8721]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06577397]
# Recall [0.89005572 1.        ]
# F-score [0.94183014 0.12342949]
# Support [79322   614]
# **************************************
# Iteration number   491
# Class weights  {0: 1, 1: 491}
# Performance on validation data - Confusion matrix
# [[70589  8733]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06568953]
# Recall [0.88990444 1.        ]
# F-score [0.94174544 0.1232808 ]
# Support [79322   614]
# **************************************
# Iteration number   492
# Class weights  {0: 1, 1: 492}
# Performance on validation data - Confusion matrix
# [[70579  8743]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06561932]
# Recall [0.88977837 1.        ]
# F-score [0.94167484 0.12315716]
# Support [79322   614]
# **************************************
# Iteration number   493
# Class weights  {0: 1, 1: 493}
# Performance on validation data - Confusion matrix
# [[70571  8751]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06556327]
# Recall [0.88967752 1.        ]
# F-score [0.94161835 0.12305842]
# Support [79322   614]
# **************************************
# Iteration number   494
# Class weights  {0: 1, 1: 494}
# Performance on validation data - Confusion matrix
# [[70559  8763]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06547936]
# Recall [0.88952623 1.        ]
# F-score [0.94153362 0.12291062]
# Support [79322   614]
# **************************************
# Iteration number   495
# Class weights  {0: 1, 1: 495}
# Performance on validation data - Confusion matrix
# [[70546  8776]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06538871]
# Recall [0.88936235 1.        ]
# F-score [0.9414418 0.1227509]
# Support [79322   614]
# **************************************
# Iteration number   496
# Class weights  {0: 1, 1: 496}
# Performance on validation data - Confusion matrix
# [[70532  8790]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06529137]
# Recall [0.88918585 1.        ]
# F-score [0.94134291 0.12257936]
# Support [79322   614]
# **************************************
# Iteration number   497
# Class weights  {0: 1, 1: 497}
# Performance on validation data - Confusion matrix
# [[70527  8795]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06525667]
# Recall [0.88912282 1.        ]
# F-score [0.94130758 0.12251821]
# Support [79322   614]
# **************************************
# Iteration number   498
# Class weights  {0: 1, 1: 498}
# Performance on validation data - Confusion matrix
# [[70517  8805]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06518739]
# Recall [0.88899675 1.        ]
# F-score [0.94123693 0.12239609]
# Support [79322   614]
# **************************************
# Iteration number   499
# Class weights  {0: 1, 1: 499}
# Performance on validation data - Confusion matrix
# [[70504  8818]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06509754]
# Recall [0.88883286 1.        ]
# F-score [0.94114506 0.12223771]
# Support [79322   614]
# **************************************
# Iteration number   500
# Class weights  {0: 1, 1: 500}
# Performance on validation data - Confusion matrix
# [[70492  8830]
#  [    0   614]]
# Precision, Recall, F-score, Support on validation data
# Precision [1.         0.06501482]
# Recall [0.88868158 1.        ]
# F-score [0.94106025 0.12209187]
# Support [79322   614]
