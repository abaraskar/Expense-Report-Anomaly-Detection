# %%
import numpy as np
import pandas as pd
import csv
import sys
import os
  
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
import warnings
import pickle

max_iters = 101
#n_estimators = 10

def logreg(x,y,filename):

   # Model output file name
   file = (os.path.splitext(filename))[0]
   fname = './models/lr_' + file +'/'

   # File for writing precision,recall, f-measure scores for fraud transactions
   f = open('./prf/lr_'+ file + '_prf' +'.txt' ,'w')
   f.write('precision,recall,f-score \n')

   # Stratified sampling based on Y
   X_train, X_test, y_train, y_test = train_test_split(x, y,stratify=y , test_size=0.30, random_state=42)

   # Create 15% validation set and 15% test set split
   X_val, X_test, y_val, y_test = train_test_split(X_test, y_test,stratify=y_test , test_size=0.50, random_state=42)
   
   #Iterations
   it = 1
   
   # Run training algorithm for multiple class weights
   while it < max_iters:
       cw = {}
       cw[0] = 1
       cw[1] = it
       # Train
       print('**************************************')
       print("Iteration number  " , it)
       lr = LogisticRegression(class_weight = cw)
       print('Class weights ', cw)
       lr.fit(X_train,y_train)

       # Save trained model to disk
       name = fname + str(cw[1]) + '.sav'
       pickle.dump(lr, open(name, 'wb'))

       # Predict on validation data
       y_val_pred = lr.predict(X_val)
       print('Performance on validation data - Confusion matrix')
       print(confusion_matrix(y_val,y_val_pred))
   
       precision,recall,fscore,support=score(y_val,y_val_pred,average=None)
       print('Precision, Recall, F-score, Support  on validation data' )
       print("Precision" , precision)
       print("Recall" , recall)
       print("F-score" , fscore)
       print("Support" , support)

       p1 = precision[1]
       r1 = recall[1]
       f1 = fscore[1]

       f.write(str(p1) +','+ str(r1) + ',' + str(f1) + '\n') 
       it += 1

   f.close()

def run():
   filename = 'm3.csv'
   df = pd.read_csv(filename, usecols = [9,10,11,12,13,14] , header = 0)
   
   results = list(map(int, df['Anomaly'])) 
   print('Number of fraudulent transactions ' , sum(results))

   features = ['Airfare', 'Lodging', 'Meals', 'Other_Transportation', 'Other_Expenses']
   targets = ['Anomaly']

   # Separating out the features and target variables
   x = df.loc[:, features].values
   y = df.loc[:, targets].values

   y  = [i for j in y for i in j]
   
   #Ignore warnings
   warnings.filterwarnings("ignore", category=FutureWarning)

   print("***********Logistic Regression**********")
   logreg(x,y,filename)
  
run()
# Out:
# Number of fraudulent transactions  4097
# ***********Logistic Regression**********
# **************************************
# Iteration number   1
# Class weights  {0: 1, 1: 1}
# Performance on validation data - Confusion matrix
# [[79277    45]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998739 0.93161094]
# Recall [0.99943269 0.99837134]
# F-score [0.99970996 0.96383648]
# Support [79322   614]
# **************************************
# Iteration number   2
# Class weights  {0: 1, 1: 2}
# Performance on validation data - Confusion matrix
# [[79264    58]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998738 0.91356185]
# Recall [0.9992688  0.99837134]
# F-score [0.99962796 0.9540856 ]
# Support [79322   614]
# **************************************
# Iteration number   3
# Class weights  {0: 1, 1: 3}
# Performance on validation data - Confusion matrix
# [[79247    75]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998738 0.89098837]
# Recall [0.99905449 0.99837134]
# F-score [0.99952072 0.94162826]
# Support [79322   614]
# **************************************
# Iteration number   4
# Class weights  {0: 1, 1: 4}
# Performance on validation data - Confusion matrix
# [[79230    92]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998738 0.86950355]
# Recall [0.99884017 0.99837134]
# F-score [0.99941345 0.92949204]
# Support [79322   614]
# **************************************
# Iteration number   5
# Class weights  {0: 1, 1: 5}
# Performance on validation data - Confusion matrix
# [[79220   102]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998738 0.85734266]
# Recall [0.9987141  0.99837134]
# F-score [0.99935033 0.92249812]
# Support [79322   614]
# **************************************
# Iteration number   6
# Class weights  {0: 1, 1: 6}
# Performance on validation data - Confusion matrix
# [[79214   108]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998738 0.85020804]
# Recall [0.99863846 0.99837134]
# F-score [0.99931246 0.91835206]
# Support [79322   614]
# **************************************
# Iteration number   7
# Class weights  {0: 1, 1: 7}
# Performance on validation data - Confusion matrix
# [[79207   115]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998738 0.84203297]
# Recall [0.99855021 0.99837134]
# F-score [0.99926828 0.91356185]
# Support [79322   614]
# **************************************
# Iteration number   8
# Class weights  {0: 1, 1: 8}
# Performance on validation data - Confusion matrix
# [[79197   125]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.83062331]
# Recall [0.99842414 0.99837134]
# F-score [0.99920515 0.90680473]
# Support [79322   614]
# **************************************
# Iteration number   9
# Class weights  {0: 1, 1: 9}
# Performance on validation data - Confusion matrix
# [[79192   130]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.82503365]
# Recall [0.99836111 0.99837134]
# F-score [0.99917358 0.90346352]
# Support [79322   614]
# **************************************
# Iteration number   10
# Class weights  {0: 1, 1: 10}
# Performance on validation data - Confusion matrix
# [[79185   137]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.81733333]
# Recall [0.99827286 0.99837134]
# F-score [0.99912938 0.89882698]
# Support [79322   614]
# **************************************
# Iteration number   11
# Class weights  {0: 1, 1: 11}
# Performance on validation data - Confusion matrix
# [[79181   141]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.81299735]
# Recall [0.99822244 0.99837134]
# F-score [0.99910412 0.89619883]
# Support [79322   614]
# **************************************
# Iteration number   12
# Class weights  {0: 1, 1: 12}
# Performance on validation data - Confusion matrix
# [[79179   143]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.81084656]
# Recall [0.99819722 0.99837134]
# F-score [0.99909149 0.89489051]
# Support [79322   614]
# **************************************
# Iteration number   13
# Class weights  {0: 1, 1: 13}
# Performance on validation data - Confusion matrix
# [[79178   144]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.80977543]
# Recall [0.99818461 0.99837134]
# F-score [0.99908518 0.89423778]
# Support [79322   614]
# **************************************
# Iteration number   14
# Class weights  {0: 1, 1: 14}
# Performance on validation data - Confusion matrix
# [[79177   145]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.80895916]
# Recall [0.99817201 1.        ]
# F-score [0.99908517 0.89439184]
# Support [79322   614]
# **************************************
# Iteration number   15
# Class weights  {0: 1, 1: 15}
# Performance on validation data - Confusion matrix
# [[79178   144]
#  [    0   614]]
# Precision, Recall, F-score, Support  on validation data
# Precision [1.         0.81002639]
# Recall [0.99818461 1.        ]
# F-score [0.99909148 0.89504373]
# Support [79322   614]
# **************************************
# Iteration number   16
# Class weights  {0: 1, 1: 16}
# Performance on validation data - Confusion matrix
# [[79176   146]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.80764163]
# Recall [0.9981594  0.99837134]
# F-score [0.99907255 0.89293518]
# Support [79322   614]
# **************************************
# Iteration number   17
# Class weights  {0: 1, 1: 17}
# Performance on validation data - Confusion matrix
# [[79171   151]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.80235602]
# Recall [0.99809637 0.99837134]
# F-score [0.99904097 0.88969521]
# Support [79322   614]
# **************************************
# Iteration number   18
# Class weights  {0: 1, 1: 18}
# Performance on validation data - Confusion matrix
# [[79170   152]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.80130719]
# Recall [0.99808376 0.99837134]
# F-score [0.99903466 0.88905004]
# Support [79322   614]
# **************************************
# Iteration number   19
# Class weights  {0: 1, 1: 19}
# Performance on validation data - Confusion matrix
# [[79169   153]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.8002611 ]
# Recall [0.99807115 0.99837134]
# F-score [0.99902834 0.8884058 ]
# Support [79322   614]
# **************************************
# Iteration number   20
# Class weights  {0: 1, 1: 20}
# Performance on validation data - Confusion matrix
# [[79166   156]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.79713914]
# Recall [0.99803333 0.99837134]
# F-score [0.99900939 0.88647867]
# Support [79322   614]
# **************************************
# Iteration number   21
# Class weights  {0: 1, 1: 21}
# Performance on validation data - Confusion matrix
# [[79162   160]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0.79301423]
# Recall [0.99798291 0.99837134]
# F-score [0.99898413 0.88392213]
# Support [79322   614]
# **************************************
# Iteration number   22
# Class weights  {0: 1, 1: 22}
# Performance on validation data - Confusion matrix
# [[79160   162]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998737 0

#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998732 0.58159393]
# Recall [0.99444038 0.99837134]
# F-score [0.99720614 0.73501199]
# Support [79322   614]
# **************************************
# Iteration number   50
# Class weights  {0: 1, 1: 50}
# Performance on validation data - Confusion matrix
# [[78847   475]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998732 0.56341912]
# Recall [0.99401175 0.99837134]
# F-score [0.99699058 0.72032902]
# Support [79322   614]
# **************************************
# Iteration number   51
# Class weights  {0: 1, 1: 51}
# Performance on validation data - Confusion matrix
# [[78805   517]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998731 0.54247788]
# Recall [0.99348226 0.99837134]
# F-score [0.99672417 0.70298165]
# Support [79322   614]
# **************************************
# Iteration number   52
# Class weights  {0: 1, 1: 52}
# Performance on validation data - Confusion matrix
# [[78777   545]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998731 0.52936097]
# Recall [0.99312927 0.99837134]
# F-score [0.99654649 0.69187359]
# Support [79322   614]
# **************************************
# Iteration number   53
# Class weights  {0: 1, 1: 53}
# Performance on validation data - Confusion matrix
# [[78760   562]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9999873  0.52170213]
# Recall [0.99291495 0.99837134]
# F-score [0.99643858 0.68529905]
# Support [79322   614]
# **************************************
# Iteration number   54
# Class weights  {0: 1, 1: 54}
# Performance on validation data - Confusion matrix
# [[78740   582]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9999873  0.51297071]
# Recall [0.99266282 0.99837134]
# F-score [0.9963116 0.6777225]
# Support [79322   614]
# **************************************
# Iteration number   55
# Class weights  {0: 1, 1: 55}
# Performance on validation data - Confusion matrix
# [[78719   603]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9999873  0.50411184]
# Recall [0.99239807 0.99837134]
# F-score [0.99617823 0.66994536]
# Support [79322   614]
# **************************************
# Iteration number   56
# Class weights  {0: 1, 1: 56}
# Performance on validation data - Confusion matrix
# [[78702   620]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998729 0.49716139]
# Recall [0.99218376 0.99837134]
# F-score [0.99607024 0.6637791 ]
# Support [79322   614]
# **************************************
# Iteration number   57
# Class weights  {0: 1, 1: 57}
# Performance on validation data - Confusion matrix
# [[78685   637]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998729 0.4904    ]
# Recall [0.99196944 0.99837134]
# F-score [0.99596223 0.65772532]
# Support [79322   614]
# **************************************
# Iteration number   58
# Class weights  {0: 1, 1: 58}
# Performance on validation data - Confusion matrix
# [[78668   654]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998729 0.48382005]
# Recall [0.99175512 0.99837134]
# F-score [0.99585419 0.65178097]
# Support [79322   614]
# **************************************
# Iteration number   59
# Class weights  {0: 1, 1: 59}
# Performance on validation data - Confusion matrix
# [[78654   668]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998729 0.4785324 ]
# Recall [0.99157863 0.99837134]
# F-score [0.99576521 0.6469657 ]
# Support [79322   614]
# **************************************
# Iteration number   60
# Class weights  {0: 1, 1: 60}
# Performance on validation data - Confusion matrix
# [[78643   679]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998728 0.4744582 ]
# Recall [0.99143995 0.99837134]
# F-score [0.99569528 0.6432319 ]
# Support [79322   614]
# **************************************
# Iteration number   61
# Class weights  {0: 1, 1: 61}
# Performance on validation data - Confusion matrix
# [[78630   692]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998728 0.4697318 ]
# Recall [0.99127606 0.99837134]
# F-score [0.99561262 0.63887441]
# Support [79322   614]
# **************************************
# Iteration number   62
# Class weights  {0: 1, 1: 62}
# Performance on validation data - Confusion matrix
# [[78618   704]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998728 0.46545178]
# Recall [0.99112478 0.99837134]
# F-score [0.99553631 0.63490419]
# Support [79322   614]
# **************************************
# Iteration number   63
# Class weights  {0: 1, 1: 63}
# Performance on validation data - Confusion matrix
# [[78610   712]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998728 0.46264151]
# Recall [0.99102393 0.99837134]
# F-score [0.99548543 0.63228468]
# Support [79322   614]
# **************************************
# Iteration number   64
# Class weights  {0: 1, 1: 64}
# Performance on validation data - Confusion matrix
# [[78598   724]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998728 0.45848915]
# Recall [0.99087265 0.99837134]
# F-score [0.9954091  0.62839569]
# Support [79322   614]
# **************************************
# Iteration number   65
# Class weights  {0: 1, 1: 65}
# Performance on validation data - Confusion matrix
# [[78589   733]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998728 0.45542348]
# Recall [0.99075918 0.99837134]
# F-score [0.99535184 0.6255102 ]
# Support [79322   614]
# **************************************
# Iteration number   66
# Class weights  {0: 1, 1: 66}
# Performance on validation data - Confusion matrix
# [[78581   741]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.45273264]
# Recall [0.99065833 0.99837134]
# F-score [0.99530094 0.62296748]
# Support [79322   614]
# **************************************
# Iteration number   67
# Class weights  {0: 1, 1: 67}
# Performance on validation data - Confusion matrix
# [[78572   750]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.44974321]
# Recall [0.99054487 0.99837134]
# F-score [0.99524367 0.62013151]
# Support [79322   614]
# **************************************
# Iteration number   68
# Class weights  {0: 1, 1: 68}
# Performance on validation data - Confusion matrix
# [[78557   765]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.44484761]
# Recall [0.99035577 0.99837134]
# F-score [0.99514821 0.61546185]
# Support [79322   614]
# **************************************
# Iteration number   69
# Class weights  {0: 1, 1: 69}
# Performance on validation data - Confusion matrix
# [[78551   771]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.44291908]
# Recall [0.99028012 0.99837134]
# F-score [0.99511002 0.61361361]
# Support [79322   614]
# **************************************
# Iteration number   70
# Class weights  {0: 1, 1: 70}
# Performance on validation data - Confusion matrix
# [[78547   775]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.44164265]
# Recall [0.9902297  0.99837134]
# F-score [0.99508456 0.61238761]
# Support [79322   614]
# **************************************
# Iteration number   71
# Class weights  {0: 1, 1: 71}
# Performance on validation data - Confusion matrix
# [[78543   779]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.44037356]
# Recall [0.99017927 0.99837134]
# F-score [0.9950591 0.6111665]
# Support [79322   614]
# **************************************
# Iteration number   72
# Class weights  {0: 1, 1: 72}
# Performance on validation data - Confusion matrix
# [[78537   785]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.43848355]
# Recall [0.99010363 0.99837134]
# F-score [0.9950209  0.60934394]
# Support [79322   614]
# **************************************
# Iteration number   73
# Class weights  {0: 1, 1: 73}
# Performance on validation data - Confusion matrix
# [[78536   786]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.43817012]
# Recall [0.99009102 0.99837134]
# F-score [0.99501454 0.60904123]
# Support [79322   614]
# **************************************
# Iteration number   74
# Class weights  {0: 1, 1: 74}
# Performance on validation data - Confusion matrix
# [[78531   791]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.43660969]
# Recall [0.99002799 0.99837134]
# F-score [0.99498271 0.60753221]
# Support [79322   614]
# **************************************
# Iteration number   75
# Class weights  {0: 1, 1: 75}
# Performance on validation data - Confusion matrix
# [[78525   797]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998727 0.43475177]
# Recall [0.98995235 0.99837134]
# F-score [0.9949445  0.60573123]
# Support [79322   614]
# **************************************
# Iteration number   76
# Class weights  {0: 1, 1: 76}
# Performance on validation data - Confusion matrix
# [[78515   807]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998726 0.43169014]
# Recall [0.98982628 0.99837134]
# F-score [0.99488083 0.6027532 ]
# Support [79322   614]
# **************************************
# Iteration number   77
# Class weights  {0: 1, 1: 77}
# Performance on validation data - Confusion matrix
# [[78510   812]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998726 0.43017544]
# Recall [0.98976324 0.99837134]
# F-score [0.99484899 0.60127513]
# Support [79322   614]
# **************************************
# Iteration number   78
# Class weights  {0: 1, 1: 78}
# Performance on validation data - Confusion matrix
# [[78501   821]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998726 0.42747559]
# Recall [0.98964978 0.99837134]
# F-score [0.99479167 0.59863281]
# Support [79322   614]
# **************************************
# Iteration number   79
# Class weights  {0: 1, 1: 79}
# Performance on validation data - Confusion matrix
# [[78495   827]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998726 0.42569444]
# Recall [0.98957414 0.99837134]
# F-score [0.99475345 0.59688413]
# Support [79322   614]
# **************************************
# Iteration number   80
# Class weights  {0: 1, 1: 80}
# Performance on validation data - Confusion matrix
# [[78488   834]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998726 0.42363511]
# Recall [0.98948589 0.99837134]
# F-score [0.99470886 0.59485687]
# Support [79322   614]
# **************************************
# Iteration number   81
# Class weights  {0: 1, 1: 81}
# Performance on validation data - Confusion matrix
# [[78481   841]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998726 0.4215956 ]
# Recall [0.98939765 0.99837134]
# F-score [0.99466427 0.59284333]
# Support [79322   614]
# **************************************
# Iteration number   82
# Class weights  {0: 1, 1: 82}
# Performance on validation data - Confusion matrix
# [[78467   855]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998726 0.41757493]
# Recall [0.98922115 0.99837134]
# F-score [0.99457507 0.58885687]
# Support [79322   614]
# **************************************
# Iteration number   83
# Class weights  {0: 1, 1: 83}
# Performance on validation data - Confusion matrix
# [[78457   865]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.41474966]
# Recall [0.98909508 0.99837134]
# F-score [0.99451134 0.58604207]
# Support [79322   614]
# **************************************
# Iteration number   84
# Class weights  {0: 1, 1: 84}
# Performance on validation data - Confusion matrix
# [[78455   867]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.41418919]
# Recall [0.98906987 0.99837134]
# F-score [0.9944986  0.58548233]
# Support [79322   614]
# **************************************
# Iteration number   85
# Class weights  {0: 1, 1: 85}
# Performance on validation data - Confusion matrix
# [[78452   870]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.41335131]
# Recall [0.98903205 0.99837134]
# F-score [0.99447948 0.58464473]
# Support [79322   614]
# **************************************
# Iteration number   86
# Class weights  {0: 1, 1: 86}
# Performance on validation data - Confusion matrix
# [[78449   873]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.41251682]
# Recall [0.98899423 0.99837134]
# F-score [0.99446036 0.58380952]
# Support [79322   614]
# **************************************
# Iteration number   87
# Class weights  {0: 1, 1: 87}
# Performance on validation data - Confusion matrix
# [[78441   881]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.4103079 ]
# Recall [0.98889337 0.99837134]
# F-score [0.99440937 0.58159393]
# Support [79322   614]
# **************************************
# Iteration number   88
# Class weights  {0: 1, 1: 88}
# Performance on validation data - Confusion matrix
# [[78435   887]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.40866667]
# Recall [0.98881773 0.99837134]
# F-score [0.99437113 0.57994324]
# Support [79322   614]
# **************************************
# Iteration number   89
# Class weights  {0: 1, 1: 89}
# Performance on validation data - Confusion matrix
# [[78427   895]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.40649867]
# Recall [0.98871688 0.99837134]
# F-score [0.99432013 0.57775683]
# Support [79322   614]
# **************************************
# Iteration number   90
# Class weights  {0: 1, 1: 90}
# Performance on validation data - Confusion matrix
# [[78420   902]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.40462046]
# Recall [0.98862863 0.99837134]
# F-score [0.9942755  0.57585721]
# Support [79322   614]
# **************************************
# Iteration number   91
# Class weights  {0: 1, 1: 91}
# Performance on validation data - Confusion matrix
# [[78411   911]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.40223097]
# Recall [0.98851517 0.99837134]
# F-score [0.99421811 0.57343312]
# Support [79322   614]
# **************************************
# Iteration number   92
# Class weights  {0: 1, 1: 92}
# Performance on validation data - Confusion matrix
# [[78403   919]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998725 0.40013055]
# Recall [0.98841431 0.99837134]
# F-score [0.9941671  0.57129543]
# Support [79322   614]
# **************************************
# Iteration number   93
# Class weights  {0: 1, 1: 93}
# Performance on validation data - Confusion matrix
# [[78394   928]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998724 0.39779364]
# Recall [0.98830085 0.99837134]
# F-score [0.9941097  0.56890951]
# Support [79322   614]
# **************************************
# Iteration number   94
# Class weights  {0: 1, 1: 94}
# Performance on validation data - Confusion matrix
# [[78384   938]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998724 0.39522888]
# Recall [0.98817478 0.99837134]
# F-score [0.99404592 0.56628176]
# Support [79322   614]
# **************************************
# Iteration number   95
# Class weights  {0: 1, 1: 95}
# Performance on validation data - Confusion matrix
# [[78380   942]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998724 0.39421222]
# Recall [0.98812435 0.99837134]
# F-score [0.99402041 0.56523744]
# Support [79322   614]
# **************************************
# Iteration number   96
# Class weights  {0: 1, 1: 96}
# Performance on validation data - Confusion matrix
# [[78373   949]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998724 0.39244558]
# Recall [0.98803611 0.99837134]
# F-score [0.99397575 0.56341912]
# Support [79322   614]
# **************************************
# Iteration number   97
# Class weights  {0: 1, 1: 97}
# Performance on validation data - Confusion matrix
# [[78367   955]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998724 0.39094388]
# Recall [0.98796046 0.99837134]
# F-score [0.99393747 0.56186984]
# Support [79322   614]
# **************************************
# Iteration number   98
# Class weights  {0: 1, 1: 98}
# Performance on validation data - Confusion matrix
# [[78361   961]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998724 0.38945362]
# Recall [0.98788482 0.99837134]
# F-score [0.99389919 0.56032907]
# Support [79322   614]
# **************************************
# Iteration number   99
# Class weights  {0: 1, 1: 99}
# Performance on validation data - Confusion matrix
# [[78361   961]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998724 0.38945362]
# Recall [0.98788482 0.99837134]
# F-score [0.99389919 0.56032907]
# Support [79322   614]
# **************************************
# Iteration number   100
# Class weights  {0: 1, 1: 100}
# Performance on validation data - Confusion matrix
# [[78356   966]
#  [    1   613]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99998724 0.38822039]
# Recall [0.98782179 0.99837134]
# F-score [0.99386729 0.55905153]
# Support [79322   614]

# %%
file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-046c168df224> in <module>
# ----> 1 file
#
# NameError: name 'file' is not defined
