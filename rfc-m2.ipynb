# %%
import numpy as np
import pandas as pd
import csv
import sys
import os
  
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
import warnings
import pickle

from sklearn.ensemble import RandomForestClassifier

max_iters = 501
#n_estimators = 10

def rfc(x,y,filename):

   # Model output file name
   file = (os.path.splitext(filename))[0]
   fname = './models/rfc_' + file +'/'

   # File for writing precision,recall, f-measure scores for fraud transactions
   f = open('./prf/rfc_'+ file + '_prf' +'.txt' ,'w')
   f.write('precision,recall,f-score \n')

   # Stratified sampling based on Y
   X_train, X_test, y_train, y_test = train_test_split(x, y,stratify=y , test_size=0.30, random_state=42)

   # Create 15% validation set and 15% test set split
   X_val, X_test, y_val, y_test = train_test_split(X_test, y_test,stratify=y_test , test_size=0.50, random_state=42)
   
   #Iterations
   it = 1
   
   # Run training algorithm for multiple class weights
   while it < max_iters:
       cw = {}
       cw[0] = 1
       cw[1] = it
       # Train
       print('**************************************')
       print("Iteration number  " , it)
       rfc = RandomForestClassifier(n_jobs=2, random_state=0, class_weight = cw)
       #lr = LogisticRegression(class_weight = cw)
       print('Class weights ', cw)
       rfc.fit(X_train,y_train)

       # Save trained model to disk
       name = fname + str(cw[1]) + '.sav'
       pickle.dump(rfc, open(name, 'wb'))

       # Predict on validation data
       y_val_pred = rfc.predict(X_val)
       print('Performance on validation data - Confusion matrix')
       print(confusion_matrix(y_val,y_val_pred))
   
       precision,recall,fscore,support=score(y_val,y_val_pred,average=None)
       print('Precision, Recall, F-score, Support  on validation data' )
       print("Precision" , precision)
       print("Recall" , recall)
       print("F-score" , fscore)
       print("Support" , support)

       p1 = precision[1]
       r1 = recall[1]
       f1 = fscore[1]

       f.write(str(p1) +','+ str(r1) + ',' + str(f1) + '\n') 
       it += 1

   f.close()

def run():
   filename = 'm2.csv'
   df = pd.read_csv(filename, usecols = [9,10,11,12,13,14] , header = 0)
   
   results = list(map(int, df['Anomaly'])) 
   print('Number of fraudulent transactions ' , sum(results))

   features = ['Airfare', 'Lodging', 'Meals', 'Other_Transportation', 'Other_Expenses']
   targets = ['Anomaly']

   # Separating out the features and target variables
   x = df.loc[:, features].values
   y = df.loc[:, targets].values
    
   scaler = preprocessing.StandardScaler()
   x = scaler.fit_transform(x)    

   y  = [i for j in y for i in j]
   
   #Ignore warnings
   warnings.filterwarnings("ignore", category=FutureWarning)

   print("***********Logistic Regression**********")
   rfc(x,y,filename)
  
run()
# Out:
# Number of fraudulent transactions  4116
# ***********Logistic Regression**********
# **************************************
# Iteration number   1
# Class weights  {0: 1, 1: 1}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913501 0.91111111]
# Recall [0.99990448 0.53074434]
# F-score [0.9995196  0.67075665]
# Support [335007    618]
# **************************************
# Iteration number   2
# Class weights  {0: 1, 1: 2}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.89839572]
# Recall [0.99988657 0.54368932]
# F-score [0.99952257 0.67741935]
# Support [335007    618]
# **************************************
# Iteration number   3
# Class weights  {0: 1, 1: 3}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   287    331]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914394 0.89945652]
# Recall [0.99988955 0.53559871]
# F-score [0.99951661 0.67139959]
# Support [335007    618]
# **************************************
# Iteration number   4
# Class weights  {0: 1, 1: 4}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991648  0.89655172]
# Recall [0.99988358 0.54692557]
# F-score [0.99952406 0.67939698]
# Support [335007    618]
# **************************************
# Iteration number   5
# Class weights  {0: 1, 1: 5}
# Performance on validation data - Confusion matrix
# [[334964     43]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914691 0.88533333]
# Recall [0.99987164 0.53721683]
# F-score [0.99950914 0.66868077]
# Support [335007    618]
# **************************************
# Iteration number   6
# Class weights  {0: 1, 1: 6}
# Performance on validation data - Confusion matrix
# [[334965     42]
#  [   274    344]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99918267 0.89119171]
# Recall [0.99987463 0.5566343 ]
# F-score [0.99952853 0.68525896]
# Support [335007    618]
# **************************************
# Iteration number   7
# Class weights  {0: 1, 1: 7}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916481 0.91105121]
# Recall [0.99990149 0.54692557]
# F-score [0.99953302 0.68351871]
# Support [335007    618]
# **************************************
# Iteration number   8
# Class weights  {0: 1, 1: 8}
# Performance on validation data - Confusion matrix
# [[334965     42]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915287 0.88829787]
# Recall [0.99987463 0.54045307]
# F-score [0.99951362 0.67203219]
# Support [335007    618]
# **************************************
# Iteration number   9
# Class weights  {0: 1, 1: 9}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991648  0.89893617]
# Recall [0.99988657 0.54692557]
# F-score [0.99952555 0.68008048]
# Support [335007    618]
# **************************************
# Iteration number   10
# Class weights  {0: 1, 1: 10}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914097 0.90909091]
# Recall [0.99990149 0.53398058]
# F-score [0.99952109 0.67278287]
# Support [335007    618]
# **************************************
# Iteration number   11
# Class weights  {0: 1, 1: 11}
# Performance on validation data - Confusion matrix
# [[334967     40]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913797 0.89159892]
# Recall [0.9998806  0.53236246]
# F-score [0.99950915 0.66666667]
# Support [335007    618]
# **************************************
# Iteration number   12
# Class weights  {0: 1, 1: 12}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.9027027 ]
# Recall [0.99989254 0.54045307]
# F-score [0.99952257 0.67611336]
# Support [335007    618]
# **************************************
# Iteration number   13
# Class weights  {0: 1, 1: 13}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   293    325]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99912606 0.89779006]
# Recall [0.99988955 0.52588997]
# F-score [0.99950766 0.66326531]
# Support [335007    618]
# **************************************
# Iteration number   14
# Class weights  {0: 1, 1: 14}
# Performance on validation data - Confusion matrix
# [[334965     42]
#  [   274    344]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99918267 0.89119171]
# Recall [0.99987463 0.5566343 ]
# F-score [0.99952853 0.68525896]
# Support [335007    618]
# **************************************
# Iteration number   15
# Class weights  {0: 1, 1: 15}
# Performance on validation data - Confusion matrix
# [[334965     42]
#  [   274    344]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99918267 0.89119171]
# Recall [0.99987463 0.5566343 ]
# F-score [0.99952853 0.68525896]
# Support [335007    618]
# **************************************
# Iteration number   16
# Class weights  {0: 1, 1: 16}
# Performance on validation data - Confusion matrix
# [[334963     44]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991469  0.88297872]
# Recall [0.99986866 0.53721683]
# F-score [0.99950765 0.66800805]
# Support [335007    618]
# **************************************
# Iteration number   17
# Class weights  {0: 1, 1: 17}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915883 0.89124668]
# Recall [0.99987761 0.54368932]
# F-score [0.99951809 0.67537688]
# Support [335007    618]
# **************************************
# Iteration number   18
# Class weights  {0: 1, 1: 18}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914693 0.90710383]
# Recall [0.99989851 0.53721683]
# F-score [0.99952258 0.67479675]
# Support [335007    618]
# **************************************
# Iteration number   19
# Class weights  {0: 1, 1: 19}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   293    325]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99912605 0.89285714]
# Recall [0.99988358 0.52588997]
# F-score [0.99950468 0.66191446]
# Support [335007    618]
# **************************************
# Iteration number   20
# Class weights  {0: 1, 1: 20}
# Performance on validation data - Confusion matrix
# [[334976     31]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915886 0.91553134]
# Recall [0.99990746 0.54368932]
# F-score [0.99953302 0.6822335 ]
# Support [335007    618]
# **************************************
# Iteration number   21
# Class weights  {0: 1, 1: 21}
# Performance on validation data - Confusion matrix
# [[334965     42]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913499 0.88648649]
# Recall [0.99987463 0.53074434]
# F-score [0.99950467 0.66396761]
# Support [335007    618]
# **************************************
# Iteration number   22
# Class weights  {0: 1, 1: 22}
# Performance on validation data - Confusion matrix
# [[334960     47]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915882 0.8772846 ]
# Recall [0.9998597  0.54368932]
# F-score [0.99950914 0.67132867]
# Support [335007    618]
# **************************************
# Iteration number   23
# Class weights  {0: 1, 1: 23}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   273    345]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99918567 0.90551181]
# Recall [0.99989254 0.55825243]
# F-score [0.99953898 0.69069069]
# Support [335007    618]
# **************************************
# Iteration number   24
# Class weights  {0: 1, 1: 24}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   278    340]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917075 0.89238845]
# Recall [0.99987761 0.55016181]
# F-score [0.99952406 0.68068068]
# Support [335007    618]
# **************************************
# Iteration number   25
# Class weights  {0: 1, 1: 25}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914692 0.89487871]
# Recall [0.99988358 0.53721683]
# F-score [0.99951511 0.67138524]
# Support [335007    618]
# **************************************
# Iteration number   26
# Class weights  {0: 1, 1: 26}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914096 0.90163934]
# Recall [0.99989254 0.53398058]
# F-score [0.99951661 0.67073171]
# Support [335007    618]
# **************************************
# Iteration number   27
# Class weights  {0: 1, 1: 27}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   293    325]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99912607 0.90529248]
# Recall [0.99989851 0.52588997]
# F-score [0.99951214 0.66530194]
# Support [335007    618]
# **************************************
# Iteration number   28
# Class weights  {0: 1, 1: 28}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991648  0.89893617]
# Recall [0.99988657 0.54692557]
# F-score [0.99952555 0.68008048]
# Support [335007    618]
# **************************************
# Iteration number   29
# Class weights  {0: 1, 1: 29}
# Performance on validation data - Confusion matrix
# [[334964     43]
#  [   277    341]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917373 0.88802083]
# Recall [0.99987164 0.55177994]
# F-score [0.99952256 0.68063872]
# Support [335007    618]
# **************************************
# Iteration number   30
# Class weights  {0: 1, 1: 30}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   287    331]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914393 0.88978495]
# Recall [0.99987761 0.53559871]
# F-score [0.99951064 0.66868687]
# Support [335007    618]
# **************************************
# Iteration number   31
# Class weights  {0: 1, 1: 31}
# Performance on validation data - Confusion matrix
# [[334960     47]
#  [   291    327]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913199 0.87433155]
# Recall [0.9998597  0.52912621]
# F-score [0.99949572 0.65927419]
# Support [335007    618]
# **************************************
# Iteration number   32
# Class weights  {0: 1, 1: 32}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   292    326]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99912904 0.90304709]
# Recall [0.99989552 0.52750809]
# F-score [0.99951214 0.6659857 ]
# Support [335007    618]
# **************************************
# Iteration number   33
# Class weights  {0: 1, 1: 33}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   291    327]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913201 0.88858696]
# Recall [0.99987761 0.52912621]
# F-score [0.99950467 0.663286  ]
# Support [335007    618]
# **************************************
# Iteration number   34
# Class weights  {0: 1, 1: 34}
# Performance on validation data - Confusion matrix
# [[334967     40]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913499 0.89130435]
# Recall [0.9998806  0.53074434]
# F-score [0.99950766 0.6653144 ]
# Support [335007    618]
# **************************************
# Iteration number   35
# Class weights  {0: 1, 1: 35}
# Performance on validation data - Confusion matrix
# [[334978     29]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915886 0.92054795]
# Recall [0.99991343 0.54368932]
# F-score [0.99953601 0.68362157]
# Support [335007    618]
# **************************************
# Iteration number   36
# Class weights  {0: 1, 1: 36}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914097 0.91160221]
# Recall [0.99990448 0.53398058]
# F-score [0.99952258 0.67346939]
# Support [335007    618]
# **************************************
# Iteration number   37
# Class weights  {0: 1, 1: 37}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   285    333]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914991 0.90735695]
# Recall [0.99989851 0.53883495]
# F-score [0.99952407 0.67614213]
# Support [335007    618]
# **************************************
# Iteration number   38
# Class weights  {0: 1, 1: 38}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.90322581]
# Recall [0.99989254 0.54368932]
# F-score [0.99952556 0.67878788]
# Support [335007    618]
# **************************************
# Iteration number   39
# Class weights  {0: 1, 1: 39}
# Performance on validation data - Confusion matrix
# [[334979     28]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913502 0.92134831]
# Recall [0.99991642 0.53074434]
# F-score [0.99952557 0.67351129]
# Support [335007    618]
# **************************************
# Iteration number   40
# Class weights  {0: 1, 1: 40}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   285    333]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991499  0.90243902]
# Recall [0.99989254 0.53883495]
# F-score [0.99952108 0.67477204]
# Support [335007    618]
# **************************************
# Iteration number   41
# Class weights  {0: 1, 1: 41}
# Performance on validation data - Confusion matrix
# [[334964     43]
#  [   285    333]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914989 0.8856383 ]
# Recall [0.99987164 0.53883495]
# F-score [0.99951063 0.67002012]
# Support [335007    618]
# **************************************
# Iteration number   42
# Class weights  {0: 1, 1: 42}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   279    339]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991678  0.91374663]
# Recall [0.99990448 0.54854369]
# F-score [0.999536   0.68554095]
# Support [335007    618]
# **************************************
# Iteration number   43
# Class weights  {0: 1, 1: 43}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.89839572]
# Recall [0.99988657 0.54368932]
# F-score [0.99952257 0.67741935]
# Support [335007    618]
# **************************************
# Iteration number   44
# Class weights  {0: 1, 1: 44}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991648  0.90374332]
# Recall [0.99989254 0.54692557]
# F-score [0.99952854 0.68145161]
# Support [335007    618]
# **************************************
# Iteration number   45
# Class weights  {0: 1, 1: 45}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   287    331]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914395 0.91184573]
# Recall [0.99990448 0.53559871]
# F-score [0.99952407 0.67482161]
# Support [335007    618]
# **************************************
# Iteration number   46
# Class weights  {0: 1, 1: 46}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   287    331]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914394 0.89945652]
# Recall [0.99988955 0.53559871]
# F-score [0.99951661 0.67139959]
# Support [335007    618]
# **************************************
# Iteration number   47
# Class weights  {0: 1, 1: 47}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914693 0.91208791]
# Recall [0.99990448 0.53721683]
# F-score [0.99952556 0.67617108]
# Support [335007    618]
# **************************************
# Iteration number   48
# Class weights  {0: 1, 1: 48}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   277    341]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917376 0.91420912]
# Recall [0.99990448 0.55177994]
# F-score [0.99953898 0.68819374]
# Support [335007    618]
# **************************************
# Iteration number   49
# Class weights  {0: 1, 1: 49}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   278    340]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917076 0.8994709 ]
# Recall [0.99988657 0.55016181]
# F-score [0.99952854 0.68273092]
# Support [335007    618]
# **************************************
# Iteration number   50
# Class weights  {0: 1, 1: 50}
# Performance on validation data - Confusion matrix
# [[334965     42]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915883 0.88888889]
# Recall [0.99987463 0.54368932]
# F-score [0.9995166 0.6746988]
# Support [335007    618]
# **************************************
# Iteration number   51
# Class weights  {0: 1, 1: 51}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   291    327]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913202 0.89835165]
# Recall [0.99988955 0.52912621]
# F-score [0.99951064 0.66598778]
# Support [335007    618]
# **************************************
# Iteration number   52
# Class weights  {0: 1, 1: 52}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913499 0.89373297]
# Recall [0.99988358 0.53074434]
# F-score [0.99950915 0.66598985]
# Support [335007    618]
# **************************************
# Iteration number   53
# Class weights  {0: 1, 1: 53}
# Performance on validation data - Confusion matrix
# [[334964     43]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914691 0.88533333]
# Recall [0.99987164 0.53721683]
# F-score [0.99950914 0.66868077]
# Support [335007    618]
# **************************************
# Iteration number   54
# Class weights  {0: 1, 1: 54}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914693 0.91208791]
# Recall [0.99990448 0.53721683]
# F-score [0.99952556 0.67617108]
# Support [335007    618]
# **************************************
# Iteration number   55
# Class weights  {0: 1, 1: 55}
# Performance on validation data - Confusion matrix
# [[334962     45]
#  [   295    323]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99912008 0.87771739]
# Recall [0.99986567 0.52265372]
# F-score [0.99949274 0.65517241]
# Support [335007    618]
# **************************************
# Iteration number   56
# Class weights  {0: 1, 1: 56}
# Performance on validation data - Confusion matrix
# [[334978     29]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914694 0.91966759]
# Recall [0.99991343 0.53721683]
# F-score [0.99953004 0.67824311]
# Support [335007    618]
# **************************************
# Iteration number   57
# Class weights  {0: 1, 1: 57}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.999135  0.9010989]
# Recall [0.99989254 0.53074434]
# F-score [0.99951363 0.66802444]
# Support [335007    618]
# **************************************
# Iteration number   58
# Class weights  {0: 1, 1: 58}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.9027027 ]
# Recall [0.99989254 0.54045307]
# F-score [0.99952257 0.67611336]
# Support [335007    618]
# **************************************
# Iteration number   59
# Class weights  {0: 1, 1: 59}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   281    337]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916183 0.9083558 ]
# Recall [0.99989851 0.54530744]
# F-score [0.99953003 0.68149646]
# Support [335007    618]
# **************************************
# Iteration number   60
# Class weights  {0: 1, 1: 60}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   277    341]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917375 0.90933333]
# Recall [0.99989851 0.55177994]
# F-score [0.999536   0.68680765]
# Support [335007    618]
# **************************************
# Iteration number   61
# Class weights  {0: 1, 1: 61}
# Performance on validation data - Confusion matrix
# [[334964     43]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914094 0.8847185 ]
# Recall [0.99987164 0.53398058]
# F-score [0.99950616 0.66599395]
# Support [335007    618]
# **************************************
# Iteration number   62
# Class weights  {0: 1, 1: 62}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915586 0.90053763]
# Recall [0.99988955 0.5420712 ]
# F-score [0.99952257 0.67676768]
# Support [335007    618]
# **************************************
# Iteration number   63
# Class weights  {0: 1, 1: 63}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   279    339]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916779 0.91129032]
# Recall [0.99990149 0.54854369]
# F-score [0.99953451 0.68484848]
# Support [335007    618]
# **************************************
# Iteration number   64
# Class weights  {0: 1, 1: 64}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   281    337]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916183 0.91081081]
# Recall [0.99990149 0.54530744]
# F-score [0.99953153 0.68218623]
# Support [335007    618]
# **************************************
# Iteration number   65
# Class weights  {0: 1, 1: 65}
# Performance on validation data - Confusion matrix
# [[334980     27]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915291 0.92520776]
# Recall [0.9999194  0.54045307]
# F-score [0.99953601 0.68232891]
# Support [335007    618]
# **************************************
# Iteration number   66
# Class weights  {0: 1, 1: 66}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   281    337]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916183 0.9083558 ]
# Recall [0.99989851 0.54530744]
# F-score [0.99953003 0.68149646]
# Support [335007    618]
# **************************************
# Iteration number   67
# Class weights  {0: 1, 1: 67}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   275    343]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917971 0.90740741]
# Recall [0.99989552 0.55501618]
# F-score [0.99953749 0.68875502]
# Support [335007    618]
# **************************************
# Iteration number   68
# Class weights  {0: 1, 1: 68}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916479 0.89182058]
# Recall [0.99987761 0.54692557]
# F-score [0.99952108 0.6780341 ]
# Support [335007    618]
# **************************************
# Iteration number   69
# Class weights  {0: 1, 1: 69}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   291    327]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913202 0.90082645]
# Recall [0.99989254 0.52912621]
# F-score [0.99951214 0.66666667]
# Support [335007    618]
# **************************************
# Iteration number   70
# Class weights  {0: 1, 1: 70}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915587 0.90785908]
# Recall [0.99989851 0.5420712 ]
# F-score [0.99952705 0.67882472]
# Support [335007    618]
# **************************************
# Iteration number   71
# Class weights  {0: 1, 1: 71}
# Performance on validation data - Confusion matrix
# [[334976     31]
#  [   278    340]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917078 0.91644205]
# Recall [0.99990746 0.55016181]
# F-score [0.99953899 0.6875632 ]
# Support [335007    618]
# **************************************
# Iteration number   72
# Class weights  {0: 1, 1: 72}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   281    337]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916183 0.9083558 ]
# Recall [0.99989851 0.54530744]
# F-score [0.99953003 0.68149646]
# Support [335007    618]
# **************************************
# Iteration number   73
# Class weights  {0: 1, 1: 73}
# Performance on validation data - Confusion matrix
# [[334965     42]
#  [   285    333]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914989 0.888     ]
# Recall [0.99987463 0.53883495]
# F-score [0.99951213 0.67069486]
# Support [335007    618]
# **************************************
# Iteration number   74
# Class weights  {0: 1, 1: 74}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914095 0.89430894]
# Recall [0.99988358 0.53398058]
# F-score [0.99951213 0.66869301]
# Support [335007    618]
# **************************************
# Iteration number   75
# Class weights  {0: 1, 1: 75}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   279    339]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916777 0.89210526]
# Recall [0.99987761 0.54854369]
# F-score [0.99952257 0.67935872]
# Support [335007    618]
# **************************************
# Iteration number   76
# Class weights  {0: 1, 1: 76}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915885 0.90566038]
# Recall [0.99989552 0.54368932]
# F-score [0.99952705 0.67947422]
# Support [335007    618]
# **************************************
# Iteration number   77
# Class weights  {0: 1, 1: 77}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   281    337]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916182 0.90106952]
# Recall [0.99988955 0.54530744]
# F-score [0.99952556 0.67943548]
# Support [335007    618]
# **************************************
# Iteration number   78
# Class weights  {0: 1, 1: 78}
# Performance on validation data - Confusion matrix
# [[334977     30]
#  [   285    333]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914992 0.91735537]
# Recall [0.99991045 0.53883495]
# F-score [0.99953004 0.67889908]
# Support [335007    618]
# **************************************
# Iteration number   79
# Class weights  {0: 1, 1: 79}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914692 0.8972973 ]
# Recall [0.99988657 0.53721683]
# F-score [0.99951661 0.67206478]
# Support [335007    618]
# **************************************
# Iteration number   80
# Class weights  {0: 1, 1: 80}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914693 0.90463215]
# Recall [0.99989552 0.53721683]
# F-score [0.99952108 0.67411168]
# Support [335007    618]
# **************************************
# Iteration number   81
# Class weights  {0: 1, 1: 81}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   272    346]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99918865 0.91052632]
# Recall [0.99989851 0.55987055]
# F-score [0.99954346 0.69338677]
# Support [335007    618]
# **************************************
# Iteration number   82
# Class weights  {0: 1, 1: 82}
# Performance on validation data - Confusion matrix
# [[334978     29]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991529  0.92011019]
# Recall [0.99991343 0.54045307]
# F-score [0.99953302 0.68093782]
# Support [335007    618]
# **************************************
# Iteration number   83
# Class weights  {0: 1, 1: 83}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   287    331]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914395 0.91184573]
# Recall [0.99990448 0.53559871]
# F-score [0.99952407 0.67482161]
# Support [335007    618]
# **************************************
# Iteration number   84
# Class weights  {0: 1, 1: 84}
# Performance on validation data - Confusion matrix
# [[334979     28]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914098 0.92178771]
# Recall [0.99991642 0.53398058]
# F-score [0.99952855 0.67622951]
# Support [335007    618]
# **************************************
# Iteration number   85
# Class weights  {0: 1, 1: 85}
# Performance on validation data - Confusion matrix
# [[334982     25]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914099 0.92957746]
# Recall [0.99992537 0.53398058]
# F-score [0.99953303 0.67831449]
# Support [335007    618]
# **************************************
# Iteration number   86
# Class weights  {0: 1, 1: 86}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914097 0.90909091]
# Recall [0.99990149 0.53398058]
# F-score [0.99952109 0.67278287]
# Support [335007    618]
# **************************************
# Iteration number   87
# Class weights  {0: 1, 1: 87}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915885 0.90810811]
# Recall [0.99989851 0.54368932]
# F-score [0.99952854 0.68016194]
# Support [335007    618]
# **************************************
# Iteration number   88
# Class weights  {0: 1, 1: 88}
# Performance on validation data - Confusion matrix
# [[334967     40]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915287 0.89304813]
# Recall [0.9998806  0.54045307]
# F-score [0.9995166 0.6733871]
# Support [335007    618]
# **************************************
# Iteration number   89
# Class weights  {0: 1, 1: 89}
# Performance on validation data - Confusion matrix
# [[334980     27]
#  [   279    339]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916781 0.92622951]
# Recall [0.9999194  0.54854369]
# F-score [0.99954346 0.68902439]
# Support [335007    618]
# **************************************
# Iteration number   90
# Class weights  {0: 1, 1: 90}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.90322581]
# Recall [0.99989254 0.54368932]
# F-score [0.99952556 0.67878788]
# Support [335007    618]
# **************************************
# Iteration number   91
# Class weights  {0: 1, 1: 91}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914692 0.899729  ]
# Recall [0.99988955 0.53721683]
# F-score [0.9995181  0.67274569]
# Support [335007    618]
# **************************************
# Iteration number   92
# Class weights  {0: 1, 1: 92}
# Performance on validation data - Confusion matrix
# [[334963     44]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991469  0.88297872]
# Recall [0.99986866 0.53721683]
# F-score [0.99950765 0.66800805]
# Support [335007    618]
# **************************************
# Iteration number   93
# Class weights  {0: 1, 1: 93}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916481 0.91105121]
# Recall [0.99990149 0.54692557]
# F-score [0.99953302 0.68351871]
# Support [335007    618]
# **************************************
# Iteration number   94
# Class weights  {0: 1, 1: 94}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   276    342]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917673 0.912     ]
# Recall [0.99990149 0.55339806]
# F-score [0.99953898 0.68882175]
# Support [335007    618]
# **************************************
# Iteration number   95
# Class weights  {0: 1, 1: 95}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   276    342]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917672 0.9       ]
# Recall [0.99988657 0.55339806]
# F-score [0.99953152 0.68537074]
# Support [335007    618]
# **************************************
# Iteration number   96
# Class weights  {0: 1, 1: 96}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   277    341]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917375 0.90933333]
# Recall [0.99989851 0.55177994]
# F-score [0.999536   0.68680765]
# Support [335007    618]
# **************************************
# Iteration number   97
# Class weights  {0: 1, 1: 97}
# Performance on validation data - Confusion matrix
# [[334964     43]
#  [   270    348]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99919459 0.89002558]
# Recall [0.99987164 0.5631068 ]
# F-score [0.999533   0.68979187]
# Support [335007    618]
# **************************************
# Iteration number   98
# Class weights  {0: 1, 1: 98}
# Performance on validation data - Confusion matrix
# [[334977     30]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916482 0.91847826]
# Recall [0.99991045 0.54692557]
# F-score [0.9995375  0.68559838]
# Support [335007    618]
# **************************************
# Iteration number   99
# Class weights  {0: 1, 1: 99}
# Performance on validation data - Confusion matrix
# [[334977     30]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916482 0.91847826]
# Recall [0.99991045 0.54692557]
# F-score [0.9995375  0.68559838]
# Support [335007    618]
# **************************************
# Iteration number   100
# Class weights  {0: 1, 1: 100}
# Performance on validation data - Confusion matrix
# [[334976     31]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915886 0.91553134]
# Recall [0.99990746 0.54368932]
# F-score [0.99953302 0.6822335 ]
# Support [335007    618]
# **************************************
# Iteration number   101
# Class weights  {0: 1, 1: 101}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916481 0.90860215]
# Recall [0.99989851 0.54692557]
# F-score [0.99953153 0.68282828]
# Support [335007    618]
# **************************************
# Iteration number   102
# Class weights  {0: 1, 1: 102}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   277    341]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917373 0.89267016]
# Recall [0.99987761 0.55177994]
# F-score [0.99952555 0.682     ]
# Support [335007    618]
# **************************************
# Iteration number   103
# Class weights  {0: 1, 1: 103}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914691 0.89008043]
# Recall [0.99987761 0.53721683]
# F-score [0.99951213 0.67003027]
# Support [335007    618]
# **************************************
# Iteration number   104
# Class weights  {0: 1, 1: 104}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.89544236]
# Recall [0.99988358 0.54045307]
# F-score [0.9995181 0.6740666]
# Support [335007    618]
# **************************************
# Iteration number   105
# Class weights  {0: 1, 1: 105}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   279    339]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916778 0.90159574]
# Recall [0.99988955 0.54854369]
# F-score [0.99952854 0.68209256]
# Support [335007    618]
# **************************************
# Iteration number   106
# Class weights  {0: 1, 1: 106}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   285    333]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914991 0.90735695]
# Recall [0.99989851 0.53883495]
# F-score [0.99952407 0.67614213]
# Support [335007    618]
# **************************************
# Iteration number   107
# Class weights  {0: 1, 1: 107}
# Performance on validation data - Confusion matrix
# [[334965     42]
#  [   287    331]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914393 0.88739946]
# Recall [0.99987463 0.53559871]
# F-score [0.99950914 0.66801211]
# Support [335007    618]
# **************************************
# Iteration number   108
# Class weights  {0: 1, 1: 108}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913799 0.90633609]
# Recall [0.99989851 0.53236246]
# F-score [0.9995181  0.67074414]
# Support [335007    618]
# **************************************
# Iteration number   109
# Class weights  {0: 1, 1: 109}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.999135  0.9010989]
# Recall [0.99989254 0.53074434]
# F-score [0.99951363 0.66802444]
# Support [335007    618]
# **************************************
# Iteration number   110
# Class weights  {0: 1, 1: 110}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   285    333]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914991 0.9048913 ]
# Recall [0.99989552 0.53883495]
# F-score [0.99952258 0.67545639]
# Support [335007    618]
# **************************************
# Iteration number   111
# Class weights  {0: 1, 1: 111}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914097 0.90659341]
# Recall [0.99989851 0.53398058]
# F-score [0.9995196  0.67209776]
# Support [335007    618]
# **************************************
# Iteration number   112
# Class weights  {0: 1, 1: 112}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   281    337]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916182 0.89866667]
# Recall [0.99988657 0.54530744]
# F-score [0.99952406 0.67875126]
# Support [335007    618]
# **************************************
# Iteration number   113
# Class weights  {0: 1, 1: 113}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913798 0.8989071 ]
# Recall [0.99988955 0.53236246]
# F-score [0.99951363 0.66869919]
# Support [335007    618]
# **************************************
# Iteration number   114
# Class weights  {0: 1, 1: 114}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   291    327]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913203 0.91086351]
# Recall [0.99990448 0.52912621]
# F-score [0.99951811 0.66939611]
# Support [335007    618]
# **************************************
# Iteration number   115
# Class weights  {0: 1, 1: 115}
# Performance on validation data - Confusion matrix
# [[334976     31]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916482 0.91598916]
# Recall [0.99990746 0.54692557]
# F-score [0.999536   0.68490375]
# Support [335007    618]
# **************************************
# Iteration number   116
# Class weights  {0: 1, 1: 116}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915587 0.91280654]
# Recall [0.99990448 0.5420712 ]
# F-score [0.99953004 0.68020305]
# Support [335007    618]
# **************************************
# Iteration number   117
# Class weights  {0: 1, 1: 117}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   279    339]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916778 0.89920424]
# Recall [0.99988657 0.54854369]
# F-score [0.99952705 0.68140704]
# Support [335007    618]
# **************************************
# Iteration number   118
# Class weights  {0: 1, 1: 118}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   275    343]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917971 0.90501319]
# Recall [0.99989254 0.55501618]
# F-score [0.999536   0.68806419]
# Support [335007    618]
# **************************************
# Iteration number   119
# Class weights  {0: 1, 1: 119}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.9027027 ]
# Recall [0.99989254 0.54045307]
# F-score [0.99952257 0.67611336]
# Support [335007    618]
# **************************************
# Iteration number   120
# Class weights  {0: 1, 1: 120}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.896     ]
# Recall [0.99988358 0.54368932]
# F-score [0.99952108 0.67673716]
# Support [335007    618]
# **************************************
# Iteration number   121
# Class weights  {0: 1, 1: 121}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913799 0.90384615]
# Recall [0.99989552 0.53236246]
# F-score [0.99951661 0.6700611 ]
# Support [335007    618]
# **************************************
# Iteration number   122
# Class weights  {0: 1, 1: 122}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   279    339]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916779 0.91129032]
# Recall [0.99990149 0.54854369]
# F-score [0.99953451 0.68484848]
# Support [335007    618]
# **************************************
# Iteration number   123
# Class weights  {0: 1, 1: 123}
# Performance on validation data - Confusion matrix
# [[334967     40]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916479 0.89417989]
# Recall [0.9998806  0.54692557]
# F-score [0.99952257 0.67871486]
# Support [335007    618]
# **************************************
# Iteration number   124
# Class weights  {0: 1, 1: 124}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   275    343]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917971 0.90501319]
# Recall [0.99989254 0.55501618]
# F-score [0.999536   0.68806419]
# Support [335007    618]
# **************************************
# Iteration number   125
# Class weights  {0: 1, 1: 125}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   276    342]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917673 0.9071618 ]
# Recall [0.99989552 0.55339806]
# F-score [0.999536   0.68743719]
# Support [335007    618]
# **************************************
# Iteration number   126
# Class weights  {0: 1, 1: 126}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.896     ]
# Recall [0.99988358 0.54368932]
# F-score [0.99952108 0.67673716]
# Support [335007    618]
# **************************************
# Iteration number   127
# Class weights  {0: 1, 1: 127}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   281    337]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916182 0.90106952]
# Recall [0.99988955 0.54530744]
# F-score [0.99952556 0.67943548]
# Support [335007    618]
# **************************************
# Iteration number   128
# Class weights  {0: 1, 1: 128}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   275    343]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991797  0.89790576]
# Recall [0.99988358 0.55501618]
# F-score [0.99953152 0.686     ]
# Support [335007    618]
# **************************************
# Iteration number   129
# Class weights  {0: 1, 1: 129}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   276    342]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917672 0.8976378 ]
# Recall [0.99988358 0.55339806]
# F-score [0.99953003 0.68468468]
# Support [335007    618]
# **************************************
# Iteration number   130
# Class weights  {0: 1, 1: 130}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   281    337]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916183 0.91081081]
# Recall [0.99990149 0.54530744]
# F-score [0.99953153 0.68218623]
# Support [335007    618]
# **************************************
# Iteration number   131
# Class weights  {0: 1, 1: 131}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   279    339]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916779 0.90641711]
# Recall [0.99989552 0.54854369]
# F-score [0.99953152 0.68346774]
# Support [335007    618]
# **************************************
# Iteration number   132
# Class weights  {0: 1, 1: 132}
# Performance on validation data - Confusion matrix
# [[334974     33]
#  [   280    338]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99916481 0.91105121]
# Recall [0.99990149 0.54692557]
# F-score [0.99953302 0.68351871]
# Support [335007    618]
# **************************************
# Iteration number   133
# Class weights  {0: 1, 1: 133}
# Performance on validation data - Confusion matrix
# [[334973     34]
#  [   285    333]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914991 0.90735695]
# Recall [0.99989851 0.53883495]
# F-score [0.99952407 0.67614213]
# Support [335007    618]
# **************************************
# Iteration number   134
# Class weights  {0: 1, 1: 134}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.90026954]
# Recall [0.99988955 0.54045307]
# F-score [0.99952108 0.67542973]
# Support [335007    618]
# **************************************
# Iteration number   135
# Class weights  {0: 1, 1: 135}
# Performance on validation data - Confusion matrix
# [[334972     35]
#  [   270    348]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99919461 0.90861619]
# Recall [0.99989552 0.5631068 ]
# F-score [0.99954495 0.6953047 ]
# Support [335007    618]
# **************************************
# Iteration number   136
# Class weights  {0: 1, 1: 136}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   266    352]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99920652 0.8956743 ]
# Recall [0.99987761 0.56957929]
# F-score [0.99954195 0.69634026]
# Support [335007    618]
# ...
# F-score [0.99951661 0.67073171]
# Support [335007    618]
# **************************************
# Iteration number   456
# Class weights  {0: 1, 1: 456}
# Performance on validation data - Confusion matrix
# [[334967     40]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915287 0.89304813]
# Recall [0.9998806  0.54045307]
# F-score [0.9995166 0.6733871]
# Support [335007    618]
# **************************************
# Iteration number   457
# Class weights  {0: 1, 1: 457}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914097 0.91160221]
# Recall [0.99990448 0.53398058]
# F-score [0.99952258 0.67346939]
# Support [335007    618]
# **************************************
# Iteration number   458
# Class weights  {0: 1, 1: 458}
# Performance on validation data - Confusion matrix
# [[334975     32]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913799 0.91135734]
# Recall [0.99990448 0.53236246]
# F-score [0.99952109 0.6721144 ]
# Support [335007    618]
# **************************************
# Iteration number   459
# Class weights  {0: 1, 1: 459}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913798 0.8989071 ]
# Recall [0.99988955 0.53236246]
# F-score [0.99951363 0.66869919]
# Support [335007    618]
# **************************************
# Iteration number   460
# Class weights  {0: 1, 1: 460}
# Performance on validation data - Confusion matrix
# [[334967     40]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913797 0.89159892]
# Recall [0.9998806  0.53236246]
# F-score [0.99950915 0.66666667]
# Support [335007    618]
# **************************************
# Iteration number   461
# Class weights  {0: 1, 1: 461}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.89839572]
# Recall [0.99988657 0.54368932]
# F-score [0.99952257 0.67741935]
# Support [335007    618]
# **************************************
# Iteration number   462
# Class weights  {0: 1, 1: 462}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.89839572]
# Recall [0.99988657 0.54368932]
# F-score [0.99952257 0.67741935]
# Support [335007    618]
# **************************************
# Iteration number   463
# Class weights  {0: 1, 1: 463}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915585 0.89095745]
# Recall [0.99987761 0.5420712 ]
# F-score [0.9995166  0.67404427]
# Support [335007    618]
# **************************************
# Iteration number   464
# Class weights  {0: 1, 1: 464}
# Performance on validation data - Confusion matrix
# [[334961     46]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991469  0.87830688]
# Recall [0.99986269 0.53721683]
# F-score [0.99950467 0.66666667]
# Support [335007    618]
# **************************************
# Iteration number   465
# Class weights  {0: 1, 1: 465}
# Performance on validation data - Confusion matrix
# [[334961     46]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991469  0.87830688]
# Recall [0.99986269 0.53721683]
# F-score [0.99950467 0.66666667]
# Support [335007    618]
# **************************************
# Iteration number   466
# Class weights  {0: 1, 1: 466}
# Performance on validation data - Confusion matrix
# [[334961     46]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991469  0.87830688]
# Recall [0.99986269 0.53721683]
# F-score [0.99950467 0.66666667]
# Support [335007    618]
# **************************************
# Iteration number   467
# Class weights  {0: 1, 1: 467}
# Performance on validation data - Confusion matrix
# [[334961     46]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991469  0.87830688]
# Recall [0.99986269 0.53721683]
# F-score [0.99950467 0.66666667]
# Support [335007    618]
# **************************************
# Iteration number   468
# Class weights  {0: 1, 1: 468}
# Performance on validation data - Confusion matrix
# [[334961     46]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991469  0.87830688]
# Recall [0.99986269 0.53721683]
# F-score [0.99950467 0.66666667]
# Support [335007    618]
# **************************************
# Iteration number   469
# Class weights  {0: 1, 1: 469}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   291    327]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913201 0.88858696]
# Recall [0.99987761 0.52912621]
# F-score [0.99950467 0.663286  ]
# Support [335007    618]
# **************************************
# Iteration number   470
# Class weights  {0: 1, 1: 470}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   291    327]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913201 0.88858696]
# Recall [0.99987761 0.52912621]
# F-score [0.99950467 0.663286  ]
# Support [335007    618]
# **************************************
# Iteration number   471
# Class weights  {0: 1, 1: 471}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913499 0.88888889]
# Recall [0.99987761 0.53074434]
# F-score [0.99950616 0.66464032]
# Support [335007    618]
# **************************************
# Iteration number   472
# Class weights  {0: 1, 1: 472}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   288    330]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914095 0.88948787]
# Recall [0.99987761 0.53398058]
# F-score [0.99950915 0.66734075]
# Support [335007    618]
# **************************************
# Iteration number   473
# Class weights  {0: 1, 1: 473}
# Performance on validation data - Confusion matrix
# [[334962     45]
#  [   286    332]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9991469 0.8806366]
# Recall [0.99986567 0.53721683]
# F-score [0.99950616 0.66733668]
# Support [335007    618]
# **************************************
# Iteration number   474
# Class weights  {0: 1, 1: 474}
# Performance on validation data - Confusion matrix
# [[334963     44]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915882 0.88421053]
# Recall [0.99986866 0.54368932]
# F-score [0.99951362 0.67334669]
# Support [335007    618]
# **************************************
# Iteration number   475
# Class weights  {0: 1, 1: 475}
# Performance on validation data - Confusion matrix
# [[334963     44]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915882 0.88421053]
# Recall [0.99986866 0.54368932]
# F-score [0.99951362 0.67334669]
# Support [335007    618]
# **************************************
# Iteration number   476
# Class weights  {0: 1, 1: 476}
# Performance on validation data - Confusion matrix
# [[334963     44]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915882 0.88421053]
# Recall [0.99986866 0.54368932]
# F-score [0.99951362 0.67334669]
# Support [335007    618]
# **************************************
# Iteration number   477
# Class weights  {0: 1, 1: 477}
# Performance on validation data - Confusion matrix
# [[334963     44]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915882 0.88421053]
# Recall [0.99986866 0.54368932]
# F-score [0.99951362 0.67334669]
# Support [335007    618]
# **************************************
# Iteration number   478
# Class weights  {0: 1, 1: 478}
# Performance on validation data - Confusion matrix
# [[334963     44]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915584 0.88390501]
# Recall [0.99986866 0.5420712 ]
# F-score [0.99951212 0.67201605]
# Support [335007    618]
# **************************************
# Iteration number   479
# Class weights  {0: 1, 1: 479}
# Performance on validation data - Confusion matrix
# [[334964     43]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915287 0.88594164]
# Recall [0.99987164 0.54045307]
# F-score [0.99951213 0.67135678]
# Support [335007    618]
# **************************************
# Iteration number   480
# Class weights  {0: 1, 1: 480}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913798 0.90136986]
# Recall [0.99989254 0.53236246]
# F-score [0.99951512 0.66937945]
# Support [335007    618]
# **************************************
# Iteration number   481
# Class weights  {0: 1, 1: 481}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913798 0.90136986]
# Recall [0.99989254 0.53236246]
# F-score [0.99951512 0.66937945]
# Support [335007    618]
# **************************************
# Iteration number   482
# Class weights  {0: 1, 1: 482}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   290    328]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913499 0.88888889]
# Recall [0.99987761 0.53074434]
# F-score [0.99950616 0.66464032]
# Support [335007    618]
# **************************************
# Iteration number   483
# Class weights  {0: 1, 1: 483}
# Performance on validation data - Confusion matrix
# [[334969     38]
#  [   289    329]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99913798 0.89645777]
# Recall [0.99988657 0.53236246]
# F-score [0.99951213 0.6680203 ]
# Support [335007    618]
# **************************************
# Iteration number   484
# Class weights  {0: 1, 1: 484}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   287    331]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99914394 0.89459459]
# Recall [0.99988358 0.53559871]
# F-score [0.99951362 0.67004049]
# Support [335007    618]
# **************************************
# Iteration number   485
# Class weights  {0: 1, 1: 485}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915586 0.90296496]
# Recall [0.99989254 0.5420712 ]
# F-score [0.99952407 0.67745197]
# Support [335007    618]
# **************************************
# Iteration number   486
# Class weights  {0: 1, 1: 486}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.90080429]
# Recall [0.99988955 0.54368932]
# F-score [0.99952406 0.67810293]
# Support [335007    618]
# **************************************
# Iteration number   487
# Class weights  {0: 1, 1: 487}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915585 0.89095745]
# Recall [0.99987761 0.5420712 ]
# F-score [0.9995166  0.67404427]
# Support [335007    618]
# **************************************
# Iteration number   488
# Class weights  {0: 1, 1: 488}
# Performance on validation data - Confusion matrix
# [[334966     41]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915585 0.89095745]
# Recall [0.99987761 0.5420712 ]
# F-score [0.9995166  0.67404427]
# Support [335007    618]
# **************************************
# Iteration number   489
# Class weights  {0: 1, 1: 489}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915586 0.89572193]
# Recall [0.99988358 0.5420712 ]
# F-score [0.99951959 0.67540323]
# Support [335007    618]
# **************************************
# Iteration number   490
# Class weights  {0: 1, 1: 490}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915586 0.89572193]
# Recall [0.99988358 0.5420712 ]
# F-score [0.99951959 0.67540323]
# Support [335007    618]
# **************************************
# Iteration number   491
# Class weights  {0: 1, 1: 491}
# Performance on validation data - Confusion matrix
# [[334968     39]
#  [   283    335]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915586 0.89572193]
# Recall [0.99988358 0.5420712 ]
# F-score [0.99951959 0.67540323]
# Support [335007    618]
# **************************************
# Iteration number   492
# Class weights  {0: 1, 1: 492}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.90322581]
# Recall [0.99989254 0.54368932]
# F-score [0.99952556 0.67878788]
# Support [335007    618]
# **************************************
# Iteration number   493
# Class weights  {0: 1, 1: 493}
# Performance on validation data - Confusion matrix
# [[334971     36]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915884 0.90322581]
# Recall [0.99989254 0.54368932]
# F-score [0.99952556 0.67878788]
# Support [335007    618]
# **************************************
# Iteration number   494
# Class weights  {0: 1, 1: 494}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.90026954]
# Recall [0.99988955 0.54045307]
# F-score [0.99952108 0.67542973]
# Support [335007    618]
# **************************************
# Iteration number   495
# Class weights  {0: 1, 1: 495}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.90026954]
# Recall [0.99988955 0.54045307]
# F-score [0.99952108 0.67542973]
# Support [335007    618]
# **************************************
# Iteration number   496
# Class weights  {0: 1, 1: 496}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.90026954]
# Recall [0.99988955 0.54045307]
# F-score [0.99952108 0.67542973]
# Support [335007    618]
# **************************************
# Iteration number   497
# Class weights  {0: 1, 1: 497}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.90026954]
# Recall [0.99988955 0.54045307]
# F-score [0.99952108 0.67542973]
# Support [335007    618]
# **************************************
# Iteration number   498
# Class weights  {0: 1, 1: 498}
# Performance on validation data - Confusion matrix
# [[334970     37]
#  [   284    334]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915288 0.90026954]
# Recall [0.99988955 0.54045307]
# F-score [0.99952108 0.67542973]
# Support [335007    618]
# **************************************
# Iteration number   499
# Class weights  {0: 1, 1: 499}
# Performance on validation data - Confusion matrix
# [[334967     40]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915883 0.89361702]
# Recall [0.9998806  0.54368932]
# F-score [0.99951959 0.67605634]
# Support [335007    618]
# **************************************
# Iteration number   500
# Class weights  {0: 1, 1: 500}
# Performance on validation data - Confusion matrix
# [[334967     40]
#  [   282    336]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99915883 0.89361702]
# Recall [0.9998806  0.54368932]
# F-score [0.99951959 0.67605634]
# Support [335007    618]
