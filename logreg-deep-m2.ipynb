# %%
import numpy as np
import pandas as pd
import csv
import sys
import os
  
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
import warnings
import pickle

max_iters = 501
#n_estimators = 10

def logreg(x,y,filename):

   # Model output file name
   file = (os.path.splitext(filename))[0]
   fname = './models/lr_' + file +'/'

   # File for writing precision,recall, f-measure scores for fraud transactions
   f = open('./prf/lr_'+ file + '_prf' +'.txt' ,'w')
   f.write('precision,recall,f-score \n')

   # Stratified sampling based on Y
   X_train, X_test, y_train, y_test = train_test_split(x, y,stratify=y , test_size=0.30, random_state=42)

   # Create 15% validation set and 15% test set split
   X_val, X_test, y_val, y_test = train_test_split(X_test, y_test,stratify=y_test , test_size=0.50, random_state=42)
   
   #Iterations
   it = 1
   
   # Run training algorithm for multiple class weights
   while it < max_iters:
       cw = {}
       cw[0] = 1
       cw[1] = it
       # Train
       print('**************************************')
       print("Iteration number  " , it)
       lr = LogisticRegression(class_weight = cw)
       print('Class weights ', cw)
       lr.fit(X_train,y_train)

       # Save trained model to disk
       name = fname + str(cw[1]) + '.sav'
       pickle.dump(lr, open(name, 'wb'))

       # Predict on validation data
       y_val_pred = lr.predict(X_val)
       print('Performance on validation data - Confusion matrix')
       print(confusion_matrix(y_val,y_val_pred))
   
       precision,recall,fscore,support=score(y_val,y_val_pred,average=None)
       print('Precision, Recall, F-score, Support  on validation data' )
       print("Precision" , precision)
       print("Recall" , recall)
       print("F-score" , fscore)
       print("Support" , support)

       p1 = precision[1]
       r1 = recall[1]
       f1 = fscore[1]

       f.write(str(p1) +','+ str(r1) + ',' + str(f1) + '\n') 
       it += 1

   f.close()

def run():
   filename = 'm2.csv'
   df = pd.read_csv(filename, usecols = [9,10,11,12,13,14] , header = 0)
   
   results = list(map(int, df['Anomaly'])) 
   print('Number of fraudulent transactions ' , sum(results))

   features = ['Airfare', 'Lodging', 'Meals', 'Other_Transportation', 'Other_Expenses']
   targets = ['Anomaly']

   # Separating out the features and target variables
   x = df.loc[:, features].values
   y = df.loc[:, targets].values
    
   scaler = preprocessing.StandardScaler()
   x = scaler.fit_transform(x)    

   y  = [i for j in y for i in j]
   
   #Ignore warnings
   warnings.filterwarnings("ignore", category=FutureWarning)

   print("***********Logistic Regression**********")
   logreg(x,y,filename)
  
run()
# Out:
# Number of fraudulent transactions  4116
# ***********Logistic Regression**********
# **************************************
# Iteration number   1
# Class weights  {0: 1, 1: 1}
# Performance on validation data - Confusion matrix
# [[334984     23]
#  [   330    288]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99901585 0.92604502]
# Recall [0.99993134 0.46601942]
# F-score [0.99947339 0.62002153]
# Support [335007    618]
# **************************************
# Iteration number   2
# Class weights  {0: 1, 1: 2}
# Performance on validation data - Confusion matrix
# [[334961     46]
#  [   299    319]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99910815 0.8739726 ]
# Recall [0.99986269 0.51618123]
# F-score [0.99948528 0.64903357]
# Support [335007    618]
# **************************************
# Iteration number   3
# Class weights  {0: 1, 1: 3}
# Performance on validation data - Confusion matrix
# [[334936     71]
#  [   277    341]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99917366 0.8276699 ]
# Recall [0.99978806 0.55177994]
# F-score [0.99948077 0.66213592]
# Support [335007    618]
# **************************************
# Iteration number   4
# Class weights  {0: 1, 1: 4}
# Performance on validation data - Confusion matrix
# [[334907    100]
#  [   269    349]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99919744 0.77728285]
# Recall [0.9997015  0.56472492]
# F-score [0.9994494  0.65417057]
# Support [335007    618]
# **************************************
# Iteration number   5
# Class weights  {0: 1, 1: 5}
# Performance on validation data - Confusion matrix
# [[334883    124]
#  [   255    363]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99923912 0.74537988]
# Recall [0.99962986 0.58737864]
# F-score [0.99943445 0.65701357]
# Support [335007    618]
# **************************************
# Iteration number   6
# Class weights  {0: 1, 1: 6}
# Performance on validation data - Confusion matrix
# [[334859    148]
#  [   247    371]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99926292 0.71483622]
# Recall [0.99955822 0.60032362]
# F-score [0.99941055 0.65259455]
# Support [335007    618]
# **************************************
# Iteration number   7
# Class weights  {0: 1, 1: 7}
# Performance on validation data - Confusion matrix
# [[334834    173]
#  [   237    381]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99929269 0.68772563]
# Recall [0.99948359 0.61650485]
# F-score [0.99938813 0.65017065]
# Support [335007    618]
# **************************************
# Iteration number   8
# Class weights  {0: 1, 1: 8}
# Performance on validation data - Confusion matrix
# [[334803    204]
#  [   230    388]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9993135  0.65540541]
# Recall [0.99939106 0.62783172]
# F-score [0.99935228 0.64132231]
# Support [335007    618]
# **************************************
# Iteration number   9
# Class weights  {0: 1, 1: 9}
# Performance on validation data - Confusion matrix
# [[334767    240]
#  [   227    391]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99932238 0.61965135]
# Recall [0.9992836  0.63268608]
# F-score [0.99930299 0.62610088]
# Support [335007    618]
# **************************************
# Iteration number   10
# Class weights  {0: 1, 1: 10}
# Performance on validation data - Confusion matrix
# [[334733    274]
#  [   222    396]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99933722 0.59104478]
# Recall [0.99918211 0.6407767 ]
# F-score [0.99925966 0.61490683]
# Support [335007    618]
# **************************************
# Iteration number   11
# Class weights  {0: 1, 1: 11}
# Performance on validation data - Confusion matrix
# [[334702    305]
#  [   213    405]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99936402 0.57042254]
# Recall [0.99908957 0.65533981]
# F-score [0.99922678 0.60993976]
# Support [335007    618]
# **************************************
# Iteration number   12
# Class weights  {0: 1, 1: 12}
# Performance on validation data - Confusion matrix
# [[334675    332]
#  [   205    413]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99938784 0.55436242]
# Recall [0.99900898 0.66828479]
# F-score [0.99919837 0.60601614]
# Support [335007    618]
# **************************************
# Iteration number   13
# Class weights  {0: 1, 1: 13}
# Performance on validation data - Confusion matrix
# [[334649    358]
#  [   197    421]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99941167 0.54043646]
# Recall [0.99893137 0.68122977]
# F-score [0.99917146 0.60272011]
# Support [335007    618]
# **************************************
# Iteration number   14
# Class weights  {0: 1, 1: 14}
# Performance on validation data - Confusion matrix
# [[334626    381]
#  [   194    424]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99942058 0.52670807]
# Recall [0.99886271 0.68608414]
# F-score [0.99914157 0.5959241 ]
# Support [335007    618]
# **************************************
# Iteration number   15
# Class weights  {0: 1, 1: 15}
# Performance on validation data - Confusion matrix
# [[334599    408]
#  [   188    430]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99943845 0.51312649]
# Recall [0.99878212 0.69579288]
# F-score [0.99911017 0.59065934]
# Support [335007    618]
# **************************************
# Iteration number   16
# Class weights  {0: 1, 1: 16}
# Performance on validation data - Confusion matrix
# [[334573    434]
#  [   183    435]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99945333 0.50057537]
# Recall [0.9987045 0.7038835]
# F-score [0.99907878 0.58507061]
# Support [335007    618]
# **************************************
# Iteration number   17
# Class weights  {0: 1, 1: 17}
# Performance on validation data - Confusion matrix
# [[334549    458]
#  [   179    439]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99946524 0.48940914]
# Recall [0.99863286 0.71035599]
# F-score [0.99904888 0.57953795]
# Support [335007    618]
# **************************************
# Iteration number   18
# Class weights  {0: 1, 1: 18}
# Performance on validation data - Confusion matrix
# [[334523    484]
#  [   177    441]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99947117 0.47675676]
# Recall [0.99855525 0.71359223]
# F-score [0.999013   0.57161374]
# Support [335007    618]
# **************************************
# Iteration number   19
# Class weights  {0: 1, 1: 19}
# Performance on validation data - Confusion matrix
# [[334499    508]
#  [   174    444]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99948009 0.46638655]
# Recall [0.99848361 0.7184466 ]
# F-score [0.9989816 0.5656051]
# Support [335007    618]
# **************************************
# Iteration number   20
# Class weights  {0: 1, 1: 20}
# Performance on validation data - Confusion matrix
# [[334472    535]
#  [   172    446]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99948602 0.45463812]
# Recall [0.99840302 0.72168285]
# F-score [0.99894423 0.55784866]
# Support [335007    618]
# **************************************
# Iteration number   21
# Class weights  {0: 1, 1: 21}
# Performance on validation data - Confusion matrix
# [[334454    553]
#  [   167    451]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99950093 0.44920319]
# Recall [0.99834929 0.72977346]
# F-score [0.99892478 0.55610358]
# Support [335007    618]
# **************************************
# Iteration number   22
# Class weights  {0: 1, 1: 22}
# Performance on validation data - Confusion matrix
# [[334428    579]
#  [   162    456]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99951583 0.44057971]
# Recall [0.99827168 0.73786408]
# F-score [0.99889336 0.55172414]
# Support [335007    618]
# **************************************
# Iteration number   23
# Class weights  {0: 1, 1: 23}
# Performance on validation data - Confusion matrix
# [[334406    601]
#  [   160    458]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99952177 0.43248347]
# Recall [0.99820601 0.74110032]
# F-score [0.99886345 0.54621348]
# Support [335007    618]
# **************************************
# Iteration number   24
# Class weights  {0: 1, 1: 24}
# Performance on validation data - Confusion matrix
# [[334379    628]
#  [   158    460]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99952771 0.42279412]
# Recall [0.99812541 0.74433657]
# F-score [0.99882607 0.53927315]
# Support [335007    618]
# **************************************
# Iteration number   25
# Class weights  {0: 1, 1: 25}
# Performance on validation data - Confusion matrix
# [[334357    650]
#  [   155    463]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99953664 0.41599281]
# Recall [0.99805974 0.74919094]
# F-score [0.99879764 0.5349509 ]
# Support [335007    618]
# **************************************
# Iteration number   26
# Class weights  {0: 1, 1: 26}
# Performance on validation data - Confusion matrix
# [[334327    680]
#  [   152    466]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99954556 0.40663176]
# Recall [0.99797019 0.75404531]
# F-score [0.99875726 0.52834467]
# Support [335007    618]
# **************************************
# Iteration number   27
# Class weights  {0: 1, 1: 27}
# Performance on validation data - Confusion matrix
# [[334310    697]
#  [   148    470]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99955749 0.40274207]
# Recall [0.99791945 0.7605178 ]
# F-score [0.9987378  0.52661064]
# Support [335007    618]
# **************************************
# Iteration number   28
# Class weights  {0: 1, 1: 28}
# Performance on validation data - Confusion matrix
# [[334285    722]
#  [   146    472]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99956344 0.39530988]
# Recall [0.99784482 0.76375405]
# F-score [0.99870339 0.5209713 ]
# Support [335007    618]
# **************************************
# Iteration number   29
# Class weights  {0: 1, 1: 29}
# Performance on validation data - Confusion matrix
# [[334254    753]
#  [   144    474]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99956938 0.38630807]
# Recall [0.99775229 0.76699029]
# F-score [0.99866    0.51382114]
# Support [335007    618]
# **************************************
# Iteration number   30
# Class weights  {0: 1, 1: 30}
# Performance on validation data - Confusion matrix
# [[334229    778]
#  [   140    478]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9995813  0.38057325]
# Recall [0.99767766 0.77346278]
# F-score [0.99862857 0.51013874]
# Support [335007    618]
# **************************************
# Iteration number   31
# Class weights  {0: 1, 1: 31}
# Performance on validation data - Confusion matrix
# [[334204    803]
#  [   139    479]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99958426 0.37363495]
# Recall [0.99760304 0.77508091]
# F-score [0.99859266 0.50421053]
# Support [335007    618]
# **************************************
# Iteration number   32
# Class weights  {0: 1, 1: 32}
# Performance on validation data - Confusion matrix
# [[334174    833]
#  [   138    480]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99958721 0.36557502]
# Recall [0.99751348 0.77669903]
# F-score [0.99854927 0.49715173]
# Support [335007    618]
# **************************************
# Iteration number   33
# Class weights  {0: 1, 1: 33}
# Performance on validation data - Confusion matrix
# [[334150    857]
#  [   137    481]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99959017 0.35949178]
# Recall [0.99744184 0.77831715]
# F-score [0.99851485 0.49182004]
# Support [335007    618]
# **************************************
# Iteration number   34
# Class weights  {0: 1, 1: 34}
# Performance on validation data - Confusion matrix
# [[334127    880]
#  [   135    483]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99959613 0.35436537]
# Recall [0.99737319 0.7815534 ]
# F-score [0.99848342 0.48763251]
# Support [335007    618]
# **************************************
# Iteration number   35
# Class weights  {0: 1, 1: 35}
# Performance on validation data - Confusion matrix
# [[334107    900]
#  [   134    484]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99959909 0.34971098]
# Recall [0.99731349 0.78317152]
# F-score [0.99845498 0.48351648]
# Support [335007    618]
# **************************************
# Iteration number   36
# Class weights  {0: 1, 1: 36}
# Performance on validation data - Confusion matrix
# [[334081    926]
#  [   131    487]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99960803 0.34465676]
# Recall [0.99723588 0.78802589]
# F-score [0.99842055 0.47956672]
# Support [335007    618]
# **************************************
# Iteration number   37
# Class weights  {0: 1, 1: 37}
# Performance on validation data - Confusion matrix
# [[334068    939]
#  [   130    488]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99961101 0.34197617]
# Recall [0.99719707 0.78964401]
# F-score [0.99840258 0.47726161]
# Support [335007    618]
# **************************************
# Iteration number   38
# Class weights  {0: 1, 1: 38}
# Performance on validation data - Confusion matrix
# [[334046    961]
#  [   128    490]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99961697 0.33769814]
# Recall [0.9971314  0.79288026]
# F-score [0.99837264 0.47365877]
# Support [335007    618]
# **************************************
# Iteration number   39
# Class weights  {0: 1, 1: 39}
# Performance on validation data - Confusion matrix
# [[334029    978]
#  [   127    491]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99961994 0.33424098]
# Recall [0.99708066 0.79449838]
# F-score [0.99834868 0.47053186]
# Support [335007    618]
# **************************************
# Iteration number   40
# Class weights  {0: 1, 1: 40}
# Performance on validation data - Confusion matrix
# [[333998   1009]
#  [   125    493]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99962589 0.32822903]
# Recall [0.99698812 0.79773463]
# F-score [0.99830526 0.46509434]
# Support [335007    618]
# **************************************
# Iteration number   41
# Class weights  {0: 1, 1: 41}
# Performance on validation data - Confusion matrix
# [[333969   1038]
#  [   122    496]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99963483 0.32333768]
# Recall [0.99690156 0.802589  ]
# F-score [0.99826632 0.46096654]
# Support [335007    618]
# **************************************
# Iteration number   42
# Class weights  {0: 1, 1: 42}
# Performance on validation data - Confusion matrix
# [[333946   1061]
#  [   119    499]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99964378 0.31987179]
# Recall [0.9968329  0.80744337]
# F-score [0.99823636 0.45821855]
# Support [335007    618]
# **************************************
# Iteration number   43
# Class weights  {0: 1, 1: 43}
# Performance on validation data - Confusion matrix
# [[333926   1081]
#  [   118    500]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99964675 0.31625553]
# Recall [0.9967732  0.80906149]
# F-score [0.99820791 0.45475216]
# Support [335007    618]
# **************************************
# Iteration number   44
# Class weights  {0: 1, 1: 44}
# Performance on validation data - Confusion matrix
# [[333890   1117]
#  [   117    501]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99964971 0.30964153]
# Recall [0.99666574 0.81067961]
# F-score [0.99815549 0.44812165]
# Support [335007    618]
# **************************************
# Iteration number   45
# Class weights  {0: 1, 1: 45}
# Performance on validation data - Confusion matrix
# [[333867   1140]
#  [   116    502]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99965268 0.30572473]
# Recall [0.99659709 0.81229773]
# F-score [0.99812254 0.44424779]
# Support [335007    618]
# **************************************
# Iteration number   46
# Class weights  {0: 1, 1: 46}
# Performance on validation data - Confusion matrix
# [[333842   1165]
#  [   114    504]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99965864 0.30197723]
# Recall [0.99652246 0.81553398]
# F-score [0.99808809 0.44075208]
# Support [335007    618]
# **************************************
# Iteration number   47
# Class weights  {0: 1, 1: 47}
# Performance on validation data - Confusion matrix
# [[333815   1192]
#  [   111    507]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99966759 0.29841083]
# Recall [0.99644187 0.82038835]
# F-score [0.99805212 0.43763487]
# Support [335007    618]
# **************************************
# Iteration number   48
# Class weights  {0: 1, 1: 48}
# Performance on validation data - Confusion matrix
# [[333792   1215]
#  [   111    507]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99966757 0.29442509]
# Recall [0.99637321 0.82038835]
# F-score [0.99801767 0.43333333]
# Support [335007    618]
# **************************************
# Iteration number   49
# Class weights  {0: 1, 1: 49}
# Performance on validation data - Confusion matrix
# [[333767   1240]
#  [   109    509]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99967353 0.29102344]
# Recall [0.99629858 0.8236246 ]
# F-score [0.9979832  0.43008027]
# Support [335007    618]
# **************************************
# Iteration number   50
# Class weights  {0: 1, 1: 50}
# Performance on validation data - Confusion matrix
# [[333743   1264]
#  [   107    511]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9996795  0.28788732]
# Recall [0.99622694 0.82686084]
# F-score [0.99795023 0.42707898]
# Support [335007    618]
# **************************************
# Iteration number   51
# Class weights  {0: 1, 1: 51}
# Performance on validation data - Confusion matrix
# [[333725   1282]
#  [   104    514]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99968846 0.28619154]
# Recall [0.99617321 0.83171521]
# F-score [0.99792774 0.42584921]
# Support [335007    618]
# **************************************
# Iteration number   52
# Class weights  {0: 1, 1: 52}
# Performance on validation data - Confusion matrix
# [[333708   1299]
#  [   104    514]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99968845 0.283508  ]
# Recall [0.99612247 0.83171521]
# F-score [0.99790227 0.42287125]
# Support [335007    618]
# **************************************
# Iteration number   53
# Class weights  {0: 1, 1: 53}
# Performance on validation data - Confusion matrix
# [[333685   1322]
#  [   101    517]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99969741 0.28113105]
# Recall [0.99605381 0.83656958]
# F-score [0.99787229 0.42083842]
# Support [335007    618]
# **************************************
# Iteration number   54
# Class weights  {0: 1, 1: 54}
# Performance on validation data - Confusion matrix
# [[333670   1337]
#  [   100    518]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99970039 0.27924528]
# Recall [0.99600904 0.8381877 ]
# F-score [0.9978513  0.41892438]
# Support [335007    618]
# **************************************
# Iteration number   55
# Class weights  {0: 1, 1: 55}
# Performance on validation data - Confusion matrix
# [[333654   1353]
#  [   100    518]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99970038 0.2768573 ]
# Recall [0.99596128 0.8381877 ]
# F-score [0.99782733 0.41623142]
# Support [335007    618]
# **************************************
# Iteration number   56
# Class weights  {0: 1, 1: 56}
# Performance on validation data - Confusion matrix
# [[333633   1374]
#  [   100    518]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99970036 0.27378436]
# Recall [0.99589859 0.8381877 ]
# F-score [0.99779585 0.412749  ]
# Support [335007    618]
# **************************************
# Iteration number   57
# Class weights  {0: 1, 1: 57}
# Performance on validation data - Confusion matrix
# [[333614   1393]
#  [   100    518]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99970034 0.27106227]
# Recall [0.99584188 0.8381877 ]
# F-score [0.99776738 0.40964808]
# Support [335007    618]
# **************************************
# Iteration number   58
# Class weights  {0: 1, 1: 58}
# Performance on validation data - Confusion matrix
# [[333602   1405]
#  [   100    518]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99970033 0.26937077]
# Recall [0.99580606 0.8381877 ]
# F-score [0.99774939 0.4077135 ]
# Support [335007    618]
# **************************************
# Iteration number   59
# Class weights  {0: 1, 1: 59}
# Performance on validation data - Confusion matrix
# [[333583   1424]
#  [    97    521]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9997093  0.26786632]
# Recall [0.99574934 0.84304207]
# F-score [0.99772539 0.40655482]
# Support [335007    618]
# **************************************
# Iteration number   60
# Class weights  {0: 1, 1: 60}
# Performance on validation data - Confusion matrix
# [[333569   1438]
#  [    96    522]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99971229 0.26632653]
# Recall [0.99570755 0.84466019]
# F-score [0.9977059  0.40496509]
# Support [335007    618]
# **************************************
# Iteration number   61
# Class weights  {0: 1, 1: 61}
# Performance on validation data - Confusion matrix
# [[333548   1459]
#  [    95    523]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99971526 0.26387487]
# Recall [0.99564487 0.84627832]
# F-score [0.99767591 0.40230769]
# Support [335007    618]
# **************************************
# Iteration number   62
# Class weights  {0: 1, 1: 62}
# Performance on validation data - Confusion matrix
# [[333527   1480]
#  [    92    526]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99972424 0.26221336]
# Recall [0.99558218 0.85113269]
# F-score [0.99764891 0.40091463]
# Support [335007    618]
# **************************************
# Iteration number   63
# Class weights  {0: 1, 1: 63}
# Performance on validation data - Confusion matrix
# [[333500   1507]
#  [    89    529]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9997332  0.25982318]
# Recall [0.99550159 0.85598706]
# F-score [0.99761291 0.39864356]
# Support [335007    618]
# **************************************
# Iteration number   64
# Class weights  {0: 1, 1: 64}
# Performance on validation data - Confusion matrix
# [[333478   1529]
#  [    86    532]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99974218 0.25812712]
# Recall [0.99543592 0.86084142]
# F-score [0.9975844  0.39716312]
# Support [335007    618]
# **************************************
# Iteration number   65
# Class weights  {0: 1, 1: 65}
# Performance on validation data - Confusion matrix
# [[333453   1554]
#  [    85    533]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99974516 0.25539051]
# Recall [0.99536129 0.86245955]
# F-score [0.99754841 0.39408503]
# Support [335007    618]
# **************************************
# Iteration number   66
# Class weights  {0: 1, 1: 66}
# Performance on validation data - Confusion matrix
# [[333424   1583]
#  [    85    533]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99974513 0.25189036]
# Recall [0.99527473 0.86245955]
# F-score [0.99750492 0.3899049 ]
# Support [335007    618]
# **************************************
# Iteration number   67
# Class weights  {0: 1, 1: 67}
# Performance on validation data - Confusion matrix
# [[333404   1603]
#  [    84    534]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99974812 0.24988301]
# Recall [0.99521503 0.86407767]
# F-score [0.99747642 0.3876588 ]
# Support [335007    618]
# **************************************
# Iteration number   68
# Class weights  {0: 1, 1: 68}
# Performance on validation data - Confusion matrix
# [[333386   1621]
#  [    82    536]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9997541  0.24849328]
# Recall [0.9951613  0.86731392]
# F-score [0.99745241 0.38630631]
# Support [335007    618]
# **************************************
# Iteration number   69
# Class weights  {0: 1, 1: 69}
# Performance on validation data - Confusion matrix
# [[333360   1647]
#  [    82    536]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99975408 0.24553367]
# Recall [0.99508368 0.86731392]
# F-score [0.99741342 0.38272046]
# Support [335007    618]
# **************************************
# Iteration number   70
# Class weights  {0: 1, 1: 70}
# Performance on validation data - Confusion matrix
# [[333340   1667]
#  [    82    536]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99975407 0.24330458]
# Recall [0.99502398 0.86731392]
# F-score [0.99738342 0.38000709]
# Support [335007    618]
# **************************************
# Iteration number   71
# Class weights  {0: 1, 1: 71}
# Performance on validation data - Confusion matrix
# [[333313   1694]
#  [    80    538]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99976004 0.24103943]
# Recall [0.99494339 0.87055016]
# F-score [0.9973459  0.37754386]
# Support [335007    618]
# **************************************
# Iteration number   72
# Class weights  {0: 1, 1: 72}
# Performance on validation data - Confusion matrix
# [[333294   1713]
#  [    79    539]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99976303 0.23934281]
# Recall [0.99488667 0.87216828]
# F-score [0.99731889 0.37560976]
# Support [335007    618]
# **************************************
# Iteration number   73
# Class weights  {0: 1, 1: 73}
# Performance on validation data - Confusion matrix
# [[333264   1743]
#  [    79    539]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99976301 0.23619632]
# Recall [0.99479712 0.87216828]
# F-score [0.99727388 0.37172414]
# Support [335007    618]
# **************************************
# Iteration number   74
# Class weights  {0: 1, 1: 74}
# Performance on validation data - Confusion matrix
# [[333238   1769]
#  [    77    541]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99976899 0.23419913]
# Recall [0.99471951 0.87540453]
# F-score [0.99723786 0.36953552]
# Support [335007    618]
# **************************************
# Iteration number   75
# Class weights  {0: 1, 1: 75}
# Performance on validation data - Confusion matrix
# [[333216   1791]
#  [    76    542]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99977197 0.2323189 ]
# Recall [0.99465384 0.87702265]
# F-score [0.99720634 0.36733311]
# Support [335007    618]
# **************************************
# Iteration number   76
# Class weights  {0: 1, 1: 76}
# Performance on validation data - Confusion matrix
# [[333196   1811]
#  [    76    542]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99977196 0.23034424]
# Recall [0.99459414 0.87702265]
# F-score [0.99717633 0.36486032]
# Support [335007    618]
# **************************************
# Iteration number   77
# Class weights  {0: 1, 1: 77}
# Performance on validation data - Confusion matrix
# [[333183   1824]
#  [    76    542]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99977195 0.22907861]
# Recall [0.99455534 0.87702265]
# F-score [0.99715682 0.36327078]
# Support [335007    618]
# **************************************
# Iteration number   78
# Class weights  {0: 1, 1: 78}
# Performance on validation data - Confusion matrix
# [[333162   1845]
#  [    75    543]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99977493 0.22738693]
# Recall [0.99449265 0.87864078]
# F-score [0.9971268  0.36127745]
# Support [335007    618]
# **************************************
# Iteration number   79
# Class weights  {0: 1, 1: 79}
# Performance on validation data - Confusion matrix
# [[333142   1865]
#  [    73    545]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99978092 0.22614108]
# Recall [0.99443295 0.88187702]
# F-score [0.99709977 0.35997358]
# Support [335007    618]
# **************************************
# Iteration number   80
# Class weights  {0: 1, 1: 80}
# Performance on validation data - Confusion matrix
# [[333117   1890]
#  [    70    548]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99978991 0.22477441]
# Recall [0.99435833 0.88673139]
# F-score [0.99706672 0.35863874]
# Support [335007    618]
# **************************************
# Iteration number   81
# Class weights  {0: 1, 1: 81}
# Performance on validation data - Confusion matrix
# [[333096   1911]
#  [    70    548]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99978989 0.22285482]
# Recall [0.99429564 0.88673139]
# F-score [0.9970352 0.3561911]
# Support [335007    618]
# **************************************
# Iteration number   82
# Class weights  {0: 1, 1: 82}
# Performance on validation data - Confusion matrix
# [[333075   1932]
#  [    70    548]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99978988 0.22096774]
# Recall [0.99423296 0.88673139]
# F-score [0.99700368 0.35377663]
# Support [335007    618]
# **************************************
# Iteration number   83
# Class weights  {0: 1, 1: 83}
# Performance on validation data - Confusion matrix
# [[333046   1961]
#  [    66    552]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99980187 0.21965778]
# Recall [0.99414639 0.89320388]
# F-score [0.99696611 0.352603  ]
# Support [335007    618]
# **************************************
# Iteration number   84
# Class weights  {0: 1, 1: 84}
# Performance on validation data - Confusion matrix
# [[333029   1978]
#  [    65    553]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99980486 0.21849072]
# Recall [0.99409565 0.89482201]
# F-score [0.99694208 0.35122261]
# Support [335007    618]
# **************************************
# Iteration number   85
# Class weights  {0: 1, 1: 85}
# Performance on validation data - Confusion matrix
# [[333011   1996]
#  [    64    554]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99980785 0.2172549 ]
# Recall [0.99404192 0.89644013]
# F-score [0.99691655 0.34974747]
# Support [335007    618]
# **************************************
# Iteration number   86
# Class weights  {0: 1, 1: 86}
# Performance on validation data - Confusion matrix
# [[332987   2020]
#  [    62    556]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99981384 0.21583851]
# Recall [0.99397028 0.89967638]
# F-score [0.99688349 0.34815279]
# Support [335007    618]
# **************************************
# Iteration number   87
# Class weights  {0: 1, 1: 87}
# Performance on validation data - Confusion matrix
# [[332968   2039]
#  [    62    556]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99981383 0.21425819]
# Recall [0.99391356 0.89967638]
# F-score [0.99685496 0.34609399]
# Support [335007    618]
# **************************************
# Iteration number   88
# Class weights  {0: 1, 1: 88}
# Performance on validation data - Confusion matrix
# [[332951   2056]
#  [    62    556]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99981382 0.21286371]
# Recall [0.99386281 0.89967638]
# F-score [0.99682944 0.34427245]
# Support [335007    618]
# **************************************
# Iteration number   89
# Class weights  {0: 1, 1: 89}
# Performance on validation data - Confusion matrix
# [[332930   2077]
#  [    61    557]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99981681 0.21146545]
# Recall [0.99380013 0.9012945 ]
# F-score [0.99679939 0.34255843]
# Support [335007    618]
# **************************************
# Iteration number   90
# Class weights  {0: 1, 1: 90}
# Performance on validation data - Confusion matrix
# [[332917   2090]
#  [    60    558]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99981981 0.21072508]
# Recall [0.99376132 0.90291262]
# F-score [0.99678136 0.34170239]
# Support [335007    618]
# **************************************
# Iteration number   91
# Class weights  {0: 1, 1: 91}
# Performance on validation data - Confusion matrix
# [[332897   2110]
#  [    57    561]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99982881 0.2100337 ]
# Recall [0.99370162 0.90776699]
# F-score [0.9967558  0.34113712]
# Support [335007    618]
# **************************************
# Iteration number   92
# Class weights  {0: 1, 1: 92}
# Performance on validation data - Confusion matrix
# [[332876   2131]
#  [    57    561]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99982879 0.20839525]
# Recall [0.99363894 0.90776699]
# F-score [0.99672426 0.33897281]
# Support [335007    618]
# **************************************
# Iteration number   93
# Class weights  {0: 1, 1: 93}
# Performance on validation data - Confusion matrix
# [[332850   2157]
#  [    56    562]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99983178 0.20669364]
# Recall [0.99356133 0.90938511]
# F-score [0.99668669 0.33682949]
# Support [335007    618]
# **************************************
# Iteration number   94
# Class weights  {0: 1, 1: 94}
# Performance on validation data - Confusion matrix
# [[332833   2174]
#  [    55    563]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99983478 0.20569967]
# Recall [0.99351058 0.91100324]
# F-score [0.99666265 0.33561848]
# Support [335007    618]
# **************************************
# Iteration number   95
# Class weights  {0: 1, 1: 95}
# Performance on validation data - Confusion matrix
# [[332804   2203]
#  [    54    564]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99983777 0.20383086]
# Recall [0.99342402 0.91262136]
# F-score [0.99662057 0.33323486]
# Support [335007    618]
# **************************************
# Iteration number   96
# Class weights  {0: 1, 1: 96}
# Performance on validation data - Confusion matrix
# [[332785   2222]
#  [    53    565]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99984076 0.20272695]
# Recall [0.9933673  0.91423948]
# F-score [0.99659352 0.3318649 ]
# Support [335007    618]
# **************************************
# Iteration number   97
# Class weights  {0: 1, 1: 97}
# Performance on validation data - Confusion matrix
# [[332773   2234]
#  [    53    565]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99984076 0.20185781]
# Recall [0.99333148 0.91423948]
# F-score [0.99657549 0.33069944]
# Support [335007    618]
# **************************************
# Iteration number   98
# Class weights  {0: 1, 1: 98}
# Performance on validation data - Confusion matrix
# [[332758   2249]
#  [    53    565]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99984075 0.20078181]
# Recall [0.99328671 0.91423948]
# F-score [0.99655295 0.32925408]
# Support [335007    618]
# **************************************
# Iteration number   99
# Class weights  {0: 1, 1: 99}
# Performance on validation data - Confusion matrix
# [[332744   2263]
#  [    52    566]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99984375 0.2000707 ]
# Recall [0.99324492 0.91585761]
# F-score [0.99653341 0.32840151]
# Support [335007    618]
# **************************************
# Iteration number   100
# Class weights  {0: 1, 1: 100}
# Performance on validation data - Confusion matrix
# [[332723   2284]
#  [    51    567]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99984674 0.19887759]
# Recall [0.99318223 0.91747573]
# F-score [0.99650334 0.32689536]
# Support [335007    618]
# **************************************
# Iteration number   101
# Class weights  {0: 1, 1: 101}
# Performance on validation data - Confusion matrix
# [[332698   2309]
#  [    51    567]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99984673 0.19714882]
# Recall [0.99310761 0.91747573]
# F-score [0.99646577 0.32455638]
# Support [335007    618]
# **************************************
# Iteration number   102
# Class weights  {0: 1, 1: 102}
# Performance on validation data - Confusion matrix
# [[332678   2329]
#  [    49    569]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99985273 0.19634231]
# Recall [0.99304791 0.92071197]
# F-score [0.9964387  0.32366325]
# Support [335007    618]
# **************************************
# Iteration number   103
# Class weights  {0: 1, 1: 103}
# Performance on validation data - Confusion matrix
# [[332657   2350]
#  [    49    569]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99985272 0.19492977]
# Recall [0.99298522 0.92071197]
# F-score [0.99640714 0.32174159]
# Support [335007    618]
# **************************************
# Iteration number   104
# Class weights  {0: 1, 1: 104}
# Performance on validation data - Confusion matrix
# [[332635   2372]
#  [    48    570]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99985572 0.19374575]
# Recall [0.99291955 0.9223301 ]
# F-score [0.99637556 0.32022472]
# Support [335007    618]
# **************************************
# Iteration number   105
# Class weights  {0: 1, 1: 105}
# Performance on validation data - Confusion matrix
# [[332611   2396]
#  [    47    571]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99985871 0.19245029]
# Recall [0.99284791 0.92394822]
# F-score [0.99634098 0.31854951]
# Support [335007    618]
# **************************************
# Iteration number   106
# Class weights  {0: 1, 1: 106}
# Performance on validation data - Confusion matrix
# [[332592   2415]
#  [    47    571]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99985871 0.19122572]
# Recall [0.9927912  0.92394822]
# F-score [0.99631242 0.31687014]
# Support [335007    618]
# **************************************
# Iteration number   107
# Class weights  {0: 1, 1: 107}
# Performance on validation data - Confusion matrix
# [[332570   2437]
#  [    46    572]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9998617  0.19009638]
# Recall [0.99272553 0.92556634]
# F-score [0.99628084 0.31541219]
# Support [335007    618]
# **************************************
# Iteration number   108
# Class weights  {0: 1, 1: 108}
# Performance on validation data - Confusion matrix
# [[332550   2457]
#  [    43    575]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99987071 0.1896438 ]
# Recall [0.99266582 0.93042071]
# F-score [0.99625524 0.31506849]
# Support [335007    618]
# **************************************
# Iteration number   109
# Class weights  {0: 1, 1: 109}
# Performance on validation data - Confusion matrix
# [[332525   2482]
#  [    43    575]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9998707 0.1880929]
# Recall [0.9925912  0.93042071]
# F-score [0.99621765 0.31292517]
# Support [335007    618]
# **************************************
# Iteration number   110
# Class weights  {0: 1, 1: 110}
# Performance on validation data - Confusion matrix
# [[332503   2504]
#  [    43    575]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99987069 0.18674894]
# Recall [0.99252553 0.93042071]
# F-score [0.99618457 0.31106302]
# Support [335007    618]
# **************************************
# Iteration number   111
# Class weights  {0: 1, 1: 111}
# Performance on validation data - Confusion matrix
# [[332483   2524]
#  [    43    575]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99987069 0.18554372]
# Recall [0.99246583 0.93042071]
# F-score [0.9961545  0.30938929]
# Support [335007    618]
# **************************************
# Iteration number   112
# Class weights  {0: 1, 1: 112}
# Performance on validation data - Confusion matrix
# [[332460   2547]
#  [    43    575]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99987068 0.18417681]
# Recall [0.99239717 0.93042071]
# F-score [0.99611991 0.30748663]
# Support [335007    618]
# **************************************
# Iteration number   113
# Class weights  {0: 1, 1: 113}
# Performance on validation data - Confusion matrix
# [[332442   2565]
#  [    42    576]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99987368 0.18338109]
# Recall [0.99234344 0.93203883]
# F-score [0.99609433 0.30646449]
# Support [335007    618]
# **************************************
# Iteration number   114
# Class weights  {0: 1, 1: 114}
# Performance on validation data - Confusion matrix
# [[332422   2585]
#  [    41    577]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99987668 0.18247944]
# Recall [0.99228374 0.93365696]
# F-score [0.99606574 0.30529101]
# Support [335007    618]
# **************************************
# Iteration number   115
# Class weights  {0: 1, 1: 115}
# Performance on validation data - Confusion matrix
# [[332398   2609]
#  [    40    578]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99987968 0.18136178]
# Recall [0.9922121  0.93527508]
# F-score [0.99603113 0.30381078]
# Support [335007    618]
# **************************************
# Iteration number   116
# Class weights  {0: 1, 1: 116}
# Performance on validation data - Confusion matrix
# [[332380   2627]
#  [    38    580]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99988569 0.18085438]
# Recall [0.99215837 0.93851133]
# F-score [0.99600704 0.30326797]
# Support [335007    618]
# **************************************
# Iteration number   117
# Class weights  {0: 1, 1: 117}
# Performance on validation data - Confusion matrix
# [[332347   2660]
#  [    38    580]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99988567 0.17901235]
# Recall [0.99205987 0.93851133]
# F-score [0.9959574  0.30067392]
# Support [335007    618]
# **************************************
# Iteration number   118
# Class weights  {0: 1, 1: 118}
# Performance on validation data - Confusion matrix
# [[332326   2681]
#  [    38    580]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99988567 0.17785955]
# Recall [0.99199718 0.93851133]
# F-score [0.9959258  0.29904615]
# Support [335007    618]
# **************************************
# Iteration number   119
# Class weights  {0: 1, 1: 119}
# Performance on validation data - Confusion matrix
# [[332296   2711]
#  [    37    581]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99988867 0.17648846]
# Recall [0.99190763 0.94012945]
# F-score [0.99588216 0.2971867 ]
# Support [335007    618]
# **************************************
# Iteration number   120
# Class weights  {0: 1, 1: 120}
# Performance on validation data - Confusion matrix
# [[332266   2741]
#  [    37    581]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99988866 0.17489464]
# Recall [0.99181808 0.94012945]
# F-score [0.99583702 0.29492386]
# Support [335007    618]
# **************************************
# Iteration number   121
# Class weights  {0: 1, 1: 121}
# Performance on validation data - Confusion matrix
# [[332243   2764]
#  [    36    582]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99989166 0.17393903]
# Recall [0.99174943 0.94174757]
# F-score [0.9958039  0.29364279]
# Support [335007    618]
# **************************************
# Iteration number   122
# Class weights  {0: 1, 1: 122}
# Performance on validation data - Confusion matrix
# [[332214   2793]
#  [    36    582]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99989165 0.17244444]
# Recall [0.99166286 0.94174757]
# F-score [0.99576025 0.29151014]
# Support [335007    618]
# **************************************
# Iteration number   123
# Class weights  {0: 1, 1: 123}
# Performance on validation data - Confusion matrix
# [[332185   2822]
#  [    35    583]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99989465 0.1712188 ]
# Recall [0.9915763 0.9433657]
# F-score [0.9957181  0.28983346]
# Support [335007    618]
# **************************************
# Iteration number   124
# Class weights  {0: 1, 1: 124}
# Performance on validation data - Confusion matrix
# [[332161   2846]
#  [    35    583]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99989464 0.17002041]
# Recall [0.99150466 0.9433657 ]
# F-score [0.99568197 0.28811465]
# Support [335007    618]
# **************************************
# Iteration number   125
# Class weights  {0: 1, 1: 125}
# Performance on validation data - Confusion matrix
# [[332144   2863]
#  [    35    583]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99989464 0.16918166]
# Recall [0.99145391 0.9433657 ]
# F-score [0.99565638 0.28690945]
# Support [335007    618]
# **************************************
# Iteration number   126
# Class weights  {0: 1, 1: 126}
# Performance on validation data - Confusion matrix
# [[332114   2893]
#  [    34    584]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99989764 0.16796089]
# Recall [0.99136436 0.94498382]
# F-score [0.99561271 0.28522589]
# Support [335007    618]
# **************************************
# Iteration number   127
# Class weights  {0: 1, 1: 127}
# Performance on validation data - Confusion matrix
# [[332087   2920]
#  [    32    586]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990365 0.16714204]
# Recall [0.99128376 0.94822006]
# F-score [0.99557505 0.28419011]
# Support [335007    618]
# **************************************
# Iteration number   128
# Class weights  {0: 1, 1: 128}
# Performance on validation data - Confusion matrix
# [[332059   2948]
#  [    32    586]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990364 0.16581777]
# Recall [0.99120018 0.94822006]
# F-score [0.99553289 0.2822736 ]
# Support [335007    618]
# **************************************
# Iteration number   129
# Class weights  {0: 1, 1: 129}
# Performance on validation data - Confusion matrix
# [[332039   2968]
#  [    32    586]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990364 0.16488464]
# Recall [0.99114048 0.94822006]
# F-score [0.99550277 0.28092042]
# Support [335007    618]
# **************************************
# Iteration number   130
# Class weights  {0: 1, 1: 130}
# Performance on validation data - Confusion matrix
# [[332015   2992]
#  [    32    586]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990363 0.16377865]
# Recall [0.99106884 0.94822006]
# F-score [0.99546663 0.27931363]
# Support [335007    618]
# **************************************
# Iteration number   131
# Class weights  {0: 1, 1: 131}
# Performance on validation data - Confusion matrix
# [[331992   3015]
#  [    31    587]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990663 0.16296502]
# Recall [0.99100019 0.94983819]
# F-score [0.99543349 0.27819905]
# Support [335007    618]
# **************************************
# Iteration number   132
# Class weights  {0: 1, 1: 132}
# Performance on validation data - Confusion matrix
# [[331972   3035]
#  [    30    588]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990964 0.16229644]
# Recall [0.99094049 0.95145631]
# F-score [0.99540486 0.27729309]
# Support [335007    618]
# **************************************
# Iteration number   133
# Class weights  {0: 1, 1: 133}
# Performance on validation data - Confusion matrix
# [[331944   3063]
#  [    30    588]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990963 0.16105177]
# Recall [0.99085691 0.95145631]
# F-score [0.99536269 0.27547435]
# Support [335007    618]
# **************************************
# Iteration number   134
# Class weights  {0: 1, 1: 134}
# Performance on validation data - Confusion matrix
# [[331924   3083]
#  [    30    588]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990963 0.16017434]
# Recall [0.99079721 0.95145631]
# F-score [0.99533256 0.27418979]
# Support [335007    618]
# **************************************
# Iteration number   135
# Class weights  {0: 1, 1: 135}
# Performance on validation data - Confusion matrix
# [[331901   3106]
#  [    30    588]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990962 0.15917704]
# Recall [0.99072855 0.95145631]
# F-score [0.99529791 0.27272727]
# Support [335007    618]
# **************************************
# Iteration number   136
# Class weights  {0: 1, 1: 136}
# Performance on validation data - Confusion matrix
# [[331881   3126]
#  [    30    588]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99990961 0.15831987]
# Recall [0.99066885 0.95145631]
# F-score [0.99526778 0.27146814]
# Support [335007    618]
# ...
# F-score [0.98006336 0.08534116]
# Support [335007    618]
# **************************************
# Iteration number   456
# Class weights  {0: 1, 1: 456}
# Performance on validation data - Confusion matrix
# [[321893  13114]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997825 0.0445173 ]
# Recall [0.96085455 0.98867314]
# F-score [0.98002609 0.08519835]
# Support [335007    618]
# **************************************
# Iteration number   457
# Class weights  {0: 1, 1: 457}
# Performance on validation data - Confusion matrix
# [[321865  13142]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997825 0.04442667]
# Recall [0.96077097 0.98867314]
# F-score [0.97998261 0.08503236]
# Support [335007    618]
# **************************************
# Iteration number   458
# Class weights  {0: 1, 1: 458}
# Performance on validation data - Confusion matrix
# [[321839  13168]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997825 0.04434284]
# Recall [0.96069336 0.98867314]
# F-score [0.97994224 0.08487879]
# Support [335007    618]
# **************************************
# Iteration number   459
# Class weights  {0: 1, 1: 459}
# Performance on validation data - Confusion matrix
# [[321821  13186]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997825 0.04428499]
# Recall [0.96063963 0.98867314]
# F-score [0.97991429 0.08477281]
# Support [335007    618]
# **************************************
# Iteration number   460
# Class weights  {0: 1, 1: 460}
# Performance on validation data - Confusion matrix
# [[321792  13215]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997825 0.0441921 ]
# Recall [0.96055306 0.98867314]
# F-score [0.97986925 0.0846026 ]
# Support [335007    618]
# **************************************
# Iteration number   461
# Class weights  {0: 1, 1: 461}
# Performance on validation data - Confusion matrix
# [[321767  13240]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997825 0.04411234]
# Recall [0.96047844 0.98867314]
# F-score [0.97983042 0.08445642]
# Support [335007    618]
# **************************************
# Iteration number   462
# Class weights  {0: 1, 1: 462}
# Performance on validation data - Confusion matrix
# [[321751  13256]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997824 0.04406144]
# Recall [0.96043068 0.98867314]
# F-score [0.97980556 0.08436313]
# Support [335007    618]
# **************************************
# Iteration number   463
# Class weights  {0: 1, 1: 463}
# Performance on validation data - Confusion matrix
# [[321730  13277]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997824 0.04399482]
# Recall [0.96036799 0.98867314]
# F-score [0.97977294 0.084241  ]
# Support [335007    618]
# **************************************
# Iteration number   464
# Class weights  {0: 1, 1: 464}
# Performance on validation data - Confusion matrix
# [[321704  13303]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997824 0.04391261]
# Recall [0.96029038 0.98867314]
# F-score [0.97973255 0.08409028]
# Support [335007    618]
# **************************************
# Iteration number   465
# Class weights  {0: 1, 1: 465}
# Performance on validation data - Confusion matrix
# [[321679  13328]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997824 0.04383385]
# Recall [0.96021576 0.98867314]
# F-score [0.97969371 0.08394587]
# Support [335007    618]
# **************************************
# Iteration number   466
# Class weights  {0: 1, 1: 466}
# Performance on validation data - Confusion matrix
# [[321650  13357]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997824 0.04374284]
# Recall [0.96012919 0.98867314]
# F-score [0.97964865 0.08377897]
# Support [335007    618]
# **************************************
# Iteration number   467
# Class weights  {0: 1, 1: 467}
# Performance on validation data - Confusion matrix
# [[321624  13383]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997824 0.04366157]
# Recall [0.96005158 0.98867314]
# F-score [0.97960825 0.08362989]
# Support [335007    618]
# **************************************
# Iteration number   468
# Class weights  {0: 1, 1: 468}
# Performance on validation data - Confusion matrix
# [[321608  13399]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997823 0.04361171]
# Recall [0.96000382 0.98867314]
# F-score [0.97958338 0.08353842]
# Support [335007    618]
# **************************************
# Iteration number   469
# Class weights  {0: 1, 1: 469}
# Performance on validation data - Confusion matrix
# [[321585  13422]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997823 0.04354023]
# Recall [0.95993517 0.98867314]
# F-score [0.97954764 0.08340728]
# Support [335007    618]
# **************************************
# Iteration number   470
# Class weights  {0: 1, 1: 470}
# Performance on validation data - Confusion matrix
# [[321557  13450]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997823 0.04345352]
# Recall [0.95985159 0.98867314]
# F-score [0.97950412 0.08324818]
# Support [335007    618]
# **************************************
# Iteration number   471
# Class weights  {0: 1, 1: 471}
# Performance on validation data - Confusion matrix
# [[321537  13470]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997823 0.0433918 ]
# Recall [0.95979188 0.98867314]
# F-score [0.97947303 0.08313491]
# Support [335007    618]
# **************************************
# Iteration number   472
# Class weights  {0: 1, 1: 472}
# Performance on validation data - Confusion matrix
# [[321512  13495]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997823 0.0433149 ]
# Recall [0.95971726 0.98867314]
# F-score [0.97943417 0.08299375]
# Support [335007    618]
# **************************************
# Iteration number   473
# Class weights  {0: 1, 1: 473}
# Performance on validation data - Confusion matrix
# [[321495  13512]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997823 0.04326276]
# Recall [0.95966651 0.98867314]
# F-score [0.97940775 0.08289804]
# Support [335007    618]
# **************************************
# Iteration number   474
# Class weights  {0: 1, 1: 474}
# Performance on validation data - Confusion matrix
# [[321475  13532]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997823 0.04320158]
# Recall [0.95960681 0.98867314]
# F-score [0.97937665 0.08278572]
# Support [335007    618]
# **************************************
# Iteration number   475
# Class weights  {0: 1, 1: 475}
# Performance on validation data - Confusion matrix
# [[321448  13559]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997822 0.04311927]
# Recall [0.95952622 0.98867314]
# F-score [0.97933468 0.08263457]
# Support [335007    618]
# **************************************
# Iteration number   476
# Class weights  {0: 1, 1: 476}
# Performance on validation data - Confusion matrix
# [[321416  13591]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997822 0.04302211]
# Recall [0.9594307  0.98867314]
# F-score [0.97928492 0.08245614]
# Support [335007    618]
# **************************************
# Iteration number   477
# Class weights  {0: 1, 1: 477}
# Performance on validation data - Confusion matrix
# [[321389  13618]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997822 0.04294047]
# Recall [0.9593501  0.98867314]
# F-score [0.97924293 0.08230619]
# Support [335007    618]
# **************************************
# Iteration number   478
# Class weights  {0: 1, 1: 478}
# Performance on validation data - Confusion matrix
# [[321366  13641]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997822 0.04287118]
# Recall [0.95928145 0.98867314]
# F-score [0.97920717 0.08217888]
# Support [335007    618]
# **************************************
# Iteration number   479
# Class weights  {0: 1, 1: 479}
# Performance on validation data - Confusion matrix
# [[321339  13668]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997822 0.04279011]
# Recall [0.95920085 0.98867314]
# F-score [0.97916517 0.08202994]
# Support [335007    618]
# **************************************
# Iteration number   480
# Class weights  {0: 1, 1: 480}
# Performance on validation data - Confusion matrix
# [[321318  13689]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997822 0.04272727]
# Recall [0.95913817 0.98867314]
# F-score [0.97913251 0.08191447]
# Support [335007    618]
# **************************************
# Iteration number   481
# Class weights  {0: 1, 1: 481}
# Performance on validation data - Confusion matrix
# [[321287  13720]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997821 0.04263485]
# Recall [0.95904563 0.98867314]
# F-score [0.97908429 0.0817446 ]
# Support [335007    618]
# **************************************
# Iteration number   482
# Class weights  {0: 1, 1: 482}
# Performance on validation data - Confusion matrix
# [[321259  13748]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997821 0.04255171]
# Recall [0.95896205 0.98867314]
# F-score [0.97904073 0.08159177]
# Support [335007    618]
# **************************************
# Iteration number   483
# Class weights  {0: 1, 1: 483}
# Performance on validation data - Confusion matrix
# [[321241  13766]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997821 0.04249844]
# Recall [0.95890832 0.98867314]
# F-score [0.97901273 0.08149383]
# Support [335007    618]
# **************************************
# Iteration number   484
# Class weights  {0: 1, 1: 484}
# Performance on validation data - Confusion matrix
# [[321222  13785]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997821 0.04244235]
# Recall [0.95885161 0.98867314]
# F-score [0.97898317 0.0813907 ]
# Support [335007    618]
# **************************************
# Iteration number   485
# Class weights  {0: 1, 1: 485}
# Performance on validation data - Confusion matrix
# [[321194  13813]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997821 0.04235996]
# Recall [0.95876803 0.98867314]
# F-score [0.9789396 0.0812392]
# Support [335007    618]
# **************************************
# Iteration number   486
# Class weights  {0: 1, 1: 486}
# Performance on validation data - Confusion matrix
# [[321170  13837]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997821 0.04228959]
# Recall [0.95869639 0.98867314]
# F-score [0.97890226 0.08110978]
# Support [335007    618]
# **************************************
# Iteration number   487
# Class weights  {0: 1, 1: 487}
# Performance on validation data - Confusion matrix
# [[321145  13862]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9999782  0.04221654]
# Recall [0.95862176 0.98867314]
# F-score [0.97886335 0.08097542]
# Support [335007    618]
# **************************************
# Iteration number   488
# Class weights  {0: 1, 1: 488}
# Performance on validation data - Confusion matrix
# [[321119  13888]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9999782  0.04214084]
# Recall [0.95854415 0.98867314]
# F-score [0.97882289 0.08083614]
# Support [335007    618]
# **************************************
# Iteration number   489
# Class weights  {0: 1, 1: 489}
# Performance on validation data - Confusion matrix
# [[321092  13915]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9999782  0.04206251]
# Recall [0.95846355 0.98867314]
# F-score [0.97878087 0.08069202]
# Support [335007    618]
# **************************************
# Iteration number   490
# Class weights  {0: 1, 1: 490}
# Performance on validation data - Confusion matrix
# [[321068  13939]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9999782  0.04199313]
# Recall [0.95839191 0.98867314]
# F-score [0.97874351 0.08056435]
# Support [335007    618]
# **************************************
# Iteration number   491
# Class weights  {0: 1, 1: 491}
# Performance on validation data - Confusion matrix
# [[321041  13966]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.9999782  0.04191535]
# Recall [0.95831132 0.98867314]
# F-score [0.97870148 0.08042119]
# Support [335007    618]
# **************************************
# Iteration number   492
# Class weights  {0: 1, 1: 492}
# Performance on validation data - Confusion matrix
# [[321014  13993]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997819 0.04183785]
# Recall [0.95823072 0.98867314]
# F-score [0.97865945 0.08027854]
# Support [335007    618]
# **************************************
# Iteration number   493
# Class weights  {0: 1, 1: 493}
# Performance on validation data - Confusion matrix
# [[320986  14021]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997819 0.04175779]
# Recall [0.95814714 0.98867314]
# F-score [0.97861585 0.08013115]
# Support [335007    618]
# **************************************
# Iteration number   494
# Class weights  {0: 1, 1: 494}
# Performance on validation data - Confusion matrix
# [[320964  14043]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997819 0.0416951 ]
# Recall [0.95808147 0.98867314]
# F-score [0.9785816  0.08001572]
# Support [335007    618]
# **************************************
# Iteration number   495
# Class weights  {0: 1, 1: 495}
# Performance on validation data - Confusion matrix
# [[320940  14067]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997819 0.04162692]
# Recall [0.95800983 0.98867314]
# F-score [0.97854423 0.07989017]
# Support [335007    618]
# **************************************
# Iteration number   496
# Class weights  {0: 1, 1: 496}
# Performance on validation data - Confusion matrix
# [[320911  14096]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997819 0.04154484]
# Recall [0.95792327 0.98867314]
# F-score [0.97849907 0.07973899]
# Support [335007    618]
# **************************************
# Iteration number   497
# Class weights  {0: 1, 1: 497}
# Performance on validation data - Confusion matrix
# [[320885  14122]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997819 0.04147153]
# Recall [0.95784566 0.98867314]
# F-score [0.97845857 0.07960393]
# Support [335007    618]
# **************************************
# Iteration number   498
# Class weights  {0: 1, 1: 498}
# Performance on validation data - Confusion matrix
# [[320857  14150]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997818 0.04139286]
# Recall [0.95776208 0.98867314]
# F-score [0.97841496 0.079459  ]
# Support [335007    618]
# **************************************
# Iteration number   499
# Class weights  {0: 1, 1: 499}
# Performance on validation data - Confusion matrix
# [[320835  14172]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997818 0.04133126]
# Recall [0.95769641 0.98867314]
# F-score [0.97838069 0.0793455 ]
# Support [335007    618]
# **************************************
# Iteration number   500
# Class weights  {0: 1, 1: 500}
# Performance on validation data - Confusion matrix
# [[320808  14199]
#  [     7    611]]
# Precision, Recall, F-score, Support  on validation data
# Precision [0.99997818 0.04125591]
# Recall [0.95761581 0.98867314]
# F-score [0.97833863 0.07920664]
# Support [335007    618]
